# %% [markdown]
# <a href="https://colab.research.google.com/github/gyxcit/nlp_course1/blob/main/pw1_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/PaulLerner/aivancity_nlp/blob/main/pw1_embedding.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Part 0 - Installation and imports
#
# Hit `Ctrl+S` to save a copy of the Colab notebook to your drive
#
# Run on Google Colab GPU:
# - Connect
# - Modify execution
# - GPU
#
# ![image.png](https://paullerner.github.io/aivancity_nlp/_static/colab_gpu.png)

# %%
# %pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import torch

# %%
assert torch.cuda.is_available(), "Connect to GPU and try again (ask teacher for help)"

# %% [markdown]
# # Part 1 - Training Skipgram with negative sampling
#
# (aka word2vec)
# Mikolov, T., Sutskever, I., Chen, K., Corrado, G. S., & Dean, J. (2013). [Distributed Representations of Words and Phrases and their Compositionality](https://papers.neurips.cc/paper/2013/hash/9aa42b31882ec039965f3c4923ce901b-Abstract.html). Advances in Neural Information Processing Systems, 26.
#
# Eisenstein, J. (2018). [Natural Language Processing](https://csunibo.github.io/natural-language-processing/books/eisenstein-natural-language-processing.pdf) Chapter 14.5
#
# Not to be confused with Softmax Skipgram

# %% [markdown]
# ## Training data

# %%
from datasets import load_dataset, DatasetDict

texts = load_dataset('wikitext', 'wikitext-103-raw-v1')['train'].shuffle(seed=1111).select(range(10000))["text"]
len(texts)
# Out:
# 10000

# %% [markdown]
# ### Tokenization
#
# Unsing [`re`](https://docs.python.org/3/library/re.html), tokenize the text in a `List[str]` to keep only words, no punctuation or space. We will also preprocess the text to make it lowercase, so our model is *case-insensitive*
#
# If you don't know anything about regex, a good place to start is https://regex101.com/

# %%
import re

# %%
texts[0]
# Out:
# " Following the death of Finan , bishop of Lindisfarne , Alhfrith of Deira , in collusion with Wilfred of York , Agilbert of Wessex and others , were determined to persuade Oswiu to rule in favour of the Roman rite of Christianity within the kingdoms over which he had imperium . The case was debated in Oswiu 's presence at the Synod of Whitby in 664 , with Colmán , Hild and Cedd defending the Celtic rite and the tradition inherited from Aidan , and Wilifred speaking for the Roman position . The Roman cause prevailed and the former division of ecclesiastical authorities was set aside . Those who could not accept it , including Colmán , departed elsewhere . \n"

# %%
type(texts)
# Out:
# list

# %%
def tokenize_text(text: str) -> list[str]:
    # Convert text to lowercase

    text = text.lower()
    # Find all words using regex (alphanumeric sequences)
    tokens = re.findall(r'\b\w+\b', text)
    return tokens

# %%
def one_list_to_govern_them_all(liste:list) -> list[str]:
  to_unique=[]
  for i in range(0,len(liste)):
    to_unique.extend(liste[i])
  return to_unique

# %%
#unique list
unique_texts=one_list_to_govern_them_all(texts)

# %%
texts=[tokenize_text(x) for x in texts]

# %%
texts
# Out:
# [['following',
#   'the',
#   'death',
#   'of',
#   'finan',
#   'bishop',
#   'of',
#   'lindisfarne',
#   'alhfrith',
#   'of',
#   'deira',
#   'in',
#   'collusion',
#   'with',
#   'wilfred',
#   'of',
#   'york',
#   'agilbert',
#   'of',
#   'wessex',
#   'and',
#   'others',
#   'were',
#   'determined',
#   'to',
#   'persuade',
#   'oswiu',
#   'to',
#   'rule',
#   'in',
#   'favour',
#   'of',
#   'the',
#   'roman',
#   'rite',
#   'of',
#   'christianity',
#   'within',
#   'the',
#   'kingdoms',
#   'over',
#   'which',
#   'he',
#   'had',
#   'imperium',
#   'the',
#   'case',
#   'was',
#   'debated',
#   'in',
#   'oswiu',
#   's',
#   'presence',
#   'at',
#   'the',
#   'synod',
#   'of',
#   'whitby',
#   'in',
#   '664',
#   'with',
#   'colmán',
#   'hild',
#   'and',
#   'cedd',
#   'defending',
#   'the',
#   'celtic',
#   'rite',
#   'and',
#   'the',
#   'tradition',
#   'inherited',
#   'from',
#   'aidan',
#   'and',
#   'wilifred',
#   'speaking',
#   'for',
#   'the',
#   'roman',
#   'position',
#   'the',
#   'roman',
#   'cause',
#   'prevailed',
#   'and',
#   'the',
#   'former',
#   'division',
#   'of',
#   'ecclesiastical',
#   'authorities',
#   'was',
#   'set',
#   'aside',
#   'those',
#   'who',
#   'could',
#   'not',
#   'accept',
#   'it',
#   'including',
#   'colmán',
#   'departed',
#   'elsewhere'],
#  ['language'],
#  ['the',
#   'warriors',
#   'retreated',
#   'to',
#   'prophetstown',
#   'where',
#   'according',
#   'to',
#   'one',
#   'chief',
#   's',
#   'account',
#   'the',
#   'warriors',
#   'confronted',
#   'tenskwatawa',
#   'and',
#   'accused',
#   'him',
#   'of',
#   'deceit',
#   'because',
#   'of',
#   'the',
#   'many',
#   'deaths',
#   'which',
#   'his',
#   'spells',
#   'were',
#   'supposed',
#   'to',
#   'have',
#   'prevented',
#   'he',
#   'blamed',
#   'his',
#   'wife',
#   'for',
#   'desecrating',
#   'his',
#   'magic',
#   'medicine',
#   'and',
#   'offered',
#   'to',
#   'cast',
#   'a',
#   'new',
#   'spell',
#   'and',
#   'insisted',
#   'that',
#   'warriors',
#   'launch',
#   'a',
#   'second',
#   'attack',
#   'but',
#   'they',
#   'refused'],
#  ['in',
#   'feudal',
#   'japan',
#   'taiko',
#   'were',
#   'often',
#   'used',
#   'to',
#   'motivate',
#   'troops',
#   'call',
#   'out',
#   'orders',
#   'or',
#   'announcements',
#   'and',
#   'set',
#   'a',
#   'marching',
#   'pace',
#   'marches',
#   'were',
#   'usually',
#   'set',
#   'to',
#   'six',
#   'paces',
#   'per',
#   'beat',
#   'of',
#   'the',
#   'drum',
#   'during',
#   'the',
#   '16th',
#   'century',
#   'warring',
#   'states',
#   'period',
#   'specific',
#   'drum',
#   'calls',
#   'were',
#   'used',
#   'to',
#   'communicate',
#   'orders',
#   'for',
#   'retreating',
#   'and',
#   'advancing',
#   'other',
#   'rhythms',
#   'and',
#   'techniques',
#   'were',
#   'detailed',
#   'in',
#   'period',
#   'texts',
#   'according',
#   'to',
#   'the',
#   'war',
#   'chronicle',
#   'gunji',
#   'yoshū',
#   'nine',
#   'sets',
#   'of',
#   'five',
#   'beats',
#   'would',
#   'summon',
#   'an',
#   'ally',
#   'to',
#   'battle',
#   'while',
#   'nine',
#   'sets',
#   'of',
#   'three',
#   'beats',
#   'sped',
#   'up',
#   'three',
#   'or',
#   'four',
#   'times',
#   'was',
#   'the',
#   'call',
#   'to',
#   'advance',
#   'and',
#   'pursue',
#   'an',
#   'enemy',
#   'folklore',
#   'from',
#   'the',
#   '16th',
#   'century',
#   'on',
#   'the',
#   'legendary',
#   '6th',
#   'century',
#   'emperor',
#   'keitai',
#   'offers',
#   'a',
#   'story',
#   'that',
#   'he',
#   'obtained',
#   'a',
#   'large',
#   'drum',
#   'from',
#   'china',
#   'which',
#   'he',
#   'named',
#   'senjin',
#   'daiko',
#   '線陣太鼓',
#   'front',
#   'drum',
#   'the',
#   'emperor',
#   'was',
#   'thought',
#   'to',
#   'have',
#   'used',
#   'it',
#   'to',
#   'both',
#   'encourage',
#   'his',
#   'own',
#   'army',
#   'and',
#   'intimidate',
#   'his',
#   'enemies'],
#  ['2012', 'la', 'música', 'no', 'se', 'toca'],
#  ['for',
#   'several',
#   'weeks',
#   'afterward',
#   'wilson',
#   'was',
#   'absent',
#   'from',
#   'television',
#   'due',
#   'to',
#   'personal',
#   'issues',
#   'she',
#   'had',
#   'to',
#   'attend',
#   'to',
#   'off',
#   'screen',
#   'on',
#   'november',
#   '28',
#   'wilson',
#   'returned',
#   'to',
#   'the',
#   'group',
#   'to',
#   'participate',
#   'in',
#   'a',
#   'six',
#   'woman',
#   'tag',
#   'team',
#   'match',
#   'wilson',
#   's',
#   'dog',
#   'chloe',
#   'became',
#   'an',
#   'official',
#   'member',
#   'of',
#   'the',
#   'group',
#   'on',
#   'december',
#   '26',
#   'when',
#   'she',
#   'interfered',
#   'in',
#   'one',
#   'of',
#   'victoria',
#   's',
#   'matches',
#   'and',
#   'became',
#   'the',
#   'first',
#   'dog',
#   'to',
#   'have',
#   'her',
#   'own',
#   'wwe',
#   'com',
#   'profile',
#   'at',
#   'taboo',
#   'tuesday',
#   'in',
#   'november',
#   'candice',
#   'michelle',
#   'was',
#   'eliminated',
#   'from',
#   'the',
#   'fulfill',
#   'your',
#   'fantasy',
#   'battle',
#   'royal',
#   'for',
#   'the',
#   'wwe',
#   'women',
#   's',
#   'championship',
#   'by',
#   'former',
#   'rival',
#   'ashley',
#   'massaro'],
#  ['chart', 'performance'],
#  ['notable', 'people'],
#  ['as',
#   'of',
#   '2014',
#   'travelers',
#   'had',
#   'to',
#   'use',
#   'either',
#   'us',
#   '31',
#   'through',
#   'grand',
#   'haven',
#   'or',
#   '68th',
#   'avenue',
#   'through',
#   'eastmanville',
#   'to',
#   'cross',
#   'the',
#   'grand',
#   'river',
#   'in',
#   'ottawa',
#   'county',
#   'a',
#   'new',
#   'highway',
#   'part',
#   'of',
#   'a',
#   'long',
#   'range',
#   'plan',
#   'to',
#   'build',
#   'a',
#   'us',
#   '31',
#   'bypass',
#   'of',
#   'grand',
#   'haven',
#   'provides',
#   'a',
#   'river',
#   'crossing',
#   'almost',
#   'equidistant',
#   'between',
#   'the',
#   'two',
#   'greatly',
#   'reducing',
#   'drive',
#   'times',
#   'between',
#   'areas',
#   'north',
#   'and',
#   'south',
#   'of',
#   'the',
#   'river',
#   'a',
#   'drive',
#   'from',
#   'nunica',
#   'to',
#   'robinson',
#   'is',
#   'a',
#   '20',
#   'mile',
#   '32',
#   'km',
#   'trip',
#   'the',
#   'new',
#   'highway',
#   'provides',
#   'a',
#   'route',
#   'closer',
#   'to',
#   'seven',
#   'miles',
#   '11',
#   'km',
#   'in',
#   'length',
#   'called',
#   'm',
#   '231',
#   'this',
#   'highway',
#   'is',
#   'a',
#   'scaled',
#   'down',
#   'bypass',
#   'of',
#   'us',
#   '31',
#   'through',
#   'grand',
#   'haven',
#   'even',
#   'though',
#   'it',
#   'will',
#   'not',
#   'physically',
#   'connect',
#   'to',
#   'us',
#   '31',
#   'by',
#   'january',
#   '4',
#   '2013',
#   'mdot',
#   'had',
#   'completed',
#   'work',
#   'for',
#   'this',
#   'highway',
#   'including',
#   'a',
#   'bridge',
#   'over',
#   'north',
#   'cedar',
#   'drive',
#   'additional',
#   'ramps',
#   'at',
#   'the',
#   'i',
#   '96',
#   'and',
#   'm',
#   '104',
#   'interchange',
#   'and',
#   'reconstruction',
#   'and',
#   'widening',
#   'of',
#   'm',
#   '104',
#   'near',
#   'i',
#   '96',
#   'the',
#   'department',
#   'had',
#   'also',
#   'completed',
#   'a',
#   'reconfiguration',
#   'of',
#   'the',
#   'intersection',
#   'between',
#   'm',
#   '104',
#   'and',
#   'cleveland',
#   'drive',
#   'and',
#   'widening',
#   'the',
#   'bridge',
#   'that',
#   'carries',
#   'm',
#   '104',
#   'over',
#   'i',
#   '96',
#   'the',
#   'expected',
#   'date',
#   'of',
#   'completion',
#   'for',
#   'm',
#   '231',
#   'was',
#   'set',
#   'for',
#   'sometime',
#   'in',
#   '2016',
#   'pending',
#   'funding',
#   'availability',
#   'mdot',
#   'planned',
#   'to',
#   'build',
#   '1',
#   '4',
#   'miles',
#   '2',
#   '3',
#   'km',
#   'of',
#   'the',
#   'new',
#   'highway',
#   'starting',
#   'in',
#   '2013',
#   'including',
#   'the',
#   'bridges',
#   'over',
#   'the',
#   'grand',
#   'river',
#   'and',
#   'little',
#   'robinson',
#   'creek',
#   'the',
#   '2005',
#   'safetea',
#   'lu',
#   'transportation',
#   'bill',
#   'provided',
#   'funding',
#   'earmarked',
#   'for',
#   'the',
#   'project',
#   'by',
#   'us',
#   'representative',
#   'pete',
#   'hoekstra',
#   'from',
#   'holland',
#   'as',
#   'well',
#   'as',
#   'matching',
#   'funds',
#   'from',
#   'the',
#   'state',
#   's',
#   'michigan',
#   'jobs',
#   'today',
#   'program',
#   'the',
#   'total',
#   'cost',
#   'of',
#   'the',
#   'project',
#   'was',
#   'expected',
#   'to',
#   'be',
#   'near',
#   '150',
#   'million',
#   'on',
#   'october',
#   '30',
#   '2015',
#   'the',
#   'highway',
#   'opened',
#   'to',
#   'traffic'],
#  [],
#  ['maybe', 'angelo', 'brovelli', 'would', 'do'],
#  [],
#  ['caenorhabditis',
#   'elegans',
#   'ˌseɪnoʊræbˈdaɪtəs',
#   'ˈɛləɡænz',
#   'is',
#   'a',
#   'free',
#   'living',
#   'not',
#   'parasitic',
#   'transparent',
#   'nematode',
#   'roundworm',
#   'about',
#   '1',
#   'mm',
#   'in',
#   'length',
#   'that',
#   'lives',
#   'in',
#   'temperate',
#   'soil',
#   'environments',
#   'the',
#   'name',
#   'is',
#   'a',
#   'blend',
#   'of',
#   'the',
#   'greek',
#   'caeno',
#   'recent',
#   'rhabditis',
#   'rod',
#   'like',
#   'and',
#   'latin',
#   'elegans',
#   'elegant',
#   'in',
#   '1900',
#   'maupas',
#   'initially',
#   'named',
#   'it',
#   'rhabditides',
#   'elegans',
#   'osche',
#   'placed',
#   'it',
#   'in',
#   'the',
#   'subgenus',
#   'caenorhabditis',
#   'in',
#   '1952',
#   'and',
#   'in',
#   '1955',
#   'dougherty',
#   'raised',
#   'it',
#   'to',
#   'the',
#   'status',
#   'of',
#   'genus'],
#  ['to',
#   'provide',
#   'forward',
#   'protection',
#   'for',
#   'the',
#   'railway',
#   'construction',
#   'workers',
#   'and',
#   'the',
#   'infrastructure',
#   'the',
#   '5th',
#   'mounted',
#   'brigade',
#   'was',
#   'ordered',
#   'to',
#   'move',
#   'to',
#   'katia',
#   'by',
#   'early',
#   'april',
#   'however',
#   'signs',
#   'of',
#   'renewed',
#   'ottoman',
#   'activity',
#   'in',
#   'the',
#   'area',
#   'were',
#   'detected',
#   'and',
#   'as',
#   'a',
#   'result',
#   'the',
#   '5th',
#   'light',
#   'horse',
#   'regiment',
#   'was',
#   'ordered',
#   'to',
#   'reinforce',
#   'the',
#   '5th',
#   'mounted',
#   'brigade',
#   'it',
#   'was',
#   'due',
#   'to',
#   'arrive',
#   'at',
#   'katia',
#   'on',
#   '24',
#   'april'],
#  ['goodbye',
#   'michael',
#   'features',
#   'several',
#   'references',
#   'to',
#   'previous',
#   'episodes',
#   'during',
#   'one',
#   'scene',
#   'michael',
#   'puts',
#   'his',
#   'dundie',
#   'on',
#   'his',
#   'desk',
#   'a',
#   'homage',
#   'to',
#   'the',
#   'final',
#   'shot',
#   'in',
#   'the',
#   'series',
#   'opening',
#   'sequence',
#   'michael',
#   's',
#   'obsession',
#   'with',
#   'basketball',
#   'and',
#   'wanting',
#   'to',
#   'use',
#   'the',
#   'baler',
#   'serves',
#   'as',
#   'a',
#   'reference',
#   'to',
#   'the',
#   'season',
#   'one',
#   'episode',
#   'basketball',
#   'and',
#   'the',
#   'season',
#   'three',
#   'episode',
#   'safety',
#   'training',
#   'respectively',
#   'michael',
#   's',
#   'character',
#   'ping',
#   'appears',
#   'having',
#   'previously',
#   'appeared',
#   'in',
#   'the',
#   'dundies',
#   'and',
#   'the',
#   'seminar',
#   'it',
#   'also',
#   'featured',
#   'the',
#   'reforming',
#   'of',
#   'the',
#   'party',
#   'planning',
#   'committee',
#   'after',
#   'being',
#   'broken',
#   'up',
#   'in',
#   'moroccan',
#   'christmas',
#   'and',
#   'briefly',
#   'showed',
#   'creed',
#   's',
#   'continual',
#   'habit',
#   'of',
#   'using',
#   'the',
#   'women',
#   's',
#   'bathroom',
#   'as',
#   'seen',
#   'in',
#   'women',
#   's',
#   'appreciation',
#   'michael',
#   'gives',
#   'darryl',
#   'his',
#   'book',
#   'somehow',
#   'i',
#   'manage',
#   'which',
#   'was',
#   'originally',
#   'mentioned',
#   'in',
#   'happy',
#   'hour',
#   'two',
#   'callbacks',
#   'are',
#   'made',
#   'to',
#   'the',
#   'episode',
#   'christmas',
#   'party',
#   'phyllis',
#   'gift',
#   'to',
#   'michael',
#   'being',
#   'homemade',
#   'sewn',
#   'mittens',
#   'and',
#   'dwight',
#   'wanting',
#   'to',
#   'play',
#   'paintball',
#   'with',
#   'michael',
#   'michael',
#   's',
#   'goodbye',
#   'to',
#   'pam',
#   'serves',
#   'as',
#   'a',
#   'homage',
#   'to',
#   'a',
#   'scene',
#   'in',
#   'the',
#   'british',
#   'version',
#   'of',
#   'the',
#   'office',
#   'where',
#   'tim',
#   'canterbury',
#   'proclaims',
#   'his',
#   'love',
#   'for',
#   'dawn',
#   'tinsley',
#   'in',
#   'a',
#   'meeting',
#   'room',
#   'but',
#   'tim',
#   'turns',
#   'off',
#   'his',
#   'microphone',
#   'first',
#   'so',
#   'the',
#   'cameras',
#   'pick',
#   'up',
#   'only',
#   'their',
#   'reactions',
#   'and',
#   'no',
#   'sound',
#   'this',
#   'scene',
#   'was',
#   'also',
#   'referenced',
#   'in',
#   'the',
#   'fifth',
#   'season',
#   'finale',
#   'company',
#   'picnic'],
#  [],
#  [],
#  [],
#  [],
#  ['rebirth',
#   'was',
#   'officially',
#   'announced',
#   'in',
#   'april',
#   '2004',
#   'a',
#   'week',
#   'after',
#   'the',
#   'game',
#   's',
#   'title',
#   'and',
#   'existence',
#   'had',
#   'been',
#   'leaked',
#   'to',
#   'the',
#   'public',
#   'early',
#   'after',
#   'a',
#   'story',
#   'from',
#   'jump',
#   'magazine',
#   'was',
#   'made',
#   'available',
#   'a',
#   'week',
#   'early',
#   'due',
#   'to',
#   'being',
#   'mistakenly',
#   'being',
#   'shipped',
#   'early',
#   'in',
#   'july',
#   'namco',
#   'announced',
#   'that',
#   'people',
#   'who',
#   'pre',
#   'ordered',
#   'tales',
#   'of',
#   'symphonia',
#   'for',
#   'the',
#   'playstation',
#   '2',
#   'would',
#   'receive',
#   'a',
#   'bonus',
#   'disc',
#   'featuring',
#   'footage',
#   'from',
#   'an',
#   'early',
#   'build',
#   'of',
#   'tales',
#   'of',
#   'rebirth',
#   'upon',
#   'purchasing',
#   'symphonia',
#   'in',
#   'september',
#   'the',
#   'same',
#   'footage',
#   'along',
#   'with',
#   'a',
#   'playable',
#   'build',
#   'of',
#   'the',
#   'game',
#   'was',
#   'present',
#   'at',
#   'the',
#   'tokyo',
#   'game',
#   'show',
#   'in',
#   'the',
#   'same',
#   'month',
#   'the',
#   'game',
#   'was',
#   'released',
#   'on',
#   'the',
#   'playstation',
#   '2',
#   'on',
#   'december',
#   '16',
#   '2004',
#   'in',
#   'july',
#   '2004',
#   'ign',
#   'reported',
#   'that',
#   'tales',
#   'of',
#   'rebirth',
#   'was',
#   'a',
#   'likely',
#   'candidate',
#   'for',
#   'an',
#   'english',
#   'localization',
#   'in',
#   'north',
#   'america',
#   'due',
#   'to',
#   'the',
#   'high',
#   'reception',
#   'and',
#   'sales',
#   'of',
#   'tales',
#   'of',
#   'symphonia',
#   'in',
#   'north',
#   'america',
#   'for',
#   'the',
#   'nintendo',
#   'gamecube',
#   'the',
#   'playstation',
#   'portable',
#   'port',
#   'of',
#   'the',
#   'game',
#   'which',
#   'featured',
#   'graphical',
#   'adjustments',
#   'for',
#   'the',
#   'platform',
#   's',
#   'widescreen',
#   'was',
#   'announced',
#   'in',
#   'july',
#   '2007',
#   'the',
#   'port',
#   'was',
#   'made',
#   'following',
#   'the',
#   'port',
#   'of',
#   'destiny',
#   '2',
#   'as',
#   'with',
#   'those',
#   'games',
#   'transplanting',
#   'the',
#   '2d',
#   'graphics',
#   'onto',
#   'the',
#   'psp',
#   'and',
#   'maintaining',
#   'the',
#   'experience',
#   'of',
#   'the',
#   'original',
#   'caused',
#   'some',
#   'difficulties',
#   'conversely',
#   'they',
#   'found',
#   'the',
#   'memory',
#   'capacity',
#   'of',
#   'the',
#   'psp',
#   'compared',
#   'to',
#   'the',
#   'ps2',
#   'a',
#   'good',
#   'thing',
#   'yoshizumi',
#   'felt',
#   'that',
#   'the',
#   'fact',
#   'that',
#   'it',
#   'was',
#   'a',
#   'port',
#   'rather',
#   'than',
#   'a',
#   'remake',
#   'divided',
#   'the',
#   'development',
#   'team',
#   'the',
#   'port',
#   'also',
#   'included',
#   'extra',
#   'minor',
#   'story',
#   'scenes',
#   'and',
#   'a',
#   'viewing',
#   'gallery',
#   'for',
#   'concept',
#   'art',
#   'neither',
#   'the',
#   'original',
#   'nor',
#   'the',
#   'port',
#   'of',
#   'rebirth',
#   'have',
#   'received',
#   'an',
#   'english',
#   'localization',
#   'making',
#   'it',
#   'one',
#   'of',
#   'three',
#   'mainline',
#   'tales',
#   'titles',
#   'not',
#   'have',
#   'come',
#   'to',
#   'the',
#   'west'],
#  ['the',
#   'chronicles',
#   'of',
#   'riddick',
#   'escape',
#   'from',
#   'butcher',
#   'bay',
#   'is',
#   'a',
#   'first',
#   'person',
#   'action',
#   'and',
#   'stealth',
#   'video',
#   'game',
#   'developed',
#   'by',
#   'starbreeze',
#   'studios',
#   'and',
#   'published',
#   'by',
#   'vivendi',
#   'games',
#   'released',
#   'for',
#   'the',
#   'xbox',
#   'and',
#   'windows',
#   'in',
#   '2004',
#   'the',
#   'game',
#   'is',
#   'a',
#   'tie',
#   'in',
#   'prequel',
#   'to',
#   'the',
#   'futuristic',
#   'science',
#   'fiction',
#   'film',
#   'the',
#   'chronicles',
#   'of',
#   'riddick',
#   'actor',
#   'vin',
#   'diesel',
#   'who',
#   'was',
#   'involved',
#   'in',
#   'the',
#   'game',
#   's',
#   'development',
#   'reprises',
#   'his',
#   'role',
#   'as',
#   'that',
#   'film',
#   's',
#   'protagonist',
#   'richard',
#   'b',
#   'riddick'],
#  ['additionally',
#   'julee',
#   'cruise',
#   'who',
#   'recorded',
#   'the',
#   'theme',
#   'for',
#   'twin',
#   'peaks',
#   'recorded',
#   'a',
#   'slower',
#   'extended',
#   'version',
#   'of',
#   'the',
#   'psych',
#   'theme',
#   'song',
#   'i',
#   'know',
#   'you',
#   'know',
#   'by',
#   'series',
#   'creator',
#   'steve',
#   'franks',
#   's',
#   'band',
#   'the',
#   'friendly',
#   'indians',
#   'the',
#   'imagery',
#   'that',
#   'accompanies',
#   'it',
#   'is',
#   'an',
#   'almost',
#   'shot',
#   'for',
#   'shot',
#   'recreation',
#   'of',
#   'the',
#   'twin',
#   'peaks',
#   'opening',
#   'sequence',
#   'with',
#   'a',
#   'white',
#   'horse',
#   'that',
#   'resembles',
#   'the',
#   'one',
#   'in',
#   'sarah',
#   'palmer',
#   's',
#   'vision',
#   'before',
#   'the',
#   'attack',
#   'on',
#   'maddy',
#   'ferguson',
#   'later',
#   'during',
#   'a',
#   'bicycle',
#   'chase',
#   'scene',
#   'baby',
#   'did',
#   'a',
#   'bad',
#   'bad',
#   'thing',
#   'by',
#   'chris',
#   'isaak',
#   'is',
#   'heard',
#   'isaak',
#   'portrayed',
#   'special',
#   'agent',
#   'chester',
#   'desmond',
#   'in',
#   'twin',
#   'peaks',
#   'fire',
#   'walk',
#   'with',
#   'me'],
#  ['1884', 'navy', 'midshipmen', 'football', 'team'],
#  ['felipe',
#   'massa',
#   'failed',
#   'to',
#   'set',
#   'a',
#   'lap',
#   'time',
#   'after',
#   'stopping',
#   'on',
#   'the',
#   'circuit',
#   'in',
#   'the',
#   'first',
#   'part',
#   'of',
#   'the',
#   'qualifying',
#   'session'],
#  ['the',
#   'first',
#   'world',
#   'war',
#   'had',
#   'a',
#   'severe',
#   'effect',
#   'on',
#   'stanford',
#   'he',
#   'was',
#   'frightened',
#   'by',
#   'air',
#   'raids',
#   'and',
#   'had',
#   'to',
#   'move',
#   'from',
#   'london',
#   'to',
#   'windsor',
#   'to',
#   'avoid',
#   'them',
#   'many',
#   'of',
#   'his',
#   'former',
#   'pupils',
#   'were',
#   'casualties',
#   'of',
#   'the',
#   'fighting',
#   'including',
#   'arthur',
#   'bliss',
#   'injured',
#   'ivor',
#   'gurney',
#   'gassed',
#   'and',
#   'george',
#   'butterworth',
#   'killed',
#   'the',
#   'annual',
#   'rcm',
#   'operatic',
#   'production',
#   'which',
#   'stanford',
#   'had',
#   'supervised',
#   'and',
#   'conducted',
#   'every',
#   'year',
#   'since',
#   '1885',
#   'had',
#   'to',
#   'be',
#   'cancelled',
#   'his',
#   'income',
#   'declined',
#   'as',
#   'the',
#   'fall',
#   'in',
#   'student',
#   'numbers',
#   'at',
#   'the',
#   'college',
#   'reduced',
#   'the',
#   'demand',
#   'for',
#   'his',
#   'services',
#   'after',
#   'a',
#   'serious',
#   'disagreement',
#   'at',
#   'the',
#   'end',
#   'of',
#   '1916',
#   'his',
#   'relationship',
#   'with',
#   'parry',
#   'deteriorated',
#   'to',
#   'the',
#   'point',
#   'of',
#   'hostility',
#   'stanford',
#   's',
#   'magnanimity',
#   'however',
#   'came',
#   'to',
#   'the',
#   'fore',
#   'when',
#   'parry',
#   'died',
#   'two',
#   'years',
#   'later',
#   'and',
#   'stanford',
#   'successfully',
#   'lobbied',
#   'for',
#   'him',
#   'to',
#   'be',
#   'buried',
#   'in',
#   'st',
#   'paul',
#   's',
#   'cathedral'],
#  ['the',
#   'pier',
#   'projects',
#   'from',
#   'the',
#   'seafront',
#   'at',
#   'clevedon',
#   'into',
#   'the',
#   'severn',
#   'estuary',
#   'which',
#   'separates',
#   'south',
#   'west',
#   'england',
#   'from',
#   'south',
#   'wales',
#   'the',
#   'pier',
#   'and',
#   'toll',
#   'house',
#   'where',
#   'entry',
#   'fees',
#   'are',
#   'collected',
#   'are',
#   'adjacent',
#   'to',
#   'the',
#   'royal',
#   'pier',
#   'hotel',
#   'originally',
#   'known',
#   'as',
#   'the',
#   'rock',
#   'house',
#   'and',
#   'built',
#   'in',
#   '1823',
#   'by',
#   'thomas',
#   'hollyman'],
#  ['in',
#   '2016',
#   'it',
#   'was',
#   'announced',
#   'that',
#   'garfield',
#   'will',
#   'play',
#   'the',
#   'role',
#   'of',
#   'prior',
#   'walter',
#   'in',
#   'tony',
#   'kushner',
#   's',
#   'two',
#   'part',
#   'play',
#   'angels',
#   'in',
#   'america',
#   'at',
#   'the',
#   'national',
#   'theatre',
#   'london',
#   'in',
#   'the',
#   'lyttelton',
#   'theatre',
#   'from',
#   'april',
#   '2017',
#   'it',
#   'will',
#   'be',
#   'directed',
#   'by',
#   'marianne',
#   'elliott',
#   'and',
#   'co',
#   'starring',
#   'russell',
#   'tovey',
#   'and',
#   'denise',
#   'gough'],
#  [],
#  ['planned', 'release', 'as', 'a', 'physical', 'single'],
#  [],
#  ['from',
#   'quite',
#   'early',
#   'in',
#   'his',
#   'career',
#   'peter',
#   'was',
#   'renowned',
#   'for',
#   'his',
#   'learning',
#   'his',
#   'passion',
#   'for',
#   'reading',
#   'and',
#   'his',
#   'discussions',
#   'with',
#   'scholars',
#   'as',
#   'a',
#   'speaker',
#   'he',
#   'was',
#   'eloquent',
#   'and',
#   'persuasive',
#   'procopius',
#   'calls',
#   'him',
#   'fitted',
#   'by',
#   'nature',
#   'to',
#   'persuade',
#   'men',
#   'while',
#   'cassiodorus',
#   'who',
#   'witnessed',
#   'his',
#   'embassies',
#   'to',
#   'the',
#   'ostrogoth',
#   'court',
#   'also',
#   'praises',
#   'him',
#   'as',
#   'vir',
#   'eloquentissimus',
#   'and',
#   'disertissimus',
#   'most',
#   'eloquent',
#   'man',
#   'and',
#   'as',
#   'sapientissimus',
#   'most',
#   'wise',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'the',
#   'late',
#   '6th',
#   'century',
#   'historian',
#   'menander',
#   'protector',
#   'who',
#   'relied',
#   'on',
#   'peter',
#   's',
#   'work',
#   'for',
#   'his',
#   'own',
#   'history',
#   'accuses',
#   'him',
#   'of',
#   'boastfulness',
#   'and',
#   'of',
#   'rewriting',
#   'the',
#   'records',
#   'to',
#   'enhance',
#   'his',
#   'own',
#   'role',
#   'and',
#   'performance',
#   'in',
#   'the',
#   'negotiations',
#   'with',
#   'the',
#   'persians'],
#  [],
#  [],
#  ['the',
#   'first',
#   'modern',
#   'chess',
#   'tournament',
#   'was',
#   'organized',
#   'by',
#   'howard',
#   'staunton',
#   'a',
#   'leading',
#   'english',
#   'chess',
#   'player',
#   'and',
#   'was',
#   'held',
#   'in',
#   'london',
#   'in',
#   '1851',
#   'it',
#   'was',
#   'won',
#   'by',
#   'the',
#   'german',
#   'adolf',
#   'anderssen',
#   'who',
#   'was',
#   'hailed',
#   'as',
#   'the',
#   'leading',
#   'chess',
#   'master',
#   'his',
#   'brilliant',
#   'energetic',
#   'attacking',
#   'style',
#   'was',
#   'typical',
#   'for',
#   'the',
#   'time',
#   'sparkling',
#   'games',
#   'like',
#   'anderssen',
#   's',
#   'immortal',
#   'game',
#   'and',
#   'evergreen',
#   'game',
#   'or',
#   'morphy',
#   's',
#   'opera',
#   'game',
#   'were',
#   'regarded',
#   'as',
#   'the',
#   'highest',
#   'possible',
#   'summit',
#   'of',
#   'the',
#   'chess',
#   'art'],
#  [],
#  ['in',
#   'twelfth',
#   'night',
#   '1600',
#   '1601',
#   'shakespeare',
#   'alluded',
#   'to',
#   'the',
#   'wright',
#   'molyneux',
#   'map',
#   'when',
#   'maria',
#   'says',
#   'of',
#   'malvolio',
#   'he',
#   'does',
#   'smile',
#   'his',
#   'face',
#   'into',
#   'more',
#   'lynes',
#   'than',
#   'is',
#   'in',
#   'the',
#   'new',
#   'mappe',
#   'with',
#   'the',
#   'augmentation',
#   'of',
#   'the',
#   'indies'],
#  ['jordan',
#   'is',
#   'divided',
#   'into',
#   'twelve',
#   'administrative',
#   'divisions',
#   'each',
#   'called',
#   'a',
#   'governorate',
#   'amman',
#   'governorate',
#   'divides',
#   'into',
#   'nine',
#   'nahias',
#   'five',
#   'of',
#   'which',
#   'are',
#   'divided',
#   'into',
#   'districts',
#   'and',
#   'are',
#   'further',
#   'divided',
#   'into',
#   'neighborhoods',
#   'the',
#   'other',
#   'four',
#   'nahias',
#   'lying',
#   'in',
#   'the',
#   'suburbs',
#   'are',
#   'either',
#   'divided',
#   'into',
#   'villages',
#   'or',
#   'towns'],
#  ['the',
#   'luxury',
#   'of',
#   'the',
#   'southern',
#   'seas',
#   'was',
#   'a',
#   'far',
#   'cry',
#   'from',
#   'the',
#   'cramped',
#   'quarters',
#   'of',
#   'the',
#   'old',
#   'xpbs',
#   'and',
#   'i',
#   'remained',
#   'aboard',
#   'over',
#   'night',
#   'reveling',
#   'in',
#   'comforts',
#   'previously',
#   'enjoyed',
#   'by',
#   'pan',
#   'am',
#   's',
#   'customers',
#   'but',
#   'the',
#   'yacht',
#   'was',
#   'of',
#   'no',
#   'further',
#   'use',
#   'to',
#   'pan',
#   'am',
#   'their',
#   'service',
#   'to',
#   'new',
#   'zealand',
#   'had',
#   'been',
#   'discontinued',
#   'the',
#   'yacht',
#   'was',
#   'to',
#   'be',
#   'turned',
#   'over',
#   'to',
#   'sverdrup',
#   'to',
#   'serve',
#   'him',
#   'as',
#   'a',
#   'floating',
#   'office',
#   'which',
#   'could',
#   'follow',
#   'him',
#   'around',
#   'among',
#   'the',
#   'islands'],
#  ['the',
#   'species',
#   'was',
#   'first',
#   'named',
#   'toxostoma',
#   'curvirostre',
#   'by',
#   'william',
#   'john',
#   'swainson',
#   'in',
#   '1827',
#   'since',
#   'then',
#   'six',
#   'subspecies',
#   'have',
#   'been',
#   'recognized',
#   'and',
#   'have',
#   'been',
#   'divided',
#   'into',
#   'two',
#   'branches',
#   'genetic',
#   'research',
#   'has',
#   'indicated',
#   'that',
#   'the',
#   'curve',
#   'billed',
#   'thrasher',
#   'is',
#   'the',
#   'sister',
#   'species',
#   'of',
#   'a',
#   'clade',
#   'consisting',
#   'of',
#   'the',
#   'ocellated',
#   'thrasher',
#   'brown',
#   'thrasher',
#   'long',
#   'billed',
#   'thrasher',
#   'and',
#   'cozumel',
#   'thrasher',
#   'this',
#   'contrasts',
#   'with',
#   'an',
#   'earlier',
#   'suggestion',
#   'that',
#   'curve',
#   'billed',
#   'and',
#   'ocellated',
#   'thrashers',
#   'are',
#   'closest',
#   'relatives'],
#  ['criticism', 'and', 'influence'],
#  ['the',
#   'united',
#   'kingdom',
#   's',
#   'four',
#   'surviving',
#   'king',
#   'george',
#   'v',
#   'class',
#   'ships',
#   'were',
#   'scrapped',
#   'in',
#   '1957',
#   'and',
#   'vanguard',
#   'followed',
#   'in',
#   '1960',
#   'all',
#   'other',
#   'surviving',
#   'british',
#   'battleships',
#   'had',
#   'been',
#   'sold',
#   'or',
#   'broken',
#   'up',
#   'by',
#   '1949',
#   'the',
#   'soviet',
#   'union',
#   's',
#   'marat',
#   'was',
#   'scrapped',
#   'in',
#   '1953',
#   'parizhskaya',
#   'kommuna',
#   'in',
#   '1957',
#   'and',
#   'oktyabrskaya',
#   'revolutsiya',
#   'back',
#   'under',
#   'her',
#   'original',
#   'name',
#   'gangut',
#   'since',
#   '1942',
#   'in',
#   '1956',
#   '7',
#   'brazil',
#   's',
#   'minas',
#   'geraes',
#   'was',
#   'scrapped',
#   'in',
#   'genoa',
#   'in',
#   '1953',
#   'and',
#   'her',
#   'sister',
#   'ship',
#   'são',
#   'paulo',
#   'sank',
#   'during',
#   'a',
#   'storm',
#   'in',
#   'the',
#   'atlantic',
#   'en',
#   'route',
#   'to',
#   'the',
#   'breakers',
#   'in',
#   'italy',
#   'in',
#   '1951'],
#  [],
#  ['in',
#   '1960',
#   'pacific',
#   'gas',
#   'and',
#   'electric',
#   'began',
#   'operation',
#   'of',
#   'the',
#   'first',
#   'successful',
#   'geothermal',
#   'electric',
#   'power',
#   'plant',
#   'in',
#   'the',
#   'united',
#   'states',
#   'at',
#   'the',
#   'geysers',
#   'in',
#   'california',
#   'the',
#   'original',
#   'turbine',
#   'lasted',
#   'for',
#   'more',
#   'than',
#   '30',
#   'years',
#   'and',
#   'produced',
#   '11',
#   'mw',
#   'net',
#   'power'],
#  ['r',
#   'bancoult',
#   'v',
#   'secretary',
#   'of',
#   'state',
#   'for',
#   'foreign',
#   'and',
#   'commonwealth',
#   'affairs',
#   '2000',
#   'was',
#   'a',
#   'case',
#   'concerning',
#   'the',
#   'forcible',
#   'removal',
#   'of',
#   'the',
#   'indigenous',
#   'people',
#   'of',
#   'the',
#   'chagos',
#   'archipelago',
#   'from',
#   'diego',
#   'garcia',
#   'and',
#   'the',
#   'prohibition',
#   'of',
#   'their',
#   'return',
#   'by',
#   'the',
#   'government',
#   'of',
#   'the',
#   'united',
#   'kingdom',
#   'so',
#   'that',
#   'the',
#   'united',
#   'states',
#   'could',
#   'construct',
#   'a',
#   'large',
#   'military',
#   'base',
#   'there',
#   'this',
#   'was',
#   'effected',
#   'by',
#   'section',
#   '4',
#   'of',
#   'the',
#   'immigration',
#   'ordinance',
#   '1971',
#   'of',
#   'the',
#   'british',
#   'indian',
#   'ocean',
#   'territory',
#   'enacted',
#   'pursuant',
#   'to',
#   'section',
#   '11',
#   '1',
#   'of',
#   'the',
#   'british',
#   'indian',
#   'ocean',
#   'territory',
#   'order',
#   'which',
#   'states',
#   'the',
#   'commissioner',
#   'for',
#   'the',
#   'british',
#   'indian',
#   'ocean',
#   'territory',
#   'may',
#   'make',
#   'laws',
#   'for',
#   'the',
#   'peace',
#   'order',
#   'and',
#   'good',
#   'government',
#   'of',
#   'the',
#   'territory',
#   'and',
#   'such',
#   'laws',
#   'shall',
#   'be',
#   'published',
#   'in',
#   'such',
#   'manner',
#   'as',
#   'the',
#   'commissioner',
#   'may',
#   'direct',
#   'the',
#   'high',
#   'court',
#   'held',
#   'that',
#   'the',
#   '1971',
#   'ordinance',
#   'was',
#   'ultra',
#   'vires',
#   'the',
#   'order',
#   'since',
#   'removing',
#   'a',
#   'people',
#   'from',
#   'their',
#   'homeland',
#   'could',
#   'not',
#   'be',
#   'regarded',
#   'as',
#   'within',
#   'the',
#   'power',
#   'to',
#   'make',
#   'laws',
#   'for',
#   'the',
#   'territory',
#   's',
#   'peace',
#   'order',
#   'and',
#   'good',
#   'government',
#   'subsequently',
#   'the',
#   'exclusion',
#   'of',
#   'the',
#   'chagossians',
#   'from',
#   'the',
#   'land',
#   'was',
#   'reimposed',
#   'by',
#   'an',
#   'order',
#   'in',
#   'council',
#   'the',
#   'british',
#   'indian',
#   'ocean',
#   'territory',
#   'constitution',
#   'order',
#   '2004',
#   'which',
#   'was',
#   'made',
#   'in',
#   'the',
#   'exercise',
#   'of',
#   'the',
#   'royal',
#   'prerogative',
#   'the',
#   'legality',
#   'of',
#   'this',
#   'order',
#   'was',
#   'upheld',
#   'by',
#   'the',
#   'house',
#   'of',
#   'lords',
#   'in',
#   'r',
#   'bancoult',
#   'v',
#   'secretary',
#   'of',
#   'state',
#   'for',
#   'foreign',
#   'and',
#   'commonwealth',
#   'affairs',
#   'no',
#   '2',
#   '2008',
#   'which',
#   'overruled',
#   'the',
#   'earlier',
#   'decision',
#   'the',
#   'house',
#   'of',
#   'lords',
#   'took',
#   'the',
#   'view',
#   'that',
#   'the',
#   'phrase',
#   'peace',
#   'order',
#   'and',
#   'good',
#   'government',
#   'did',
#   'not',
#   'entitle',
#   'the',
#   'courts',
#   'to',
#   'substitute',
#   'their',
#   'own',
#   'view',
#   'on',
#   'what',
#   'the',
#   'phrase',
#   'required',
#   'for',
#   'that',
#   'of',
#   'the',
#   'government',
#   'laws',
#   'made',
#   'pursuant',
#   'to',
#   'it',
#   'were',
#   'therefore',
#   'not',
#   'justiciable'],
#  [],
#  ['the',
#   'saga',
#   'relates',
#   'that',
#   'haakon',
#   'throws',
#   'himself',
#   'to',
#   'the',
#   'ground',
#   'before',
#   'the',
#   'woman',
#   'for',
#   'some',
#   'time',
#   'when',
#   'he',
#   'gets',
#   'up',
#   'he',
#   'tells',
#   'sigmund',
#   'that',
#   'they',
#   'should',
#   'give',
#   'her',
#   'an',
#   'offering',
#   'that',
#   'they',
#   'ought',
#   'to',
#   'lay',
#   'silver',
#   'on',
#   'the',
#   'stool',
#   'before',
#   'her',
#   'haakon',
#   'says'],
#  ['preparations'],
#  [],
#  ['the',
#   'bandshell',
#   'hosted',
#   'symbolic',
#   'events',
#   'at',
#   'the',
#   'time',
#   'of',
#   'world',
#   'war',
#   'ii',
#   'the',
#   'july',
#   '1942',
#   'celebration',
#   'of',
#   'the',
#   'city',
#   's',
#   '10',
#   '000th',
#   'united',
#   'states',
#   'navy',
#   'recruit',
#   'with',
#   'a',
#   '500',
#   'sailor',
#   'representation',
#   'from',
#   'navy',
#   'pier',
#   'to',
#   'salute',
#   'the',
#   'color',
#   'guard',
#   'was',
#   'held',
#   'at',
#   'the',
#   'band',
#   'shell',
#   'in',
#   '1944',
#   'a',
#   'public',
#   'address',
#   'system',
#   'was',
#   'added',
#   'and',
#   'following',
#   'the',
#   'war',
#   'grant',
#   'park',
#   'usage',
#   'increased',
#   'heavily'],
#  [],
#  ['ibagnez',
#   'bernardo',
#   '1774',
#   'jesuitisches',
#   'reich',
#   'in',
#   'paraguay',
#   'durch',
#   'originaldocumente',
#   'der',
#   'gesellschaft',
#   'jesu',
#   'bewiesen',
#   'von',
#   'dem',
#   'aus',
#   'dem',
#   'jesuiterorden',
#   'verstoßenen',
#   'pater',
#   'ibagnez',
#   'in',
#   'german',
#   'cölln',
#   'peter',
#   'marteau'],
#  ['slavery',
#   'was',
#   'a',
#   'very',
#   'common',
#   'practice',
#   'in',
#   'ancient',
#   'greek',
#   'history',
#   'as',
#   'in',
#   'other',
#   'places',
#   'of',
#   'the',
#   'time',
#   'it',
#   'is',
#   'estimated',
#   'that',
#   'the',
#   'majority',
#   'of',
#   'athenian',
#   'citizens',
#   'owned',
#   'at',
#   'least',
#   'one',
#   'slave',
#   'most',
#   'ancient',
#   'writers',
#   'considered',
#   'slavery',
#   'natural',
#   'and',
#   'even',
#   'necessary',
#   'this',
#   'paradigm',
#   'was',
#   'notably',
#   'questioned',
#   'in',
#   'socratic',
#   'dialogues',
#   'the',
#   'stoics',
#   'produced',
#   'the',
#   'first',
#   'recorded',
#   'condemnation',
#   'of',
#   'slavery'],
#  ['on',
#   'november',
#   '25',
#   '2008',
#   'wone',
#   's',
#   'widow',
#   'katherine',
#   'filed',
#   'a',
#   'wrongful',
#   'death',
#   'lawsuit',
#   'against',
#   'the',
#   'three',
#   'men',
#   'largely',
#   'based',
#   'on',
#   'the',
#   'police',
#   'affidavit',
#   'the',
#   'lawsuit',
#   'alleged',
#   'defendants',
#   'negligent',
#   'failure',
#   'to',
#   'rescue',
#   'robert',
#   'wone',
#   'after',
#   'he',
#   'was',
#   'injured',
#   'defendants',
#   'destruction',
#   'of',
#   'evidence',
#   'of',
#   'robert',
#   'wone',
#   's',
#   'murder',
#   'and',
#   'defendants',
#   'conspiracy',
#   'to',
#   'destroy',
#   'evidence',
#   'and',
#   'obstruct',
#   'the',
#   'police',
#   'investigation',
#   'into',
#   'robert',
#   'wone',
#   's',
#   'murder',
#   'the',
#   'suit',
#   'was',
#   'settled',
#   'august',
#   '3',
#   '2011',
#   'for',
#   'an',
#   'undisclosed',
#   'sum',
#   'and',
#   'agreement',
#   'prior',
#   'to',
#   'his',
#   'nomination',
#   'as',
#   'united',
#   'states',
#   'attorney',
#   'general',
#   'eric',
#   'holder',
#   'advised',
#   'wone',
#   's',
#   'widow',
#   'on',
#   'a',
#   'pro',
#   'bono',
#   'basis'],
#  ['the',
#   'treaty',
#   'generously',
#   'restored',
#   'most',
#   'of',
#   'the',
#   'colonies',
#   'that',
#   'had',
#   'been',
#   'lost',
#   'to',
#   'the',
#   'british',
#   'since',
#   '1795',
#   'except',
#   'ceylon',
#   'but',
#   'including',
#   'the',
#   'cape',
#   'colony',
#   'this',
#   'now',
#   'made',
#   'the',
#   'attempts',
#   'in',
#   'the',
#   'asiatic',
#   'council',
#   'which',
#   'had',
#   'replaced',
#   'the',
#   'directorate',
#   'of',
#   'the',
#   'voc',
#   'in',
#   '1799',
#   'to',
#   'reform',
#   'the',
#   'management',
#   'of',
#   'the',
#   'colonies',
#   'more',
#   'urgent',
#   'dirk',
#   'van',
#   'hogendorp',
#   'was',
#   'commissioned',
#   'to',
#   'write',
#   'a',
#   'proposal',
#   'that',
#   'met',
#   'with',
#   'considerable',
#   'enthusiasm',
#   'from',
#   'the',
#   'more',
#   'progressive',
#   'elements',
#   'on',
#   'the',
#   'council',
#   'like',
#   'samuel',
#   'iperusz',
#   'wiselius',
#   'he',
#   'proposed',
#   'to',
#   'abolish',
#   'all',
#   'perquisites',
#   'and',
#   'sinecures',
#   'to',
#   'permit',
#   'private',
#   'trade',
#   'to',
#   'permit',
#   'native',
#   'subjects',
#   'to',
#   'own',
#   'private',
#   'property',
#   'to',
#   'substitute',
#   'the',
#   'land',
#   'levies',
#   'by',
#   'a',
#   'regulated',
#   'land',
#   'tax',
#   'and',
#   'the',
#   'abolition',
#   'of',
#   'all',
#   'seigneurial',
#   'rights',
#   'in',
#   'the',
#   'colonies',
#   'this',
#   'met',
#   'with',
#   'overwhelming',
#   'resistance',
#   'from',
#   'vested',
#   'interests',
#   'when',
#   'a',
#   'new',
#   'charter',
#   'for',
#   'the',
#   'colonies',
#   'was',
#   'promulgated',
#   'hogendorp',
#   's',
#   'proposals',
#   'had',
#   'been',
#   'whittled',
#   'down',
#   'to',
#   'insignificance',
#   'the',
#   'vestigial',
#   'democrats',
#   'on',
#   'the',
#   'council',
#   'were',
#   'now',
#   'purged',
#   'in',
#   'favor',
#   'of',
#   'orangist',
#   'reactionaries',
#   'like',
#   'hendrik',
#   'mollerus',
#   'and',
#   'hendrik',
#   'van',
#   'stralen',
#   'in',
#   'any',
#   'case',
#   'the',
#   'republic',
#   'did',
#   'not',
#   'enjoy',
#   'the',
#   'possession',
#   'of',
#   'its',
#   'colonies',
#   'for',
#   'long',
#   'after',
#   'the',
#   'resumption',
#   'of',
#   'hostilities',
#   'in',
#   '1803',
#   'the',
#   'returned',
#   'colonies',
#   'in',
#   'most',
#   'cases',
#   'were',
#   'soon',
#   'reoccupied',
#   'by',
#   'the',
#   'british',
#   'java',
#   'however',
#   'held',
#   'out',
#   'till',
#   '1811'],
#  ['siddharaj', 'in', 'the', 'rudra', 'mala', 'shivashankar', 'established'],
#  [],
#  ['ground',
#   'for',
#   'three',
#   'rivers',
#   'stadium',
#   'was',
#   'broken',
#   'on',
#   'april',
#   '25',
#   '1968',
#   'due',
#   'to',
#   'the',
#   'steelers',
#   'suggestions',
#   'the',
#   'stadium',
#   's',
#   'design',
#   'was',
#   'changed',
#   'to',
#   'enclose',
#   'center',
#   'field',
#   'construction',
#   'continued',
#   'though',
#   'it',
#   'became',
#   'plagued',
#   'with',
#   'problems',
#   'such',
#   'as',
#   'thieves',
#   'stealing',
#   'materials',
#   'from',
#   'the',
#   'building',
#   'site',
#   'in',
#   'november',
#   '1969',
#   'arthur',
#   'gratz',
#   'asked',
#   'the',
#   'city',
#   'for',
#   'an',
#   'additional',
#   '3',
#   'million',
#   '19',
#   '4',
#   'million',
#   'today',
#   'which',
#   'was',
#   'granted',
#   'in',
#   'january',
#   '1970',
#   'the',
#   'opening',
#   'target',
#   'date',
#   'of',
#   'the',
#   'stadium',
#   'was',
#   'set',
#   'for',
#   'may',
#   '29',
#   'however',
#   'because',
#   'of',
#   'a',
#   'failure',
#   'to',
#   'install',
#   'the',
#   'lights',
#   'on',
#   'schedule',
#   'opening',
#   'day',
#   'was',
#   'pushed',
#   'back',
#   'to',
#   'july',
#   '16',
#   'the',
#   'stadium',
#   'was',
#   'named',
#   'in',
#   'february',
#   '1969',
#   'for',
#   'to',
#   'its',
#   'location',
#   'at',
#   'the',
#   'confluence',
#   'of',
#   'the',
#   'allegheny',
#   'river',
#   'and',
#   'monongahela',
#   'river',
#   'which',
#   'forms',
#   'the',
#   'ohio',
#   'river',
#   'it',
#   'would',
#   'sometimes',
#   'be',
#   'called',
#   'the',
#   'house',
#   'that',
#   'clemente',
#   'built',
#   'after',
#   'pirates',
#   'right',
#   'fielder',
#   'roberto',
#   'clemente'],
#  [],
#  [],
#  [],
#  ['john',
#   'philip',
#   'brook',
#   'brooke',
#   'little',
#   'cvo',
#   'kstj',
#   'fsa',
#   'fhs',
#   '6',
#   'april',
#   '1927',
#   '13',
#   'february',
#   '2006',
#   'was',
#   'an',
#   'influential',
#   'and',
#   'popular',
#   'english',
#   'writer',
#   'on',
#   'heraldic',
#   'subjects',
#   'and',
#   'a',
#   'long',
#   'serving',
#   'herald',
#   'at',
#   'the',
#   'college',
#   'of',
#   'arms',
#   'in',
#   'london',
#   'in',
#   '1947',
#   'while',
#   'still',
#   'a',
#   'student',
#   'brooke',
#   'little',
#   'founded',
#   'the',
#   'society',
#   'of',
#   'heraldic',
#   'antiquaries',
#   'now',
#   'known',
#   'as',
#   'the',
#   'heraldry',
#   'society',
#   'and',
#   'recognised',
#   'as',
#   'one',
#   'of',
#   'the',
#   'leading',
#   'learned',
#   'societies',
#   'in',
#   'its',
#   'field',
#   'he',
#   'served',
#   'as',
#   'the',
#   'society',
#   's',
#   'chairman',
#   'for',
#   '50',
#   'years',
#   'and',
#   'then',
#   'as',
#   'its',
#   'president',
#   'from',
#   '1997',
#   'until',
#   'his',
#   'death',
#   'in',
#   '2006',
#   'in',
#   'addition',
#   'to',
#   'the',
#   'foundation',
#   'of',
#   'this',
#   'group',
#   'brooke',
#   'little',
#   'was',
#   'involved',
#   'in',
#   'other',
#   'heraldic',
#   'groups',
#   'and',
#   'societies',
#   'and',
#   'worked',
#   'for',
#   'many',
#   'years',
#   'as',
#   'an',
#   'officer',
#   'of',
#   'arms',
#   'beginning',
#   'as',
#   'bluemantle',
#   'pursuivant',
#   'brooke',
#   'little',
#   'rose',
#   'to',
#   'the',
#   'second',
#   'highest',
#   'heraldic',
#   'office',
#   'in',
#   'england',
#   'clarenceux',
#   'king',
#   'of',
#   'arms'],
#  ['origins'],
#  ['hibernation'],
#  [],
#  ['giroud',
#   'françoise',
#   '1986',
#   'marie',
#   'curie',
#   'a',
#   'life',
#   'holmes',
#   'meier',
#   'isbn',
#   '978',
#   '0',
#   '8419',
#   '0977',
#   '9',
#   'translated',
#   'by',
#   'lydia',
#   'davis'],
#  [],
#  ['late',
#   'in',
#   'the',
#   'pacific',
#   'war',
#   'the',
#   'japanese',
#   'kamikaze',
#   'relentlessly',
#   'plagued',
#   'us',
#   'naval',
#   'operations',
#   'on',
#   '7',
#   'december',
#   '1944',
#   'a',
#   'group',
#   'of',
#   'suicide',
#   'aircraft',
#   'overwhelmed',
#   'and',
#   'disabled',
#   'mahan',
#   'at',
#   'ormoc',
#   'bay',
#   'leyte',
#   'in',
#   'the',
#   'philippine',
#   'islands',
#   'on',
#   'fire',
#   'and',
#   'exploding',
#   'the',
#   'ship',
#   'was',
#   'abandoned',
#   'and',
#   'a',
#   'us',
#   'destroyer',
#   'sank',
#   'her',
#   'with',
#   'torpedoes',
#   'and',
#   'gunfire'],
#  ['favourite', 'worst', 'nightmare', 'tour', '2007', '08'],
#  ['toei',
#   'animation',
#   'produced',
#   'an',
#   'anime',
#   'television',
#   'series',
#   'based',
#   'on',
#   'the',
#   'first',
#   '194',
#   'manga',
#   'chapters',
#   'also',
#   'titled',
#   'dragon',
#   'ball',
#   'the',
#   'series',
#   'premiered',
#   'in',
#   'japan',
#   'on',
#   'fuji',
#   'television',
#   'on',
#   'february',
#   '26',
#   '1986',
#   'and',
#   'ran',
#   'until',
#   'april',
#   '12',
#   '1989',
#   'lasting',
#   '153',
#   'episodes'],
#  [],
#  ['robert',
#   'thompson',
#   'a',
#   'professor',
#   'of',
#   'communications',
#   'and',
#   'director',
#   'of',
#   'the',
#   'center',
#   'for',
#   'the',
#   'study',
#   'of',
#   'popular',
#   'television',
#   'at',
#   'syracuse',
#   'university',
#   'told',
#   'the',
#   'new',
#   'york',
#   'times',
#   'there',
#   'is',
#   'something',
#   'kind',
#   'of',
#   'unique',
#   'about',
#   'spongebob',
#   'it',
#   'seems',
#   'to',
#   'be',
#   'a',
#   'refreshing',
#   'breath',
#   'from',
#   'the',
#   'pre',
#   'irony',
#   'era',
#   'there',
#   's',
#   'no',
#   'sense',
#   'of',
#   'the',
#   'elbow',
#   'in',
#   'rib',
#   'tongue',
#   'in',
#   'cheek',
#   'aesthetic',
#   'that',
#   'so',
#   'permeates',
#   'the',
#   'rest',
#   'of',
#   'american',
#   'culture',
#   'including',
#   'kids',
#   'shows',
#   'like',
#   'the',
#   'rugrats',
#   'i',
#   'think',
#   'what',
#   's',
#   'subversive',
#   'about',
#   'it',
#   'is',
#   'it',
#   's',
#   'so',
#   'incredibly',
#   'naive',
#   'deliberately',
#   'because',
#   'there',
#   's',
#   'nothing',
#   'in',
#   'it',
#   'that',
#   's',
#   'trying',
#   'to',
#   'be',
#   'hip',
#   'or',
#   'cool',
#   'or',
#   'anything',
#   'else',
#   'hipness',
#   'can',
#   'be',
#   'grafted',
#   'onto',
#   'it',
#   'in',
#   'a',
#   '2007',
#   'interview',
#   'barack',
#   'obama',
#   'named',
#   'spongebob',
#   'his',
#   'favorite',
#   'tv',
#   'character',
#   'and',
#   'admitted',
#   'that',
#   'spongebob',
#   'squarepants',
#   'is',
#   'the',
#   'show',
#   'i',
#   'watch',
#   'with',
#   'my',
#   'daughters',
#   'british',
#   'prime',
#   'minister',
#   'gordon',
#   'brown',
#   'has',
#   'also',
#   'said',
#   'he',
#   'watches',
#   'the',
#   'series',
#   'with',
#   'his',
#   'children'],
#  ['as',
#   'he',
#   'neared',
#   'his',
#   'eleventh',
#   'birthday',
#   'gloucester',
#   'was',
#   'assigned',
#   'mary',
#   's',
#   'old',
#   'apartments',
#   'in',
#   'kensington',
#   'palace',
#   'at',
#   'his',
#   'birthday',
#   'party',
#   'at',
#   'windsor',
#   'on',
#   '24',
#   'july',
#   '1700',
#   'he',
#   'complained',
#   'of',
#   'a',
#   'sudden',
#   'fatigue',
#   'but',
#   'was',
#   'initially',
#   'thought',
#   'to',
#   'have',
#   'overheated',
#   'himself',
#   'while',
#   'dancing',
#   'by',
#   'nightfall',
#   'he',
#   'was',
#   'suffering',
#   'from',
#   'a',
#   'sore',
#   'throat',
#   'and',
#   'chills',
#   'followed',
#   'by',
#   'a',
#   'severe',
#   'headache',
#   'and',
#   'a',
#   'high',
#   'fever',
#   'the',
#   'next',
#   'day',
#   'a',
#   'physician',
#   'hannes',
#   'did',
#   'not',
#   'arrive',
#   'until',
#   '27',
#   'july',
#   'gloucester',
#   'was',
#   'immediately',
#   'bled',
#   'but',
#   'his',
#   'condition',
#   'continued',
#   'to',
#   'deteriorate',
#   'over',
#   'the',
#   'next',
#   'day',
#   'he',
#   'developed',
#   'a',
#   'rash',
#   'and',
#   'suffered',
#   'a',
#   'bout',
#   'of',
#   'diarrhoea',
#   'a',
#   'second',
#   'physician',
#   'gibbons',
#   'arrived',
#   'early',
#   'on',
#   '28',
#   'july',
#   'followed',
#   'by',
#   'radcliffe',
#   'that',
#   'evening'],
#  ['little',
#   'busters',
#   'is',
#   'a',
#   'romance',
#   'visual',
#   'novel',
#   'in',
#   'which',
#   'the',
#   'player',
#   'assumes',
#   'the',
#   'role',
#   'of',
#   'riki',
#   'naoe',
#   'much',
#   'of',
#   'its',
#   'gameplay',
#   'is',
#   'spent',
#   'on',
#   'reading',
#   'the',
#   'story',
#   's',
#   'narrative',
#   'and',
#   'dialogue',
#   'the',
#   'text',
#   'in',
#   'the',
#   'game',
#   'is',
#   'accompanied',
#   'by',
#   'character',
#   'sprites',
#   'which',
#   'represent',
#   'who',
#   'riki',
#   'is',
#   'talking',
#   'to',
#   'over',
#   'background',
#   'art',
#   'throughout',
#   'the',
#   'game',
#   'the',
#   'player',
#   'encounters',
#   'cg',
#   'artwork',
#   'at',
#   'certain',
#   'points',
#   'in',
#   'the',
#   'story',
#   'which',
#   'take',
#   'the',
#   'place',
#   'of',
#   'the',
#   'background',
#   'art',
#   'and',
#   'character',
#   'sprites',
#   'when',
#   'the',
#   'game',
#   'is',
#   'completed',
#   'at',
#   'least',
#   'once',
#   'a',
#   'gallery',
#   'of',
#   'the',
#   'viewed',
#   'cgs',
#   'and',
#   'played',
#   'background',
#   'music',
#   'becomes',
#   'available',
#   'on',
#   'the',
#   'game',
#   's',
#   'title',
#   'screen',
#   'little',
#   'busters',
#   'follows',
#   'a',
#   'branching',
#   'plot',
#   'line',
#   'with',
#   'multiple',
#   'endings',
#   'and',
#   'depending',
#   'on',
#   'the',
#   'decisions',
#   'that',
#   'the',
#   'player',
#   'makes',
#   'during',
#   'the',
#   'game',
#   'the',
#   'plot',
#   'will',
#   'progress',
#   'in',
#   'a',
#   'specific',
#   'direction'],
#  ['there',
#   'are',
#   'at',
#   'least',
#   '14',
#   'recognized',
#   'subspecies',
#   'of',
#   'buteo',
#   'jamaicensis',
#   'which',
#   'vary',
#   'in',
#   'range',
#   'and',
#   'in',
#   'coloration'],
#  ['the',
#   'time',
#   'of',
#   '3',
#   'm',
#   '45',
#   '70',
#   's',
#   'sealed',
#   'australia',
#   's',
#   'first',
#   'ever',
#   'win',
#   'in',
#   'a',
#   'medley',
#   'relay',
#   'at',
#   'the',
#   'olympics',
#   'for',
#   'men',
#   'or',
#   'women',
#   'and',
#   'it',
#   'still',
#   'remains',
#   'the',
#   'only',
#   'time',
#   'that',
#   'the',
#   'united',
#   'states',
#   'did',
#   'not',
#   'win',
#   'the',
#   'men',
#   's',
#   'event',
#   'after',
#   'the',
#   'race',
#   'the',
#   'team',
#   'made',
#   'a',
#   'celebratory',
#   'dive',
#   'into',
#   'the',
#   'water',
#   'and',
#   'performed',
#   'a',
#   'poolside',
#   'interview',
#   'tonelli',
#   'remarked',
#   'that',
#   'i',
#   'was',
#   'totally',
#   'stunned',
#   'after',
#   'all',
#   'the',
#   'hassle',
#   'and',
#   'my',
#   'being',
#   'the',
#   'athletes',
#   'mouthpiece',
#   'we',
#   'd',
#   'come',
#   'through',
#   'and',
#   'done',
#   'it',
#   'australia',
#   's',
#   'women',
#   's',
#   'captain',
#   'lisa',
#   'forrest',
#   'hailed',
#   'the',
#   'win',
#   'as',
#   'a',
#   'gold',
#   'medal',
#   'that',
#   'should',
#   'never',
#   'have',
#   'been',
#   'evans',
#   'said',
#   'of',
#   'the',
#   'relay',
#   'it',
#   'was',
#   'unbelievable',
#   'but',
#   'it',
#   'was',
#   'all',
#   'so',
#   'logical',
#   'i',
#   'was',
#   'so',
#   'deliriously',
#   'happy',
#   'that',
#   'i',
#   'couldn',
#   't',
#   'stop',
#   'talking',
#   'as',
#   'brooks',
#   'dedicated',
#   'his',
#   'win',
#   'to',
#   'his',
#   'mother',
#   'who',
#   'had',
#   'died',
#   'from',
#   'cancer',
#   'the',
#   'previous',
#   'christmas'],
#  ['new', 'guinea', 'campaigns', '1942', '44'],
#  ['non',
#   'commercial',
#   'radio',
#   'stations',
#   'include',
#   'npr',
#   'affiliates',
#   'kuow',
#   'fm',
#   '94',
#   '9',
#   'and',
#   'kplu',
#   'fm',
#   '88',
#   '5',
#   'tacoma',
#   'as',
#   'well',
#   'as',
#   'classical',
#   'music',
#   'station',
#   'king',
#   'fm',
#   '98',
#   '1',
#   'other',
#   'stations',
#   'include',
#   'kexp',
#   'fm',
#   '90',
#   '3',
#   'affiliated',
#   'with',
#   'the',
#   'uw',
#   'community',
#   'radio',
#   'kbcs',
#   'fm',
#   '91',
#   '3',
#   'affiliated',
#   'with',
#   'bellevue',
#   'college',
#   'and',
#   'high',
#   'school',
#   'radio',
#   'knhc',
#   'fm',
#   '89',
#   '5',
#   'which',
#   'broadcasts',
#   'an',
#   'electronic',
#   'dance',
#   'music',
#   'radio',
#   'format',
#   'and',
#   'is',
#   'owned',
#   'by',
#   'the',
#   'public',
#   'school',
#   'system',
#   'and',
#   'operated',
#   'by',
#   'students',
#   'of',
#   'nathan',
#   'hale',
#   'high',
#   'school',
#   'many',
#   'seattle',
#   'radio',
#   'stations',
#   'are',
#   'also',
#   'available',
#   'through',
#   'internet',
#   'radio',
#   'with',
#   'kexp',
#   'in',
#   'particular',
#   'being',
#   'a',
#   'pioneer',
#   'of',
#   'internet',
#   'radio',
#   'seattle',
#   'also',
#   'has',
#   'numerous',
#   'commercial',
#   'radio',
#   'stations',
#   'in',
#   'a',
#   'march',
#   '2012',
#   'report',
#   'by',
#   'the',
#   'consumer',
#   'research',
#   'firm',
#   'arbitron',
#   'the',
#   'top',
#   'fm',
#   'stations',
#   'were',
#   'krwm',
#   'adult',
#   'contemporary',
#   'format',
#   'kiro',
#   'fm',
#   'news',
#   'talk',
#   'and',
#   'kisw',
#   'active',
#   'rock',
#   'while',
#   'the',
#   'top',
#   'am',
#   'stations',
#   'were',
#   'komo',
#   'am',
#   'all',
#   'news',
#   'kjr',
#   'am',
#   'all',
#   'sports',
#   'kiro',
#   'am',
#   'all',
#   'sports'],
#  ['developments', 'in', 'deicing'],
#  ['mukuro',
#   's',
#   'character',
#   'has',
#   'been',
#   'well',
#   'received',
#   'by',
#   'readers',
#   'since',
#   'his',
#   'introduction',
#   'ranking',
#   'as',
#   'one',
#   'of',
#   'the',
#   'most',
#   'popular',
#   'characters',
#   'in',
#   'every',
#   'official',
#   'shonen',
#   'jump',
#   'poll',
#   'of',
#   'the',
#   'series',
#   'also',
#   'his',
#   'and',
#   'kyoya',
#   'hibari',
#   's',
#   'character',
#   'cd',
#   'entitled',
#   'sakura',
#   'addiction',
#   'peaked',
#   'at',
#   'seventh',
#   'place',
#   'on',
#   'the',
#   'oricon',
#   'charts',
#   'their',
#   'performance',
#   'earned',
#   'each',
#   'of',
#   'their',
#   'voice',
#   'actors',
#   'a',
#   'seiyu',
#   'awards',
#   'nomination',
#   'for',
#   'best',
#   'musical',
#   'performance',
#   'in',
#   'addition',
#   'to',
#   'toshinobu',
#   'iida',
#   'being',
#   'nominated',
#   'as',
#   'the',
#   'best',
#   'rookie',
#   'actor',
#   'for',
#   'his',
#   'portrayal',
#   'as',
#   'mukuro',
#   'rokudo',
#   'numerous',
#   'anime',
#   'and',
#   'manga',
#   'publications',
#   'have',
#   'commented',
#   'on',
#   'mukuro',
#   's',
#   'character',
#   'mostly',
#   'receiving',
#   'positive',
#   'reviews',
#   'merchandise',
#   'based',
#   'on',
#   'his',
#   'appearance',
#   'has',
#   'also',
#   'been',
#   'released',
#   'including',
#   'key',
#   'chains',
#   'and',
#   'action',
#   'figures'],
#  [],
#  [],
#  [],
#  ['the',
#   'first',
#   'modern',
#   'three',
#   'point',
#   'seat',
#   'belt',
#   'the',
#   'cir',
#   'griswold',
#   'restraint',
#   'used',
#   'in',
#   'most',
#   'consumer',
#   'vehicles',
#   'today',
#   'was',
#   'patented',
#   'in',
#   '1955',
#   'us',
#   'patent',
#   '2',
#   '710',
#   '649',
#   'by',
#   'the',
#   'americans',
#   'roger',
#   'w',
#   'griswold',
#   'and',
#   'hugh',
#   'dehaven',
#   'it',
#   'was',
#   'developed',
#   'into',
#   'its',
#   'modern',
#   'form',
#   'by',
#   'swedish',
#   'inventor',
#   'nils',
#   'bohlin',
#   'us',
#   'patent',
#   '3',
#   '043',
#   '625',
#   'for',
#   'volvo',
#   'who',
#   'introduced',
#   'the',
#   'three',
#   'point',
#   'safety',
#   'device',
#   'in',
#   '1959',
#   'as',
#   'standard',
#   'equipment',
#   'he',
#   'demonstrated',
#   'its',
#   'effectiveness',
#   'in',
#   'a',
#   'study',
#   'of',
#   '28',
#   '000',
#   'accidents',
#   'in',
#   'sweden',
#   'unbelted',
#   'occupants',
#   'sustained',
#   'fatal',
#   'injuries',
#   'throughout',
#   'the',
#   'whole',
#   'speed',
#   'range',
#   'whereas',
#   'none',
#   'of',
#   'the',
#   'belted',
#   'occupants',
#   'were',
#   'fatally',
#   'injured',
#   'at',
#   'accident',
#   'speeds',
#   'below',
#   '60',
#   'mph',
#   '97',
#   'km',
#   'h',
#   'and',
#   'no',
#   'belted',
#   'occupant',
#   'was',
#   'fatally',
#   'injured',
#   'if',
#   'the',
#   'passenger',
#   'compartment',
#   'remained',
#   'intact',
#   'american',
#   'manufacturers',
#   'followed',
# ...
#   'cm2',
#   'and',
#   'temperature',
#   'of',
#   '700',
#   'f',
#   '371',
#   'c',
#   'the',
#   'engines',
#   'were',
#   'designed',
#   'to',
#   'produce',
#   'a',
#   'total',
#   'of',
#   '130',
#   '000',
#   'shaft',
#   'horsepower',
#   '97',
#   '000',
#   'kw',
#   'and',
#   'a',
#   'speed',
#   'of',
#   '30',
#   'knots',
#   '56',
#   'km',
#   'h',
#   '35',
#   'mph',
#   'but',
#   'achieved',
#   'more',
#   'than',
#   '136',
#   '000',
#   'shp',
#   '101',
#   '000',
#   'kw',
#   'during',
#   'the',
#   'ship',
#   's',
#   'sea',
#   'trials',
#   'in',
#   'july',
#   '1946',
#   'when',
#   'she',
#   'reached',
#   'a',
#   'speed',
#   'of',
#   '31',
#   '57',
#   'knots',
#   '58',
#   '47',
#   'km',
#   'h',
#   '36',
#   '33',
#   'mph',
#   'after',
#   'trials',
#   'the',
#   'three',
#   'bladed',
#   'propellers',
#   'on',
#   'the',
#   'inboard',
#   'shafts',
#   'were',
#   'replaced',
#   'by',
#   'five',
#   'bladed',
#   'propellers',
#   'in',
#   'an',
#   'unsuccessful',
#   'attempt',
#   'to',
#   'reduce',
#   'vibrations',
#   'of',
#   'the',
#   'inboard',
#   'propeller',
#   'shafts'],
#  ['in',
#   'the',
#   'united',
#   'states',
#   'suicide',
#   'is',
#   'not',
#   'illegal',
#   'but',
#   'may',
#   'be',
#   'associated',
#   'with',
#   'penalties',
#   'for',
#   'those',
#   'who',
#   'attempt',
#   'it',
#   'physician',
#   'assisted',
#   'suicide',
#   'is',
#   'legal',
#   'in',
#   'the',
#   'state',
#   'of',
#   'washington',
#   'for',
#   'people',
#   'with',
#   'terminal',
#   'diseases',
#   'in',
#   'oregon',
#   'people',
#   'with',
#   'terminal',
#   'diseases',
#   'may',
#   'request',
#   'medications',
#   'to',
#   'help',
#   'end',
#   'their',
#   'life'],
#  [],
#  [],
#  ['statistics'],
#  ['on',
#   '18',
#   'march',
#   'it',
#   'became',
#   'known',
#   'that',
#   'the',
#   'north',
#   'west',
#   'mounted',
#   'police',
#   'garrison',
#   'at',
#   'battleford',
#   'was',
#   'being',
#   'reinforced',
#   'although',
#   'only',
#   '100',
#   'men',
#   'had',
#   'been',
#   'sent',
#   'in',
#   'response',
#   'to',
#   'warnings',
#   'from',
#   'father',
#   'alexis',
#   'andré',
#   'and',
#   'nwmp',
#   'superintendent',
#   'l',
#   'n',
#   'f',
#   'crozier',
#   'a',
#   'rumour',
#   'soon',
#   'began',
#   'to',
#   'circulate',
#   'that',
#   '500',
#   'heavily',
#   'armed',
#   'troops',
#   'were',
#   'advancing',
#   'on',
#   'the',
#   'territory',
#   'métis',
#   'patience',
#   'was',
#   'exhausted',
#   'and',
#   'riel',
#   's',
#   'followers',
#   'seized',
#   'arms',
#   'took',
#   'hostages',
#   'and',
#   'cut',
#   'the',
#   'telegraph',
#   'lines',
#   'between',
#   'batoche',
#   'and',
#   'battleford',
#   'the',
#   'provisional',
#   'government',
#   'of',
#   'saskatchewan',
#   'was',
#   'declared',
#   'at',
#   'batoche',
#   'on',
#   '19',
#   'march',
#   'with',
#   'riel',
#   'as',
#   'the',
#   'political',
#   'and',
#   'spiritual',
#   'leader',
#   'and',
#   'with',
#   'dumont',
#   'assuming',
#   'responsibility',
#   'for',
#   'military',
#   'affairs',
#   'riel',
#   'formed',
#   'a',
#   'council',
#   'called',
#   'the',
#   'exovedate',
#   'a',
#   'neologism',
#   'meaning',
#   'those',
#   'who',
#   'have',
#   'left',
#   'the',
#   'flock',
#   'and',
#   'sent',
#   'representatives',
#   'to',
#   'court',
#   'poundmaker',
#   'and',
#   'big',
#   'bear',
#   'on',
#   '21',
#   'march',
#   'riel',
#   's',
#   'emissaries',
#   'demanded',
#   'that',
#   'crozier',
#   'surrender',
#   'fort',
#   'carlton',
#   'but',
#   'this',
#   'was',
#   'refused',
#   'the',
#   'situation',
#   'was',
#   'becoming',
#   'critical',
#   'and',
#   'on',
#   '23',
#   'march',
#   'dewdney',
#   'sent',
#   'a',
#   'telegraph',
#   'to',
#   'macdonald',
#   'indicating',
#   'that',
#   'military',
#   'intervention',
#   'might',
#   'be',
#   'necessary',
#   'scouting',
#   'near',
#   'duck',
#   'lake',
#   'on',
#   '26',
#   'march',
#   'a',
#   'force',
#   'led',
#   'by',
#   'gabriel',
#   'dumont',
#   'unexpectedly',
#   'chanced',
#   'upon',
#   'a',
#   'party',
#   'from',
#   'fort',
#   'carlton',
#   'in',
#   'the',
#   'ensuing',
#   'battle',
#   'of',
#   'duck',
#   'lake',
#   'the',
#   'police',
#   'were',
#   'routed',
#   'and',
#   'the',
#   'natives',
#   'also',
#   'rose',
#   'up',
#   'once',
#   'the',
#   'news',
#   'became',
#   'known',
#   'the',
#   'die',
#   'was',
#   'cast',
#   'for',
#   'a',
#   'violent',
#   'outcome',
#   'and',
#   'the',
#   'north',
#   'west',
#   'rebellion',
#   'was',
#   'begun',
#   'in',
#   'earnest'],
#  [],
#  ['wood',
#   'carving',
#   'traditions',
#   'exist',
#   'in',
#   'many',
#   'parts',
#   'of',
#   'the',
#   'country',
#   'with',
#   'exceptional',
#   'examples',
#   'are',
#   'in',
#   'jepara',
#   'in',
#   'central',
#   'java',
#   'bali',
#   'and',
#   'asmat',
#   'traditional',
#   'carpentry',
#   'masonry',
#   'stone',
#   'and',
#   'woodwork',
#   'techniques',
#   'and',
#   'decorations',
#   'are',
#   'also',
#   'thrived',
#   'in',
#   'indonesian',
#   'vernacular',
#   'architecture',
#   'with',
#   'numbers',
#   'of',
#   'traditional',
#   'houses',
#   'styles',
#   'has',
#   'been',
#   'developed',
#   'the',
#   'traditional',
#   'houses',
#   'and',
#   'settlements',
#   'of',
#   'the',
#   'several',
#   'hundreds',
#   'ethnic',
#   'groups',
#   'of',
#   'indonesia',
#   'are',
#   'extremely',
#   'varied',
#   'and',
#   'all',
#   'have',
#   'their',
#   'own',
#   'specific',
#   'history'],
#  [],
#  ['the',
#   'cooling',
#   'properties',
#   'of',
#   'the',
#   'leaves',
#   'were',
#   'used',
#   'in',
#   'britain',
#   'as',
#   'a',
#   'treatment',
#   'for',
#   'trench',
#   'foot',
#   'in',
#   'world',
#   'war',
#   'i',
#   'and',
#   'as',
#   'compresses',
#   'for',
#   'ulcers',
#   'and',
#   'breast',
#   'abscesses',
#   'accumulated',
#   'scientific',
#   'evidence',
#   'corroborates',
#   'that',
#   'cabbage',
#   'leaf',
#   'treatment',
#   'can',
#   'reduce',
#   'the',
#   'pain',
#   'and',
#   'hardness',
#   'of',
#   'engorged',
#   'breasts',
#   'and',
#   'increase',
#   'the',
#   'duration',
#   'of',
#   'breast',
#   'feeding',
#   'other',
#   'medicinal',
#   'uses',
#   'recorded',
#   'in',
#   'europe',
#   'folk',
#   'medicine',
#   'include',
#   'treatments',
#   'for',
#   'rheumatism',
#   'sore',
#   'throat',
#   'hoarseness',
#   'colic',
#   'and',
#   'melancholy',
#   'in',
#   'the',
#   'united',
#   'states',
#   'cabbage',
#   'has',
#   'been',
#   'used',
#   'as',
#   'a',
#   'hangover',
#   'cure',
#   'to',
#   'treat',
#   'abscesses',
#   'to',
#   'prevent',
#   'sunstroke',
#   'or',
#   'to',
#   'cool',
#   'body',
#   'parts',
#   'affected',
#   'by',
#   'fevers',
#   'the',
#   'leaves',
#   'have',
#   'also',
#   'been',
#   'used',
#   'to',
#   'soothe',
#   'sore',
#   'feet',
#   'and',
#   'when',
#   'tied',
#   'around',
#   'the',
#   'neck',
#   'of',
#   'children',
#   'to',
#   'relieve',
#   'croup',
#   'both',
#   'mashed',
#   'cabbage',
#   'and',
#   'cabbage',
#   'juice',
#   'have',
#   'been',
#   'used',
#   'in',
#   'poultices',
#   'to',
#   'remove',
#   'boils',
#   'and',
#   'treat',
#   'warts',
#   'pneumonia',
#   'appendicitis',
#   'and',
#   'ulcers'],
#  [],
#  ['what',
#   'is',
#   'now',
#   'route',
#   '208',
#   'was',
#   'initially',
#   'planned',
#   'as',
#   'route',
#   's4b',
#   'in',
#   '1929',
#   'a',
#   'spur',
#   'of',
#   'route',
#   '4',
#   'that',
#   'was',
#   'to',
#   'run',
#   'from',
#   'fair',
#   'lawn',
#   'northwest',
#   'to',
#   'the',
#   'new',
#   'york',
#   'border',
#   'in',
#   'greenwood',
#   'lake',
#   'where',
#   'it',
#   'would',
#   'eventually',
#   'connect',
#   'to',
#   'new',
#   'york',
#   'state',
#   'route',
#   '208',
#   'this',
#   'route',
#   'replaced',
#   'what',
#   'was',
#   'planned',
#   'as',
#   'a',
#   'part',
#   'of',
#   'route',
#   '3',
#   'in',
#   '1927',
#   'between',
#   'paterson',
#   'and',
#   'greenwood',
#   'lake',
#   'by',
#   'the',
#   'time',
#   'the',
#   'route',
#   'was',
#   'renumbered',
#   'to',
#   'route',
#   '208',
#   'in',
#   '1953',
#   'to',
#   'match',
#   'ny',
#   '208',
#   'only',
#   'a',
#   'portion',
#   'of',
#   'the',
#   'route',
#   'in',
#   'fair',
#   'lawn',
#   'from',
#   'route',
#   '4',
#   'to',
#   'maple',
#   'avenue',
#   'had',
#   'been',
#   'built',
#   'route',
#   '208',
#   'was',
#   'completed',
#   'west',
#   'to',
#   'u',
#   's',
#   'route',
#   '202',
#   'in',
#   'oakland',
#   'by',
#   '1960',
#   'as',
#   'a',
#   'two',
#   'lane',
#   'undivided',
#   'road',
#   'it',
#   'would',
#   'be',
#   'built',
#   'into',
#   'its',
#   'present',
#   'configuration',
#   'in',
#   'later',
#   'years',
#   'a',
#   'route',
#   '208',
#   'freeway',
#   'was',
#   'planned',
#   'across',
#   'the',
#   'ramapo',
#   'mountains',
#   'from',
#   'oakland',
#   'to',
#   'connect',
#   'to',
#   'a',
#   'proposed',
#   'ny',
#   '208',
#   'freeway',
#   'at',
#   'greenwood',
#   'lake',
#   'however',
#   'it',
#   'was',
#   'never',
#   'built',
#   'after',
#   'interstate',
#   '287',
#   'was',
#   'extended',
#   'from',
#   'montville',
#   'to',
#   'the',
#   'new',
#   'york',
#   'border',
#   'in',
#   '1993',
#   'it',
#   'took',
#   'over',
#   'the',
#   'alignment',
#   'of',
#   'route',
#   '208',
#   'between',
#   'u',
#   's',
#   'route',
#   '202',
#   'and',
#   'the',
#   'route',
#   's',
#   'current',
#   'northern',
#   'terminus',
#   'the',
#   'last',
#   'traffic',
#   'signal',
#   'along',
#   'route',
#   '208',
#   'at',
#   'mcbride',
#   'avenue',
#   'was',
#   'removed',
#   'in',
#   '1997',
#   'and',
#   'the',
#   'interchange',
#   'with',
#   'route',
#   '4',
#   'and',
#   'saddle',
#   'river',
#   'road',
#   'was',
#   'reconstructed',
#   'in',
#   '2002'],
#  ['broad', 'dorsoventrally', 'compressed', 'skull'],
#  ['as',
#   'a',
#   'child',
#   'usama',
#   'was',
#   'the',
#   'second',
#   'of',
#   'four',
#   'boys',
#   'and',
#   'raised',
#   'by',
#   'his',
#   'nurse',
#   'lu',
#   'lu',
#   'a',
#   'who',
#   'had',
#   'also',
#   'raised',
#   'his',
#   'father',
#   'and',
#   'would',
#   'later',
#   'raise',
#   'usama',
#   's',
#   'own',
#   'children',
#   'he',
#   'was',
#   'encouraged',
#   'by',
#   'his',
#   'father',
#   'to',
#   'memorize',
#   'the',
#   'qur',
#   'an',
#   'and',
#   'was',
#   'also',
#   'tutored',
#   'by',
#   'scholars',
#   'such',
#   'as',
#   'ibn',
#   'munira',
#   'of',
#   'kafartab',
#   'and',
#   'abu',
#   'abdullah',
#   'al',
#   'tulaytuli',
#   'of',
#   'toledo',
#   'he',
#   'spent',
#   'much',
#   'of',
#   'his',
#   'youth',
#   'hunting',
#   'with',
#   'his',
#   'family',
#   'partly',
#   'as',
#   'recreation',
#   'and',
#   'certainly',
#   'as',
#   'warrior',
#   'faris',
#   'training',
#   'for',
#   'battle',
#   'as',
#   'part',
#   'of',
#   'furusiyya',
#   'he',
#   'also',
#   'had',
#   'much',
#   'direct',
#   'experience',
#   'of',
#   'battle',
#   'against',
#   'the',
#   'neighbouring',
#   'crusader',
#   'county',
#   'of',
#   'tripoli',
#   'and',
#   'principality',
#   'of',
#   'antioch',
#   'hostile',
#   'muslim',
#   'neighbours',
#   'in',
#   'hama',
#   'homs',
#   'and',
#   'elsewhere',
#   'and',
#   'hashshashin',
#   'who',
#   'had',
#   'established',
#   'a',
#   'base',
#   'near',
#   'shaizar'],
#  ['mr', 'europa', '2005'],
#  ['toscanini',
#   'beecham',
#   'and',
#   'many',
#   'others',
#   'regarded',
#   'sargent',
#   'as',
#   'the',
#   'finest',
#   'choral',
#   'conductor',
#   'in',
#   'the',
#   'world',
#   'even',
#   'orchestral',
#   'musicians',
#   'gave',
#   'him',
#   'credit',
#   'the',
#   'principal',
#   'violist',
#   'of',
#   'the',
#   'bbc',
#   'symphony',
#   'orchestra',
#   'wrote',
#   'of',
#   'him',
#   'he',
#   'is',
#   'able',
#   'to',
#   'instil',
#   'into',
#   'the',
#   'singers',
#   'a',
#   'life',
#   'and',
#   'efficiency',
#   'they',
#   'never',
#   'dreamed',
#   'of',
#   'you',
#   'have',
#   'only',
#   'to',
#   'see',
#   'the',
#   'eyes',
#   'of',
#   'a',
#   'choral',
#   'society',
#   'screwing',
#   'into',
#   'him',
#   'like',
#   'hundreds',
#   'of',
#   'gimlets',
#   'to',
#   'understand',
#   'what',
#   'he',
#   'means',
#   'to',
#   'them',
#   'however',
#   'another',
#   'of',
#   'sargent',
#   's',
#   'colleagues',
#   'sir',
#   'adrian',
#   'boult',
#   'said',
#   'of',
#   'him',
#   'h',
#   'e',
#   'was',
#   'a',
#   'great',
#   'all',
#   'rounder',
#   'but',
#   'never',
#   'developed',
#   'his',
#   'potentialities',
#   'which',
#   'were',
#   'enormous',
#   'simply',
#   'because',
#   'he',
#   'didn',
#   't',
#   'think',
#   'hard',
#   'enough',
#   'about',
#   'music',
#   'he',
#   'never',
#   'troubled',
#   'to',
#   'improve',
#   'on',
#   'a',
#   'successful',
#   'interpretation',
#   'he',
#   'was',
#   'too',
#   'interested',
#   'in',
#   'other',
#   'things',
#   'and',
#   'not',
#   'single',
#   'minded',
#   'enough',
#   'about',
#   'music'],
#  ['history'],
#  ['revised', 'plans'],
#  [],
#  ['changyuraptor',
#   'yangi',
#   'is',
#   'a',
#   'close',
#   'relative',
#   'of',
#   'microraptor',
#   'gui',
#   'also',
#   'thought',
#   'to',
#   'be',
#   'a',
#   'glider',
#   'or',
#   'flyer',
#   'based',
#   'on',
#   'the',
#   'presence',
#   'of',
#   'four',
#   'wings',
#   'and',
#   'similar',
#   'limb',
#   'proportions',
#   'however',
#   'it',
#   'is',
#   'a',
#   'considerably',
#   'larger',
#   'animal',
#   'around',
#   'the',
#   'size',
#   'of',
#   'a',
#   'wild',
#   'turkey',
#   'being',
#   'among',
#   'the',
#   'largest',
#   'known',
#   'flying',
#   'mesozoic',
#   'paravians'],
#  ['local',
#   'volunteers',
#   'under',
#   'the',
#   'guidance',
#   'of',
#   'the',
#   'manchester',
#   'bolton',
#   'and',
#   'bury',
#   'canal',
#   'society',
#   'have',
#   'for',
#   'years',
#   'worked',
#   'on',
#   'sections',
#   'of',
#   'the',
#   'canal',
#   'removing',
#   'overgrowth',
#   'and',
#   'tidying',
#   'up',
#   'its',
#   'general',
#   'appearance',
#   'a',
#   'new',
#   'pedestrian',
#   'footbridge',
#   'designed',
#   'by',
#   'artist',
#   'liam',
#   'curtin',
#   'was',
#   'opened',
#   'at',
#   'nob',
#   'end',
#   'locks',
#   'in',
#   'april',
#   '2013',
#   'made',
#   'entirely',
#   'out',
#   'of',
#   'scaled',
#   'up',
#   'pieces',
#   'of',
#   'meccano',
#   'it',
#   'was',
#   'built',
#   'by',
#   'society',
#   'volunteers',
#   'and',
#   'other',
#   'members',
#   'of',
#   'the',
#   'public',
#   'at',
#   'a',
#   'cost',
#   'of',
#   'about',
#   '90',
#   '000',
#   'toward',
#   'the',
#   'end',
#   'of',
#   '2015',
#   'work',
#   'began',
#   'to',
#   'restore',
#   'water',
#   'to',
#   'the',
#   'top',
#   'lock',
#   'at',
#   'nob',
#   'end',
#   'infill',
#   'beneath',
#   'the',
#   'first',
#   'bridge',
#   'on',
#   'the',
#   'canal',
#   's',
#   'bolton',
#   'arm',
#   'was',
#   'excavated',
#   'exposing',
#   'the',
#   'towpath',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'decades'],
#  ['in',
#   'the',
#   '1820s',
#   'the',
#   'balfours',
#   'employed',
#   'the',
#   'architect',
#   'robert',
#   'smirke',
#   'designer',
#   'of',
#   'the',
#   'british',
#   'museum',
#   'to',
#   'build',
#   'a',
#   'large',
#   'classical',
#   'mansion',
#   'at',
#   'whittingehame',
#   'along',
#   'with',
#   'a',
#   'stable',
#   'block',
#   'and',
#   'gate',
#   'lodges',
#   'they',
#   'equipped',
#   'their',
#   'home',
#   'with',
#   'french',
#   'furniture',
#   'and',
#   'sèvres',
#   'china',
#   'built',
#   'of',
#   'pale',
#   'cullalo',
#   'stone',
#   'the',
#   'house',
#   'was',
#   'expanded',
#   'and',
#   'altered',
#   'in',
#   '1827',
#   'to',
#   'the',
#   'designs',
#   'of',
#   'william',
#   'burn',
#   'which',
#   'were',
#   'not',
#   'entirely',
#   'successful',
#   'colin',
#   'mcwilliam',
#   'and',
#   'christopher',
#   'wilson',
#   'describe',
#   'them',
#   'as',
#   'having',
#   'changed',
#   'a',
#   'dry',
#   'composition',
#   'into',
#   'a',
#   'boring',
#   'one'],
#  ['her',
#   'eyes',
#   'gaze',
#   'downward',
#   'in',
#   'humility',
#   'in',
#   'contrast',
#   'to',
#   'her',
#   'relatively',
#   'extravagant',
#   'clothes',
#   'the',
#   'piety',
#   'of',
#   'her',
#   'expression',
#   'is',
#   'achieved',
#   'through',
#   'motifs',
#   'common',
#   'to',
#   'van',
#   'der',
#   'weyden',
#   's',
#   'work',
#   'her',
#   'eyes',
#   'and',
#   'nose',
#   'are',
#   'elongated',
#   'and',
#   'her',
#   'lower',
#   'lip',
#   'made',
#   'fuller',
#   'by',
#   'the',
#   'use',
#   'of',
#   'tone',
#   'and',
#   'pronounced',
#   'finish',
#   'some',
#   'vertical',
#   'lines',
#   'around',
#   'these',
#   'features',
#   'are',
#   'emphasised',
#   'while',
#   'her',
#   'pupils',
#   'are',
#   'enlarged',
#   'and',
#   'her',
#   'eyebrows',
#   'slightly',
#   'raised',
#   'in',
#   'addition',
#   'the',
#   'contours',
#   'of',
#   'her',
#   'face',
#   'are',
#   'highlighted',
#   'in',
#   'a',
#   'manner',
#   'that',
#   'is',
#   'slightly',
#   'unnatural',
#   'and',
#   'abstract',
#   'and',
#   'outside',
#   'the',
#   'usual',
#   'spatial',
#   'constraints',
#   'of',
#   '15th',
#   'century',
#   'human',
#   'representation',
#   'this',
#   'methodology',
#   'was',
#   'described',
#   'by',
#   'art',
#   'historian',
#   'erwin',
#   'panofsky',
#   'rogier',
#   'concentrated',
#   'on',
#   'certain',
#   'salient',
#   'features',
#   'salient',
#   'both',
#   'from',
#   'a',
#   'physiognomical',
#   'and',
#   'psychological',
#   'point',
#   'of',
#   'view',
#   'which',
#   'he',
#   'expressed',
#   'primarily',
#   'by',
#   'lines',
#   'her',
#   'high',
#   'forehead',
#   'and',
#   'full',
#   'mouth',
#   'have',
#   'been',
#   'seen',
#   'as',
#   'suggestive',
#   'of',
#   'a',
#   'nature',
#   'at',
#   'once',
#   'intellectual',
#   'ascetic',
#   'and',
#   'passionate',
#   'symbolic',
#   'of',
#   'an',
#   'unresolved',
#   'conflict',
#   'in',
#   'her',
#   'personality',
#   'panofsky',
#   'refers',
#   'to',
#   'a',
#   'smouldering',
#   'excitability'],
#  ...]

# %% [markdown]
# ### Vocabulary
#
#
#
# Using `collections.Counter`, construct the vocabulary by tokenizing every text in the dataset and keeping only the $V$ most frequent words. Let's set $V=1000$ to start
#
# Then use this vocabulary to vectorize examples, assigning integer identifiers to words (from $0$ to $V-1$)

# %%
from collections import Counter
V = 1000

# %%
def build_vocabulary(lists: list[str], V: int) -> list[str]:
    """Builds a vocabulary with the V most frequent words."""
    # Fusionner les compteurs de chaque liste
    word_counts = sum((Counter(lst) for lst in lists), Counter())
    most_common_words = [word for word, _ in word_counts.most_common(V)]
    print(f"most commmon words:\n{most_common_words}")
    vocab = {word: idx for idx, word in enumerate(most_common_words)}
    return word_counts, vocab

# %%
vocab
# Out:
# {'the': 0,
#  'of': 1,
#  'and': 2,
#  'in': 3,
#  'to': 4,
#  'a': 5,
#  'was': 6,
#  'on': 7,
#  's': 8,
#  'as': 9,
#  'for': 10,
#  'with': 11,
#  'that': 12,
#  'by': 13,
#  'is': 14,
#  'he': 15,
#  'his': 16,
#  'at': 17,
#  'it': 18,
#  'from': 19,
#  'were': 20,
#  'an': 21,
#  'had': 22,
#  'which': 23,
#  'be': 24,
#  'but': 25,
#  'this': 26,
#  'are': 27,
#  'first': 28,
#  'not': 29,
#  'after': 30,
#  'also': 31,
#  'one': 32,
#  'their': 33,
#  'two': 34,
#  'her': 35,
#  'its': 36,
#  'they': 37,
#  'or': 38,
#  'who': 39,
#  'when': 40,
#  'have': 41,
#  'new': 42,
#  'has': 43,
#  'she': 44,
#  'been': 45,
#  'would': 46,
#  'other': 47,
#  'i': 48,
#  'during': 49,
#  'time': 50,
#  'all': 51,
#  'more': 52,
#  'into': 53,
#  '1': 54,
#  'game': 55,
#  'over': 56,
#  'most': 57,
#  'him': 58,
#  'while': 59,
#  'only': 60,
#  'than': 61,
#  'between': 62,
#  'later': 63,
#  'up': 64,
#  'out': 65,
#  '2': 66,
#  'three': 67,
#  'about': 68,
#  'before': 69,
#  'film': 70,
#  'there': 71,
#  'such': 72,
#  'some': 73,
#  'may': 74,
#  'made': 75,
#  '000': 76,
#  'world': 77,
#  'year': 78,
#  'where': 79,
#  'series': 80,
#  'through': 81,
#  'second': 82,
#  '3': 83,
#  'season': 84,
#  'years': 85,
#  'no': 86,
#  'them': 87,
#  'm': 88,
#  'used': 89,
#  'these': 90,
#  'became': 91,
#  'state': 92,
#  'war': 93,
#  'however': 94,
#  'being': 95,
#  'music': 96,
#  'can': 97,
#  'several': 98,
#  'against': 99,
#  'then': 100,
#  'many': 101,
#  'city': 102,
#  'album': 103,
#  '5': 104,
#  'number': 105,
#  'including': 106,
#  'both': 107,
#  'song': 108,
#  'four': 109,
#  'north': 110,
#  '4': 111,
#  'part': 112,
#  'team': 113,
#  'south': 114,
#  'did': 115,
#  'united': 116,
#  'well': 117,
#  'because': 118,
#  'early': 119,
#  'following': 120,
#  'under': 121,
#  'episode': 122,
#  'day': 123,
#  'american': 124,
#  'so': 125,
#  'states': 126,
#  'high': 127,
#  'work': 128,
#  'us': 129,
#  'known': 130,
#  'said': 131,
#  'like': 132,
#  'began': 133,
#  'until': 134,
#  't': 135,
#  'released': 136,
#  'same': 137,
#  'although': 138,
#  'five': 139,
#  'end': 140,
#  '6': 141,
#  'west': 142,
#  'people': 143,
#  'around': 144,
#  'could': 145,
#  'each': 146,
#  'john': 147,
#  'if': 148,
#  'use': 149,
#  'national': 150,
#  'another': 151,
#  'along': 152,
#  'since': 153,
#  '10': 154,
#  'single': 155,
#  'found': 156,
#  'long': 157,
#  'school': 158,
#  'called': 159,
#  'back': 160,
#  'took': 161,
#  'any': 162,
#  'july': 163,
#  'million': 164,
#  'show': 165,
#  'area': 166,
#  'best': 167,
#  'august': 168,
#  '7': 169,
#  'system': 170,
#  'life': 171,
#  'east': 172,
#  'group': 173,
#  'just': 174,
#  'video': 175,
#  'due': 176,
#  'november': 177,
#  'will': 178,
#  'now': 179,
#  'british': 180,
#  'times': 181,
#  'based': 182,
#  'october': 183,
#  'final': 184,
#  'history': 185,
#  'received': 186,
#  'september': 187,
#  'june': 188,
#  'you': 189,
#  'march': 190,
#  'what': 191,
#  '12': 192,
#  'production': 193,
#  'line': 194,
#  'six': 195,
#  'games': 196,
#  'large': 197,
#  'third': 198,
#  'off': 199,
#  'major': 200,
#  'character': 201,
#  '8': 202,
#  'king': 203,
#  'general': 204,
#  'km': 205,
#  'top': 206,
#  'home': 207,
#  'won': 208,
#  '0': 209,
#  'route': 210,
#  'april': 211,
#  '9': 212,
#  'century': 213,
#  'included': 214,
#  'make': 215,
#  'house': 216,
#  'built': 217,
#  'player': 218,
#  'u': 219,
#  'described': 220,
#  'played': 221,
#  'family': 222,
#  'main': 223,
#  'species': 224,
#  'battle': 225,
#  'down': 226,
#  'near': 227,
#  'original': 228,
#  'government': 229,
#  'much': 230,
#  'army': 231,
#  'members': 232,
#  'place': 233,
#  'road': 234,
#  'york': 235,
#  'those': 236,
#  '11': 237,
#  'last': 238,
#  'own': 239,
#  '20': 240,
#  'within': 241,
#  'we': 242,
#  'left': 243,
#  'band': 244,
#  'story': 245,
#  'service': 246,
#  'club': 247,
#  'set': 248,
#  'white': 249,
#  'side': 250,
#  'death': 251,
#  'late': 252,
#  'way': 253,
#  'named': 254,
#  'december': 255,
#  'january': 256,
#  'february': 257,
#  'small': 258,
#  'according': 259,
#  'name': 260,
#  'ship': 261,
#  '15': 262,
#  '2010': 263,
#  'though': 264,
#  'days': 265,
#  'having': 266,
#  'public': 267,
#  'german': 268,
#  'very': 269,
#  'form': 270,
#  'again': 271,
#  'do': 272,
#  'company': 273,
#  'old': 274,
#  'university': 275,
#  'record': 276,
#  'street': 277,
#  'division': 278,
#  'county': 279,
#  '100': 280,
#  'led': 281,
#  'point': 282,
#  'held': 283,
#  '2008': 284,
#  'wrote': 285,
#  '30': 286,
#  'among': 287,
#  'still': 288,
#  'next': 289,
#  'de': 290,
#  'release': 291,
#  'men': 292,
#  'man': 293,
#  'highway': 294,
#  'track': 295,
#  'military': 296,
#  'book': 297,
#  'park': 298,
#  'former': 299,
#  'further': 300,
#  'order': 301,
#  'building': 302,
#  'career': 303,
#  'black': 304,
#  'even': 305,
#  'little': 306,
#  '2011': 307,
#  'characters': 308,
#  'force': 309,
#  'river': 310,
#  'party': 311,
#  'power': 312,
#  'often': 313,
#  'continued': 314,
#  'french': 315,
#  'lost': 316,
#  'my': 317,
#  '2007': 318,
#  'himself': 319,
#  'never': 320,
#  'songs': 321,
#  'great': 322,
#  'match': 323,
#  'b': 324,
#  'air': 325,
#  'half': 326,
#  'came': 327,
#  'england': 328,
#  'president': 329,
#  'play': 330,
#  '18': 331,
#  'championship': 332,
#  '16': 333,
#  'court': 334,
#  'right': 335,
#  '13': 336,
#  'different': 337,
#  'similar': 338,
#  '2012': 339,
#  'h': 340,
#  'version': 341,
#  'london': 342,
#  'despite': 343,
#  'women': 344,
#  'ii': 345,
#  'water': 346,
#  'international': 347,
#  'short': 348,
#  'forces': 349,
#  'tropical': 350,
#  'using': 351,
#  'love': 352,
#  'storm': 353,
#  'take': 354,
#  'period': 355,
#  'english': 356,
#  'role': 357,
#  'western': 358,
#  'without': 359,
#  'how': 360,
#  'moved': 361,
#  'considered': 362,
#  'few': 363,
#  'good': 364,
#  'published': 365,
#  'went': 366,
#  'star': 367,
#  'become': 368,
#  '2009': 369,
#  'development': 370,
#  'country': 371,
#  'c': 372,
#  'field': 373,
#  'recorded': 374,
#  'written': 375,
#  'james': 376,
#  'town': 377,
#  'construction': 378,
#  'class': 379,
#  'support': 380,
#  'local': 381,
#  'children': 382,
#  'red': 383,
#  'league': 384,
#  'away': 385,
#  'throughout': 386,
#  'feet': 387,
#  'tour': 388,
#  '14': 389,
#  'lead': 390,
#  'given': 391,
#  'land': 392,
#  'father': 393,
#  'gave': 394,
#  'less': 395,
#  'returned': 396,
#  'died': 397,
#  '2006': 398,
#  'players': 399,
#  'run': 400,
#  'light': 401,
#  'fire': 402,
#  '25': 403,
#  'design': 404,
#  'various': 405,
#  'attack': 406,
#  'killed': 407,
#  'instead': 408,
#  'performance': 409,
#  'total': 410,
#  'include': 411,
#  'church': 412,
#  '17': 413,
#  'd': 414,
#  'island': 415,
#  'royal': 416,
#  'southern': 417,
#  'ships': 418,
#  'sent': 419,
#  'felt': 420,
#  'race': 421,
#  'control': 422,
#  'hurricane': 423,
#  'appeared': 424,
#  'title': 425,
#  'style': 426,
#  'produced': 427,
#  'should': 428,
#  'office': 429,
#  'too': 430,
#  'stated': 431,
#  'central': 432,
#  'political': 433,
#  'member': 434,
#  'me': 435,
#  'chart': 436,
#  'seen': 437,
#  'present': 438,
#  'william': 439,
#  'eight': 440,
#  'able': 441,
#  'previous': 442,
#  'college': 443,
#  'common': 444,
#  'win': 445,
#  'live': 446,
#  'created': 447,
#  'seven': 448,
#  '24': 449,
#  'aircraft': 450,
#  'center': 451,
#  'once': 452,
#  'age': 453,
#  'head': 454,
#  'front': 455,
#  'thought': 456,
#  'position': 457,
#  'completed': 458,
#  'followed': 459,
#  'director': 460,
#  '23': 461,
#  'low': 462,
#  'per': 463,
#  'announced': 464,
#  'law': 465,
#  'young': 466,
#  'writing': 467,
#  'reached': 468,
#  'see': 469,
#  'result': 470,
#  'art': 471,
#  'making': 472,
#  '22': 473,
#  'formed': 474,
#  'project': 475,
#  'mm': 476,
#  '2004': 477,
#  'upon': 478,
#  'r': 479,
#  'site': 480,
#  'australia': 481,
#  'station': 482,
#  'body': 483,
#  '21': 484,
#  'miles': 485,
#  '2013': 486,
#  'developed': 487,
#  'george': 488,
#  'worked': 489,
#  'works': 490,
#  'taken': 491,
#  'playing': 492,
#  'act': 493,
#  'weeks': 494,
#  'modern': 495,
#  'non': 496,
#  'across': 497,
#  're': 498,
#  'close': 499,
#  'television': 500,
#  '28': 501,
#  'st': 502,
#  'mother': 503,
#  'northern': 504,
#  'featured': 505,
#  'special': 506,
#  '50': 507,
#  'eventually': 508,
#  'others': 509,
#  'night': 510,
#  'points': 511,
#  'success': 512,
#  'months': 513,
#  'michael': 514,
#  'america': 515,
#  'get': 516,
#  'recording': 517,
#  'wanted': 518,
#  'france': 519,
#  'don': 520,
#  'ft': 521,
#  'ny': 522,
#  'full': 523,
#  'free': 524,
#  'ground': 525,
#  'soon': 526,
#  'born': 527,
#  'mid': 528,
#  'features': 529,
#  'opening': 530,
#  'return': 531,
#  '19': 532,
#  'ten': 533,
#  'noted': 534,
#  'started': 535,
#  'sea': 536,
#  'case': 537,
#  '27': 538,
#  'performed': 539,
#  'go': 540,
#  'level': 541,
#  'cast': 542,
#  'range': 543,
#  'almost': 544,
#  'additional': 545,
#  'magazine': 546,
#  'every': 547,
#  'remained': 548,
#  'least': 549,
#  'population': 550,
#  '2001': 551,
#  'towards': 552,
#  'help': 553,
#  'australian': 554,
#  'wife': 555,
#  'shot': 556,
#  'originally': 557,
#  'union': 558,
#  'e': 559,
#  'decided': 560,
#  'designed': 561,
#  'turned': 562,
#  'important': 563,
#  'award': 564,
#  'lake': 565,
#  'together': 566,
#  'campaign': 567,
#  '2014': 568,
#  'week': 569,
#  'available': 570,
#  'post': 571,
#  'established': 572,
#  'son': 573,
#  'list': 574,
#  'hit': 575,
#  'nine': 576,
#  'caused': 577,
#  'rather': 578,
#  'section': 579,
#  'fleet': 580,
#  'behind': 581,
#  'brown': 582,
#  'washington': 583,
#  'victory': 584,
#  '26': 585,
#  'bridge': 586,
#  '2005': 587,
#  'provided': 588,
#  'kingdom': 589,
#  'base': 590,
#  'robert': 591,
#  'allowed': 592,
#  'rest': 593,
#  'strong': 594,
#  'association': 595,
#  'future': 596,
#  'going': 597,
#  'reported': 598,
#  'sold': 599,
#  'shows': 600,
#  'above': 601,
#  'charles': 602,
#  'square': 603,
#  'hill': 604,
#  'must': 605,
#  'put': 606,
#  'saw': 607,
#  '40': 608,
#  'initially': 609,
#  'come': 610,
#  'popular': 611,
#  'singles': 612,
#  'either': 613,
#  'action': 614,
#  'addition': 615,
#  'japanese': 616,
#  'told': 617,
#  'plot': 618,
#  'event': 619,
#  'awards': 620,
#  'critics': 621,
#  'council': 622,
#  'groups': 623,
#  'europe': 624,
#  'located': 625,
#  'thus': 626,
#  'runs': 627,
#  'scored': 628,
#  'hot': 629,
#  'training': 630,
#  'does': 631,
#  'successful': 632,
#  'california': 633,
#  'ever': 634,
#  'board': 635,
#  'governor': 636,
#  'japan': 637,
#  'areas': 638,
#  'failed': 639,
#  'replaced': 640,
#  'served': 641,
#  'students': 642,
#  'largest': 643,
#  'command': 644,
#  'damage': 645,
#  'type': 646,
#  'forced': 647,
#  'fourth': 648,
#  'coast': 649,
#  'cup': 650,
#  'material': 651,
#  'dark': 652,
#  'opened': 653,
#  'previously': 654,
#  'rock': 655,
#  'leading': 656,
#  'earlier': 657,
#  '500': 658,
#  'police': 659,
#  'education': 660,
#  'finished': 661,
#  'heavy': 662,
#  'goal': 663,
#  'believed': 664,
#  'becoming': 665,
#  'example': 666,
#  'significant': 667,
#  'david': 668,
#  'whose': 669,
#  'guns': 670,
#  'hall': 671,
#  'real': 672,
#  'elements': 673,
#  'outside': 674,
#  'media': 675,
#  'lines': 676,
#  'films': 677,
#  'railway': 678,
#  'scene': 679,
#  'relationship': 680,
#  'prior': 681,
#  'added': 682,
#  'o': 683,
#  '2003': 684,
#  'parts': 685,
#  'generally': 686,
#  'find': 687,
#  'space': 688,
#  'open': 689,
#  'middle': 690,
#  'grand': 691,
#  'program': 692,
#  'ordered': 693,
#  'extended': 694,
#  'peter': 695,
#  'operation': 696,
#  'society': 697,
#  'mph': 698,
#  'saying': 699,
#  '2002': 700,
#  'big': 701,
#  'joined': 702,
#  'agreed': 703,
#  'critical': 704,
#  'average': 705,
#  'brought': 706,
#  '31': 707,
#  'plan': 708,
#  'committee': 709,
#  'navy': 710,
#  'records': 711,
#  'events': 712,
#  'beginning': 713,
#  'radio': 714,
#  'working': 715,
#  'village': 716,
#  'germany': 717,
#  'henry': 718,
#  'lower': 719,
#  '1998': 720,
#  'interest': 721,
#  'bill': 722,
#  'sound': 723,
#  'far': 724,
#  'proposed': 725,
#  'gun': 726,
#  'hours': 727,
#  'start': 728,
#  'itself': 729,
#  'press': 730,
#  'enough': 731,
#  'summer': 732,
#  'fantasy': 733,
#  'research': 734,
#  '200': 735,
#  'stone': 736,
#  'human': 737,
#  'better': 738,
#  'cyclone': 739,
#  'ended': 740,
#  'region': 741,
#  'chief': 742,
#  '2015': 743,
#  'paul': 744,
#  'give': 745,
#  'gold': 746,
#  'commercial': 747,
#  'stage': 748,
#  'taking': 749,
#  'ranked': 750,
#  'limited': 751,
#  'already': 752,
#  'squadron': 753,
#  'length': 754,
#  'reception': 755,
#  'involved': 756,
#  'studio': 757,
#  'female': 758,
#  'countries': 759,
#  'difficult': 760,
#  'mi': 761,
#  'offered': 762,
#  'episodes': 763,
#  'fifth': 764,
#  'port': 765,
#  'co': 766,
#  'required': 767,
#  '29': 768,
#  'study': 769,
#  'background': 770,
#  'captain': 771,
#  'process': 772,
#  'debut': 773,
#  'idea': 774,
#  'network': 775,
#  'car': 776,
#  'directed': 777,
#  'pacific': 778,
#  'asked': 779,
#  'minister': 780,
#  'blue': 781,
#  'appear': 782,
#  'european': 783,
#  'defeated': 784,
#  'our': 785,
#  'response': 786,
#  'election': 787,
#  'official': 788,
#  'appears': 789,
#  'football': 790,
#  'natural': 791,
#  'operations': 792,
#  'community': 793,
#  'always': 794,
#  'producer': 795,
#  'staff': 796,
#  'past': 797,
#  'passed': 798,
#  'term': 799,
#  'course': 800,
#  'brother': 801,
#  'score': 802,
#  'particularly': 803,
#  'attempt': 804,
#  'review': 805,
#  'uk': 806,
#  'usually': 807,
#  'woman': 808,
#  'thomas': 809,
#  'highest': 810,
#  'view': 811,
#  'writer': 812,
#  'introduced': 813,
#  'district': 814,
#  'cover': 815,
#  'texas': 816,
#  'department': 817,
#  'meeting': 818,
#  'experience': 819,
#  'know': 820,
#  'hand': 821,
#  'met': 822,
#  'crew': 823,
#  'al': 824,
#  'praised': 825,
#  'j': 826,
#  'eastern': 827,
#  'includes': 828,
#  'language': 829,
#  'troops': 830,
#  'pre': 831,
#  'scenes': 832,
#  'person': 833,
#  '2000': 834,
#  'suffered': 835,
#  'novel': 836,
#  'report': 837,
#  'martin': 838,
#  'complete': 839,
#  'change': 840,
#  'god': 841,
#  'especially': 842,
#  'x': 843,
#  'cut': 844,
#  'surface': 845,
#  'carried': 846,
#  'running': 847,
#  'l': 848,
#  'science': 849,
#  'theme': 850,
#  'face': 851,
#  'news': 852,
#  'musical': 853,
#  'business': 854,
#  'loss': 855,
#  'f': 856,
#  'anti': 857,
#  'tower': 858,
#  'turn': 859,
#  'wall': 860,
#  'airport': 861,
#  'fight': 862,
#  'child': 863,
#  'yet': 864,
#  'mission': 865,
#  'infantry': 866,
#  'teams': 867,
#  'influence': 868,
#  'atlantic': 869,
#  'problems': 870,
#  'appearance': 871,
#  'battalion': 872,
#  'listed': 873,
#  'quickly': 874,
#  'attacks': 875,
#  'letter': 876,
#  'mark': 877,
#  'virginia': 878,
#  'food': 879,
#  'latter': 880,
#  'entered': 881,
#  'edward': 882,
#  'shortly': 883,
#  'room': 884,
#  'direct': 885,
#  'done': 886,
#  'buildings': 887,
#  'initial': 888,
#  'commission': 889,
#  'feature': 890,
#  'round': 891,
#  'social': 892,
#  'really': 893,
#  'current': 894,
#  'removed': 895,
#  'homer': 896,
#  'placed': 897,
#  'provide': 898,
#  'lap': 899,
#  'soviet': 900,
#  'numerous': 901,
#  '60': 902,
#  '1999': 903,
#  'keep': 904,
#  'flight': 905,
#  'signed': 906,
#  'sun': 907,
#  'md': 908,
#  'personal': 909,
#  'planned': 910,
#  'v': 911,
#  'indian': 912,
#  'majority': 913,
#  'sometimes': 914,
#  'immediately': 915,
#  'dance': 916,
#  'federal': 917,
#  'independent': 918,
#  'dvd': 919,
#  'stars': 920,
#  'got': 921,
#  'green': 922,
#  'longer': 923,
#  'winning': 924,
#  'deep': 925,
#  'actor': 926,
#  'decision': 927,
#  '1997': 928,
#  'speed': 929,
#  'greatest': 930,
#  'britain': 931,
#  'suggested': 932,
#  'issue': 933,
#  'intended': 934,
#  'india': 935,
#  'morning': 936,
#  'begins': 937,
#  'contract': 938,
#  'oil': 939,
#  'civil': 940,
#  'san': 941,
#  '80': 942,
#  'move': 943,
#  'possible': 944,
#  'key': 945,
#  'jack': 946,
#  'overall': 947,
#  'dead': 948,
#  'minutes': 949,
#  'remaining': 950,
#  'dr': 951,
#  'here': 952,
#  'pressure': 953,
#  'industry': 954,
#  'cross': 955,
#  'brigade': 956,
#  'showed': 957,
#  'minor': 958,
#  'increased': 959,
#  'officer': 960,
#  'energy': 961,
#  'soldiers': 962,
#  'daily': 963,
#  'tracks': 964,
#  'test': 965,
#  'represented': 966,
#  'depression': 967,
#  'earth': 968,
#  'forward': 969,
#  'respectively': 970,
#  'nature': 971,
#  'practice': 972,
#  'trade': 973,
#  'changed': 974,
#  'location': 975,
#  'certain': 976,
#  'individuals': 977,
#  'corps': 978,
#  'word': 979,
#  'friend': 980,
#  'box': 981,
#  'larger': 982,
#  'conference': 983,
#  'might': 984,
#  'structure': 985,
#  'filming': 986,
#  'los': 987,
#  'unable': 988,
#  'smith': 989,
#  'daughter': 990,
#  'married': 991,
#  'chinese': 992,
#  'compared': 993,
#  'appointed': 994,
#  'jackson': 995,
#  'hard': 996,
#  'lack': 997,
#  'market': 998,
#  'movement': 999}

# %%
occurrences,vocab = build_vocabulary(texts,V)
occurrences
# Out:
# most commmon words:
# ['the', 'of', 'and', 'in', 'to', 'a', 'was', 'on', 's', 'as', 'for', 'with', 'that', 'by', 'is', 'he', 'his', 'at', 'it', 'from', 'were', 'an', 'had', 'which', 'be', 'but', 'this', 'are', 'first', 'not', 'after', 'also', 'one', 'their', 'two', 'her', 'its', 'they', 'or', 'who', 'when', 'have', 'new', 'has', 'she', 'been', 'would', 'other', 'i', 'during', 'time', 'all', 'more', 'into', '1', 'game', 'over', 'most', 'him', 'while', 'only', 'than', 'between', 'later', 'up', 'out', '2', 'three', 'about', 'before', 'film', 'there', 'such', 'some', 'may', 'made', '000', 'world', 'year', 'where', 'series', 'through', 'second', '3', 'season', 'years', 'no', 'them', 'm', 'used', 'these', 'became', 'state', 'war', 'however', 'being', 'music', 'can', 'several', 'against', 'then', 'many', 'city', 'album', '5', 'number', 'including', 'both', 'song', 'four', 'north', '4', 'part', 'team', 'south', 'did', 'united', 'well', 'because', 'early', 'following', 'under', 'episode', 'day', 'american', 'so', 'states', 'high', 'work', 'us', 'known', 'said', 'like', 'began', 'until', 't', 'released', 'same', 'although', 'five', 'end', '6', 'west', 'people', 'around', 'could', 'each', 'john', 'if', 'use', 'national', 'another', 'along', 'since', '10', 'single', 'found', 'long', 'school', 'called', 'back', 'took', 'any', 'july', 'million', 'show', 'area', 'best', 'august', '7', 'system', 'life', 'east', 'group', 'just', 'video', 'due', 'november', 'will', 'now', 'british', 'times', 'based', 'october', 'final', 'history', 'received', 'september', 'june', 'you', 'march', 'what', '12', 'production', 'line', 'six', 'games', 'large', 'third', 'off', 'major', 'character', '8', 'king', 'general', 'km', 'top', 'home', 'won', '0', 'route', 'april', '9', 'century', 'included', 'make', 'house', 'built', 'player', 'u', 'described', 'played', 'family', 'main', 'species', 'battle', 'down', 'near', 'original', 'government', 'much', 'army', 'members', 'place', 'road', 'york', 'those', '11', 'last', 'own', '20', 'within', 'we', 'left', 'band', 'story', 'service', 'club', 'set', 'white', 'side', 'death', 'late', 'way', 'named', 'december', 'january', 'february', 'small', 'according', 'name', 'ship', '15', '2010', 'though', 'days', 'having', 'public', 'german', 'very', 'form', 'again', 'do', 'company', 'old', 'university', 'record', 'street', 'division', 'county', '100', 'led', 'point', 'held', '2008', 'wrote', '30', 'among', 'still', 'next', 'de', 'release', 'men', 'man', 'highway', 'track', 'military', 'book', 'park', 'former', 'further', 'order', 'building', 'career', 'black', 'even', 'little', '2011', 'characters', 'force', 'river', 'party', 'power', 'often', 'continued', 'french', 'lost', 'my', '2007', 'himself', 'never', 'songs', 'great', 'match', 'b', 'air', 'half', 'came', 'england', 'president', 'play', '18', 'championship', '16', 'court', 'right', '13', 'different', 'similar', '2012', 'h', 'version', 'london', 'despite', 'women', 'ii', 'water', 'international', 'short', 'forces', 'tropical', 'using', 'love', 'storm', 'take', 'period', 'english', 'role', 'western', 'without', 'how', 'moved', 'considered', 'few', 'good', 'published', 'went', 'star', 'become', '2009', 'development', 'country', 'c', 'field', 'recorded', 'written', 'james', 'town', 'construction', 'class', 'support', 'local', 'children', 'red', 'league', 'away', 'throughout', 'feet', 'tour', '14', 'lead', 'given', 'land', 'father', 'gave', 'less', 'returned', 'died', '2006', 'players', 'run', 'light', 'fire', '25', 'design', 'various', 'attack', 'killed', 'instead', 'performance', 'total', 'include', 'church', '17', 'd', 'island', 'royal', 'southern', 'ships', 'sent', 'felt', 'race', 'control', 'hurricane', 'appeared', 'title', 'style', 'produced', 'should', 'office', 'too', 'stated', 'central', 'political', 'member', 'me', 'chart', 'seen', 'present', 'william', 'eight', 'able', 'previous', 'college', 'common', 'win', 'live', 'created', 'seven', '24', 'aircraft', 'center', 'once', 'age', 'head', 'front' ...
# Counter({'following': 324,
#          'the': 35377,
#          'death': 176,
#          'of': 14994,
#          'finan': 1,
#          'bishop': 23,
#          'lindisfarne': 1,
#          'alhfrith': 1,
#          'deira': 1,
#          'in': 12074,
#          'collusion': 3,
#          'with': 3738,
#          'wilfred': 5,
#          'york': 186,
#          'agilbert': 1,
#          'wessex': 1,
#          'and': 13832,
#          'others': 101,
#          'were': 1868,
#          'determined': 31,
#          'to': 11022,
#          'persuade': 8,
#          'oswiu': 2,
#          'rule': 41,
#          'favour': 8,
#          'roman': 44,
#          'rite': 7,
#          'christianity': 15,
#          'within': 181,
#          'kingdoms': 4,
#          'over': 601,
#          'which': 1525,
#          'he': 2713,
#          'had': 1615,
#          'imperium': 7,
#          'case': 96,
#          'was': 5883,
#          'debated': 2,
#          's': 4221,
#          'presence': 38,
#          'at': 2479,
#          'synod': 3,
#          'whitby': 3,
#          '664': 2,
#          'colmán': 2,
#          'hild': 1,
#          'cedd': 1,
#          'defending': 9,
#          'celtic': 6,
#          'tradition': 25,
#          'inherited': 9,
#          'from': 2430,
#          'aidan': 2,
#          'wilifred': 1,
#          'speaking': 22,
#          'for': 3851,
#          'position': 111,
#          'cause': 51,
#          'prevailed': 4,
#          'former': 160,
#          'division': 168,
#          'ecclesiastical': 6,
#          'authorities': 27,
#          'set': 177,
#          'aside': 14,
#          'those': 185,
#          'who': 881,
#          'could': 260,
#          'not': 1126,
#          'accept': 24,
#          'it': 2461,
#          'including': 361,
#          'departed': 18,
#          'elsewhere': 18,
#          'language': 65,
#          'warriors': 10,
#          'retreated': 13,
#          'prophetstown': 1,
#          'where': 426,
#          'according': 174,
#          'one': 1015,
#          'chief': 72,
#          'account': 37,
#          'confronted': 7,
#          'tenskwatawa': 1,
#          'accused': 22,
#          'him': 562,
#          'deceit': 2,
#          'because': 328,
#          'many': 367,
#          'deaths': 19,
#          'his': 2607,
#          'spells': 4,
#          'supposed': 17,
#          'have': 859,
#          'prevented': 15,
#          'blamed': 6,
#          'wife': 94,
#          'desecrating': 1,
#          'magic': 19,
#          'medicine': 21,
#          'offered': 70,
#          'cast': 95,
#          'a': 9897,
#          'new': 847,
#          'spell': 10,
#          'insisted': 19,
#          'that': 3690,
#          'launch': 31,
#          'second': 421,
#          'attack': 125,
#          'but': 1213,
#          'they': 973,
#          'refused': 40,
#          'feudal': 7,
#          'japan': 81,
#          'taiko': 3,
#          'often': 151,
#          'used': 394,
#          'motivate': 1,
#          'troops': 65,
#          'call': 46,
#          'out': 527,
#          'orders': 37,
#          'or': 936,
#          'announcements': 4,
#          'marching': 4,
#          'pace': 17,
#          'marches': 2,
#          'usually': 67,
#          'six': 207,
#          'paces': 1,
#          'per': 108,
#          'beat': 32,
#          'drum': 28,
#          'during': 718,
#          '16th': 21,
#          'century': 198,
#          'warring': 3,
#          'states': 308,
#          'period': 139,
#          'specific': 38,
#          'calls': 25,
#          'communicate': 4,
#          'retreating': 4,
#          'advancing': 14,
#          'other': 734,
#          'rhythms': 2,
#          'techniques': 23,
#          'detailed': 19,
#          'texts': 6,
#          'war': 387,
#          'chronicle': 14,
#          'gunji': 1,
#          'yoshū': 1,
#          'nine': 90,
#          'sets': 31,
#          'five': 275,
#          'beats': 19,
#          'would': 750,
#          'summon': 2,
#          'an': 1815,
#          'ally': 10,
#          'battle': 191,
#          'while': 552,
#          'three': 510,
#          'sped': 1,
#          'up': 528,
#          'four': 354,
#          'times': 217,
#          'advance': 51,
#          'pursue': 14,
#          'enemy': 53,
#          'folklore': 4,
#          'on': 4257,
#          'legendary': 4,
#          '6th': 22,
#          'emperor': 45,
#          'keitai': 1,
#          'offers': 31,
#          'story': 178,
#          'obtained': 20,
#          'large': 206,
#          'china': 42,
#          'named': 175,
#          'senjin': 1,
#          'daiko': 2,
#          '線陣太鼓': 1,
#          'front': 112,
#          'thought': 112,
#          'both': 358,
#          'encourage': 13,
#          'own': 182,
#          'army': 190,
#          'intimidate': 2,
#          'enemies': 30,
#          '2012': 143,
#          'la': 34,
#          'música': 2,
#          'no': 412,
#          'se': 2,
#          'toca': 1,
#          'several': 377,
#          'weeks': 104,
#          'afterward': 5,
#          'wilson': 48,
#          'absent': 9,
#          'television': 103,
#          'due': 222,
#          'personal': 60,
#          'issues': 47,
#          'she': 825,
#          'attend': 21,
#          'off': 205,
#          'screen': 41,
#          'november': 222,
#          '28': 103,
#          'returned': 127,
#          'group': 225,
#          'participate': 15,
#          'woman': 67,
#          'tag': 27,
#          'team': 346,
#          'match': 148,
#          'dog': 28,
#          'chloe': 2,
#          'became': 388,
#          'official': 68,
#          'member': 117,
#          'december': 175,
#          '26': 88,
#          'when': 867,
#          'interfered': 3,
#          'victoria': 38,
#          'matches': 36,
#          'first': 1129,
#          'her': 977,
#          'wwe': 33,
#          'com': 18,
#          'profile': 12,
#          'taboo': 2,
#          'tuesday': 8,
#          'candice': 3,
#          'michelle': 7,
#          'eliminated': 19,
#          'fulfill': 2,
#          'your': 51,
#          'fantasy': 73,
#          'royal': 122,
#          'women': 141,
#          'championship': 144,
#          'by': 3418,
#          'rival': 14,
#          'ashley': 4,
#          'massaro': 1,
#          'chart': 116,
#          'performance': 124,
#          'notable': 33,
#          'people': 263,
#          'as': 3989,
#          '2014': 92,
#          'travelers': 3,
#          'use': 249,
#          'either': 84,
#          'us': 298,
#          '31': 75,
#          'through': 423,
#          'grand': 76,
#          'haven': 11,
#          '68th': 1,
#          'avenue': 36,
#          'eastmanville': 1,
#          'cross': 57,
#          'river': 154,
#          'ottawa': 10,
#          'county': 168,
#          'highway': 163,
#          'part': 353,
#          'long': 244,
#          'range': 95,
#          'plan': 75,
#          'build': 44,
#          'bypass': 10,
#          'provides': 31,
#          'crossing': 26,
#          'almost': 95,
#          'equidistant': 1,
#          'between': 531,
#          'two': 998,
#          'greatly': 17,
#          'reducing': 8,
#          'drive': 46,
#          'areas': 81,
#          'north': 354,
#          'south': 333,
#          'nunica': 1,
#          'robinson': 21,
#          'is': 2889,
#          '20': 182,
#          'mile': 36,
#          '32': 32,
#          'km': 202,
#          'trip': 32,
#          'route': 200,
#          'closer': 21,
#          'seven': 114,
#          'miles': 105,
#          '11': 184,
#          'length': 71,
#          'called': 242,
#          'm': 395,
#          '231': 5,
#          'this': 1205,
#          'scaled': 4,
#          'down': 191,
#          'even': 156,
#          'though': 172,
#          'will': 222,
#          'physically': 9,
#          'connect': 14,
#          'january': 175,
#          '4': 354,
#          '2013': 105,
#          'mdot': 4,
#          'completed': 110,
#          'work': 303,
#          'bridge': 88,
#          'cedar': 7,
#          'additional': 95,
#          'ramps': 2,
#          'i': 719,
#          '96': 27,
#          '104': 16,
#          'interchange': 28,
#          'reconstruction': 9,
#          'widening': 6,
#          'near': 191,
#          'department': 66,
#          'also': 1049,
#          'reconfiguration': 1,
#          'intersection': 40,
#          'cleveland': 17,
#          'carries': 10,
#          'expected': 51,
#          'date': 50,
#          'completion': 19,
#          'sometime': 4,
#          '2016': 45,
#          'pending': 6,
#          'funding': 30,
#          'availability': 7,
#          'planned': 60,
#          '1': 607,
#          '2': 522,
#          '3': 420,
#          'starting': 49,
#          'bridges': 23,
#          'little': 156,
#          'creek': 42,
#          '2005': 88,
#          'safetea': 1,
#          'lu': 7,
#          'transportation': 27,
#          'bill': 74,
#          'provided': 88,
#          'earmarked': 3,
#          'project': 106,
#          'representative': 14,
#          'pete': 11,
#          'hoekstra': 1,
#          'holland': 7,
#          'well': 329,
#          'matching': 5,
#          'funds': 19,
#          'state': 388,
#          'michigan': 47,
#          'jobs': 21,
#          'today': 46,
#          'program': 76,
#          'total': 124,
#          'cost': 52,
#          'be': 1291,
#          '150': 32,
#          'million': 238,
#          'october': 216,
#          '30': 166,
#          '2015': 72,
#          'opened': 80,
#          'traffic': 43,
#          'maybe': 6,
#          'angelo': 3,
#          'brovelli': 1,
#          'do': 169,
#          'caenorhabditis': 2,
#          'elegans': 4,
#          'ˌseɪnoʊræbˈdaɪtəs': 1,
#          'ˈɛləɡænz': 1,
#          'free': 98,
#          'living': 53,
#          'parasitic': 4,
#          'transparent': 3,
#          'nematode': 2,
#          'roundworm': 1,
#          'about': 487,
#          'mm': 106,
#          'lives': 39,
#          'temperate': 8,
#          'soil': 21,
#          'environments': 13,
#          'name': 174,
#          'blend': 5,
#          'greek': 53,
#          'caeno': 1,
#          'recent': 43,
#          'rhabditis': 1,
#          'rod': 7,
#          'like': 287,
#          'latin': 37,
#          'elegant': 3,
#          '1900': 21,
#          'maupas': 1,
#          'initially': 85,
#          'rhabditides': 1,
#          'osche': 1,
#          'placed': 61,
#          'subgenus': 2,
#          '1952': 23,
#          '1955': 24,
#          'dougherty': 3,
#          'raised': 42,
#          'status': 46,
#          'genus': 45,
#          'provide': 61,
#          'forward': 56,
#          'protection': 31,
#          'railway': 77,
#          'construction': 132,
#          'workers': 53,
#          'infrastructure': 12,
#          '5th': 14,
#          'mounted': 31,
#          'brigade': 57,
#          'ordered': 76,
#          'move': 58,
#          'katia': 4,
#          'early': 327,
#          'april': 199,
#          'however': 385,
#          'signs': 14,
#          'renewed': 7,
#          'ottoman': 33,
#          'activity': 32,
#          'area': 236,
#          'detected': 9,
#          'result': 107,
#          'light': 126,
#          'horse': 40,
#          'regiment': 52,
#          'reinforce': 7,
#          'arrive': 19,
#          '24': 114,
#          'goodbye': 9,
#          'michael': 100,
#          'features': 97,
#          'references': 28,
#          'previous': 115,
#          'episodes': 70,
#          'scene': 77,
#          'puts': 3,
#          'dundie': 1,
#          'desk': 4,
#          'homage': 7,
#          'final': 216,
#          'shot': 94,
#          'series': 426,
#          'opening': 97,
#          'sequence': 42,
#          'obsession': 5,
#          'basketball': 37,
#          'wanting': 12,
#          'baler': 1,
#          'serves': 16,
#          'reference': 41,
#          'season': 419,
#          'episode': 319,
#          'safety': 42,
#          'training': 82,
#          'respectively': 56,
#          'character': 204,
#          'ping': 1,
#          'appears': 68,
#          'having': 171,
#          'previously': 80,
#          'appeared': 120,
#          'dundies': 1,
#          'seminar': 1,
#          'featured': 102,
#          'reforming': 2,
#          'party': 153,
#          'planning': 33,
#          'committee': 75,
#          'after': 1059,
#          'being': 382,
#          'broken': 36,
#          'moroccan': 5,
#          'christmas': 32,
#          'briefly': 34,
#          'showed': 57,
#          'creed': 6,
#          'continual': 2,
#          'habit': 5,
#          'using': 140,
#          'bathroom': 4,
#          'seen': 116,
#          'appreciation': 9,
#          'gives': 31,
#          'darryl': 7,
#          'book': 161,
#          'somehow': 5,
#          'manage': 8,
#          'originally': 94,
#          'mentioned': 28,
#          'happy': 20,
#          'hour': 47,
#          'callbacks': 1,
#          'are': 1203,
#          'made': 448,
#          'phyllis': 4,
#          'gift': 8,
#          'homemade': 2,
#          'sewn': 2,
#          'mittens': 1,
#          'dwight': 25,
#          'play': 145,
#          'paintball': 3,
#          'pam': 11,
#          'british': 218,
#          'version': 142,
#          'office': 119,
#          'tim': 22,
#          'canterbury': 10,
#          'proclaims': 3,
#          'love': 140,
#          'dawn': 11,
#          'tinsley': 1,
#          'meeting': 66,
#          'room': 62,
#          'turns': 25,
#          'microphone': 2,
#          'so': 312,
#          'cameras': 11,
#          'pick': 13,
#          'only': 550,
#          'their': 1012,
#          'reactions': 14,
#          'sound': 74,
#          'referenced': 5,
#          'fifth': 70,
#          'finale': 9,
#          'company': 169,
#          'picnic': 3,
#          'rebirth': 6,
#          'officially': 41,
#          'announced': 108,
#          '2004': 106,
#          'week': 92,
#          'game': 605,
#          'title': 120,
#          'existence': 21,
#          'been': 787,
#          'leaked': 10,
#          'public': 171,
#          'jump': 15,
#          'magazine': 95,
#          'available': 92,
#          'mistakenly': 2,
#          'shipped': 6,
#          'july': 239,
#          'namco': 1,
#          'pre': 65,
#          'tales': 9,
#          'symphonia': 3,
#          'playstation': 27,
#          'receive': 17,
#          'bonus': 20,
#          'disc': 29,
#          'featuring': 34,
#          'footage': 39,
#          'upon': 106,
#          'purchasing': 4,
#          'september': 213,
#          'same': 281,
#          'along': 247,
#          'playable': 15,
#          'present': 116,
#          'tokyo': 20,
#          'show': 237,
#          'month': 53,
#          'released': 283,
#          '16': 144,
#          'ign': 26,
#          'reported': 86,
#          'likely': 48,
#          'candidate': 22,
#          'english': 139,
#          'localization': 3,
#          'america': 100,
#          'high': 305,
#          'reception': 71,
#          'sales': 47,
#          'nintendo': 38,
#          'gamecube': 3,
#          'portable': 4,
#          'port': 70,
#          'graphical': 3,
#          'adjustments': 1,
#          'platform': 20,
#          'widescreen': 1,
#          '2007': 149,
#          'destiny': 16,
#          'games': 207,
#          'transplanting': 1,
#          '2d': 10,
#          'graphics': 21,
#          'onto': 36,
#          'psp': 3,
#          'maintaining': 9,
#          'experience': 66,
#          'original': 191,
#          'caused': 90,
#          'some': 460,
#          'difficulties': 19,
#          'conversely': 5,
#          'found': 245,
#          'memory': 32,
#          'capacity': 32,
#          'compared': 55,
#          'ps2': 2,
#          'good': 137,
#          'thing': 41,
#          'yoshizumi': 1,
#          'felt': 121,
#          'fact': 49,
#          'rather': 90,
#          'than': 539,
#          'remake': 7,
#          'divided': 42,
#          'development': 136,
#          'included': 198,
#          'extra': 26,
#          'minor': 57,
#          'scenes': 65,
#          'viewing': 8,
#          'gallery': 14,
#          'concept': 43,
#          'art': 107,
#          'neither': 19,
#          'nor': 23,
#          'received': 214,
#          'making': 107,
#          'mainline': 4,
#          'titles': 36,
#          'come': 85,
#          'west': 265,
#          'chronicles': 5,
#          'riddick': 3,
#          'escape': 36,
#          'butcher': 5,
#          'bay': 39,
#          'person': 65,
#          'action': 84,
#          'stealth': 2,
#          'video': 224,
#          'developed': 105,
#          'starbreeze': 1,
#          'studios': 51,
#          'published': 137,
#          'vivendi': 1,
#          'xbox': 19,
#          'windows': 26,
#          'tie': 24,
#          'prequel': 10,
#          'futuristic': 6,
#          'science': 64,
#          'fiction': 47,
#          'film': 480,
#          'actor': 59,
#          'vin': 3,
#          'diesel': 6,
#          'involved': 71,
#          'reprises': 2,
#          'role': 139,
#          'protagonist': 17,
#          'richard': 53,
#          'b': 148,
#          'additionally': 24,
#          'julee': 1,
#          'cruise': 7,
#          'recorded': 133,
#          'theme': 64,
#          'twin': 26,
#          'peaks': 8,
#          'slower': 6,
#          'extended': 76,
#          'psych': 1,
#          'song': 358,
#          'know': 66,
#          'you': 212,
#          'creator': 14,
#          'steve': 19,
#          'franks': 5,
#          'band': 179,
#          'friendly': 14,
#          'indians': 9,
#          'imagery': 10,
#          'accompanies': 1,
#          'recreation': 12,
#          'white': 177,
#          'resembles': 4,
#          'sarah': 14,
#          'palmer': 8,
#          'vision': 29,
#          'before': 483,
#          'maddy': 1,
#          'ferguson': 7,
#          'later': 531,
#          'bicycle': 7,
#          'chase': 17,
#          'baby': 25,
#          'did': 331,
#          'bad': 40,
#          'chris': 38,
#          'isaak': 2,
#          'heard': 35,
#          'portrayed': 19,
#          'special': 102,
#          'agent': 26,
#          'chester': 9,
#          'desmond': 5,
#          'fire': 126,
#          'walk': 18,
#          'me': 117,
#          '1884': 10,
#          'navy': 75,
#          'midshipmen': 3,
#          'football': 68,
#          'felipe': 1,
#          'massa': 3,
#          'failed': 81,
#          'lap': 61,
#          'time': 716,
#          'stopping': 6,
#          'circuit': 26,
#          'qualifying': 5,
#          'session': 34,
#          'world': 441,
#          'severe': 43,
#          'effect': 41,
#          'stanford': 7,
#          'frightened': 3,
#          'air': 148,
#          'raids': 13,
#          'london': 142,
#          'windsor': 11,
#          'avoid': 37,
#          'them': 399,
#          'pupils': 13,
#          'casualties': 29,
#          'fighting': 52,
#          'arthur': 27,
#          'bliss': 3,
#          'injured': 40,
#          'ivor': 1,
#          'gurney': 1,
#          'gassed': 1,
#          'george': 105,
#          'butterworth': 5,
#          'killed': 125,
#          'annual': 51,
#          'rcm': 1,
#          'operatic': 3,
#          'production': 210,
#          'supervised': 1,
#          'conducted': 37,
#          'every': 95,
#          'year': 441,
#          'since': 247,
#          '1885': 8,
#          'cancelled': 9,
#          'income': 23,
#          'declined': 38,
#          'fall': 44,
#          'student': 48,
#          'numbers': 42,
#          'college': 115,
#          'reduced': 33,
#          'demand': 24,
#          'services': 54,
#          'serious': 35,
#          'disagreement': 6,
#          'end': 272,
#          '1916': 27,
#          'relationship': 77,
#          'parry': 6,
#          'deteriorated': 1,
#          'point': 167,
#          'hostility': 7,
#          'magnanimity': 1,
#          'came': 146,
#          'fore': 7,
#          'died': 127,
#          'years': 416,
#          'successfully': 35,
#          'lobbied': 6,
#          'buried': 31,
#          'st': 103,
#          'paul': 72,
#          'cathedral': 18,
#          'pier': 9,
#          'projects': 24,
#          'seafront': 1,
#          'clevedon': 1,
#          'into': 642,
#          'severn': 2,
#          'estuary': 4,
#          'separates': 3,
#          'england': 146,
#          'wales': 46,
#          'toll': 5,
#          'house': 194,
#          'entry': 26,
#          'fees': 9,
#          'collected': 21,
#          'adjacent': 27,
#          'hotel': 36,
#          'known': 294,
#          'rock': 80,
#          'built': 194,
#          '1823': 6,
#          'thomas': 67,
#          'hollyman': 1,
#          'garfield': 8,
#          'prior': 77,
#          'walter': 18,
#          'tony': 26,
#          'kushner': 1,
#          'angels': 17,
#          'national': 249,
#          'theatre': 26,
#          'lyttelton': 1,
#          '2017': 2,
#          'directed': 69,
#          'marianne': 1,
#          'elliott': 7,
#          'co': 70,
#          'starring': 15,
#          'russell': 16,
#          'tovey': 1,
#          'denise': 3,
#          'gough': 2,
#          'release': 165,
#          'physical': 45,
#          'single': 246,
#          'quite': 25,
#          'career': 159,
#          'peter': 76,
#          'renowned': 7,
#          'learning': 19,
#          'passion': 10,
#          'reading': 30,
#          'discussions': 11,
#          'scholars': 13,
#          'speaker': 12,
#          'eloquent': 2,
#          'persuasive': 4,
#          'procopius': 1,
#          'fitted': 17,
#          'nature': 56,
#          'men': 164,
#          'cassiodorus': 1,
#          'witnessed': 5,
#          'embassies': 2,
#          'ostrogoth': 1,
#          'court': 144,
#          'praises': 5,
#          'vir': 1,
#          'eloquentissimus': 1,
#          'disertissimus': 1,
#          'most': 569,
#          'man': 164,
#          'sapientissimus': 1,
#          'wise': 2,
#          'hand': 66,
#          'late': 176,
#          'historian': 32,
#          'menander': 1,
#          'protector': 4,
#          'relied': 9,
#          'history': 216,
#          'accuses': 3,
#          'boastfulness': 1,
#          'rewriting': 1,
#          'records': 75,
#          'enhance': 4,
#          'negotiations': 14,
#          'persians': 2,
#          'modern': 104,
#          'chess': 11,
#          'tournament': 35,
#          'organized': 23,
#          'howard': 37,
#          'staunton': 5,
#          'leading': 80,
#          'player': 194,
#          'held': 167,
#          '1851': 7,
#          'won': 201,
#          'german': 171,
#          'adolf': 3,
#          'anderssen': 3,
#          'hailed': 6,
#          'master': 31,
#          'brilliant': 9,
#          'energetic': 4,
#          'attacking': 21,
#          'style': 120,
#          'typical': 23,
#          'sparkling': 1,
#          'immortal': 3,
#          'evergreen': 3,
#          'morphy': 1,
#          'opera': 30,
#          'regarded': 33,
#          'highest': 67,
#          'possible': 58,
#          'summit': 12,
#          'twelfth': 7,
#          'night': 101,
#          '1600': 2,
#          '1601': 2,
#          'shakespeare': 8,
#          'alluded': 3,
#          'wright': 11,
#          'molyneux': 1,
#          'map': 9,
#          'maria': 26,
#          'says': 37,
#          'malvolio': 1,
#          'does': 82,
#          'smile': 10,
#          'face': 64,
#          'more': 649,
#          'lynes': 1,
#          'mappe': 1,
#          'augmentation': 1,
#          'indies': 11,
#          'jordan': 19,
#          'twelve': 47,
#          'administrative': 16,
#          'divisions': 24,
#          'each': 260,
#          'governorate': 2,
#          'amman': 1,
#          'divides': 4,
#          'nahias': 2,
#          'districts': 19,
#          'further': 160,
#          'neighborhoods': 6,
#          'lying': 11,
#          'suburbs': 10,
#          'villages': 22,
#          'towns': 24,
#          'luxury': 6,
#          'southern': 122,
#          'seas': 15,
#          'far': 74,
#          'cry': 12,
#          'cramped': 1,
#          'quarters': 8,
#          'old': 169,
#          'xpbs': 1,
#          'remained': 95,
#          'aboard': 23,
#          'reveling': 1,
#          'comforts': 2,
#          'enjoyed': 24,
#          'pan': 6,
#          'am': 46,
#          'customers': 11,
#          'yacht': 4,
#          'service': 178,
#          'zealand': 41,
#          'discontinued': 2,
#          'turned': 93,
#          'sverdrup': 1,
#          'serve': 41,
#          'floating': 11,
#          'follow': 47,
#          'around': 262,
#          'among': 166,
#          ...})

# %%
# expected results
occurrences.most_common(10)
# Out:
# [('the', 35377),
#  ('of', 14994),
#  ('and', 13832),
#  ('in', 12074),
#  ('to', 11022),
#  ('a', 9897),
#  ('was', 5883),
#  ('on', 4257),
#  ('s', 4221),
#  ('as', 3989)]

# %%
# expected results
len(occurrences)
# Out:
# 39030

# %%
def vectorize_texts(token_text, vocab) -> list[list[int]]:
    """Convert texts into sequences of integer identifiers based on the vocabulary."""
    return [[vocab[word] for word in token_text if word in vocab]]

# %%
vectorized_texts = vectorize_texts(texts[0], vocab)

# %%
vectorized_texts
# Out:
# [[120,
#   0,
#   251,
#   1,
#   1,
#   1,
#   3,
#   11,
#   1,
#   235,
#   1,
#   2,
#   509,
#   20,
#   4,
#   4,
#   3,
#   1,
#   0,
#   1,
#   241,
#   0,
#   56,
#   23,
#   15,
#   22,
#   0,
#   537,
#   6,
#   3,
#   8,
#   17,
#   0,
#   1,
#   3,
#   11,
#   2,
#   0,
#   2,
#   0,
#   19,
#   2,
#   10,
#   0,
#   457,
#   0,
#   2,
#   0,
#   299,
#   278,
#   1,
#   6,
#   248,
#   236,
#   39,
#   145,
#   29,
#   18,
#   106]]

# %% [markdown]
# ### Self-supervision: input and targets from raw text
#
# using `window_size=2`, iterate through the tokenized data and collect indices of target word $w$ and positive context words $c_+$
#
# After debugging, apply this function to all text in dataset

# %%
word_contexts = []
window_size=2

# %%
def collect_context_pairs(vectorized_texts: list[list[int]], window_size: int = 2) -> list[tuple[int, int]]:
    """Collects (target, context) pairs from vectorized texts using a given window size."""
    context_pairs = []
    for text in vectorized_texts:
        for i, target in enumerate(text):
            left = max(i - window_size, 0)
            right = min(i + window_size + 1, len(text))

            for j in range(left, right):
                if i != j:  # Ne pas inclure le mot cible lui-même comme contexte
                    context_pairs.append((target, text[j]))

    return context_pairs

# %%
word_contexts = collect_context_pairs(vectorized_texts, window_size=2)

# %%
word_contexts[:10]
# Out:
# [(120, 0),
#  (120, 251),
#  (0, 120),
#  (0, 251),
#  (0, 1),
#  (251, 120),
#  (251, 0),
#  (251, 1),
#  (251, 1),
#  (1, 0)]

# %%
len(word_contexts)
# Out:
# 230

# %%
len(vectorized_texts)
# Out:
# 1

# %%
def collect_context_pairs_for_all(lists,vocabulary,window_size_number):
  collect=[]
  #print(f'len :: {len(lists)}')
  for i in range(len(lists)):
    vectorized_texts = vectorize_texts(lists[i], vocabulary)
    word_contexts = collect_context_pairs(vectorized_texts, window_size=window_size_number)
    #print(f'word  {word_contexts}')
    collect.extend(word_contexts)
    #print(len(collect))
  return collect

# %%
words_contexts=collect_context_pairs_for_all(lists=texts,vocabulary=vocab,window_size_number=2)

# %%
len(words_contexts)
# Out:
# 1202312

# %%
len(words_contexts)
# Out:
# 1202312

# %% [markdown]
# ### DataLoader
#
# `torch.utils.data.DataLoader` provides a convenient interface for batching and randomly sampling data.
#
# use `batch_size=1024` to wrap the above generate data
#
# and `drop_last=True` so that the batch has always the same size

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# %%
# Convertir les paires (w, c+) en tenseurs PyTorch
def create_dataloader(context_pairs, batch_size=1024, drop_last=True):
    """Wraps context pairs into a PyTorch DataLoader for batching."""
    targets, contexts = zip(*context_pairs)  # Sépare les cibles et les contextes

    # Conversion en tenseurs
    targets_tensor = torch.tensor(targets, dtype=torch.long)
    contexts_tensor = torch.tensor(contexts, dtype=torch.long)

    # Création du dataset PyTorch
    dataset = TensorDataset(targets_tensor, contexts_tensor)

    # Création du DataLoader
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=drop_last)
    #print(f'data loader ::{dataloader}')
    return dataloader

# %%
# Définition des paramètres
BATCH_SIZE = 1024

# Création du DataLoader
dataloader = create_dataloader(words_contexts, batch_size=BATCH_SIZE, drop_last=True)

# Afficher un batch pour vérification
for batch in dataloader:
    print(f'{batch}')
    target_batch, context_batch = batch
    print("Target batch shape:", target_batch.shape)
    print("Context batch shape:", context_batch.shape)
    print("Example batch (targets, contexts):", list(zip(target_batch[:5].tolist(), context_batch[:5].tolist())))
# Out:
# data loader ::<torch.utils.data.dataloader.DataLoader object at 0x7e44ea3a6850>
# [tensor([ 14,  14,  10,  ...,   3,  10, 322]), tensor([ 1, 55,  5,  ..., 76, 17,  6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(14, 1), (14, 55), (10, 5), (860, 2), (18, 3)]
# [tensor([268,  13,  63,  ...,   0,   0, 808]), tensor([753,  10,  12,  ...,   3, 316,   8])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(268, 753), (13, 10), (63, 12), (121, 906), (6, 119)]
# [tensor([699, 719,  49,  ...,  24,  12, 793]), tensor([ 12,   0,   2,  ...,  89, 934,  67])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(699, 12), (719, 0), (49, 2), (67, 65), (525, 9)]
# [tensor([ 92,  12,  10,  ...,   9,  16, 102]), tensor([767,  21,  51,  ...,  72,   2, 526])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(92, 767), (12, 21), (10, 51), (145, 23), (65, 4)]
# [tensor([687,   3, 235,  ...,   8,  42,  12]), tensor([ 43,   0,   2,  ..., 173, 813,  26])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(687, 43), (3, 0), (235, 2), (988, 6), (671, 0)]
# [tensor([ 17, 918, 586,  ...,   6,  49,   3]), tensor([ 0,  0, 42,  ..., 67,  8,  1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(17, 0), (918, 0), (586, 42), (46, 4), (48, 345)]
# [tensor([ 92,  32,  34,  ...,  41, 102,  47]), tensor([282, 131,   5,  ...,   0,   3, 570])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(92, 282), (32, 131), (34, 5), (163, 7), (806, 436)]
# [tensor([  0,   1, 603,  ..., 401,   8, 251]), tensor([489,  33,   0,  ..., 529, 990, 134])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 489), (1, 33), (603, 0), (270, 1), (1, 0)]
# [tensor([  3, 126, 965,  ...,   3, 118,   3]), tensor([  2, 177,  17,  ..., 558,   5,  96])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 2), (126, 177), (965, 17), (52, 4), (16, 865)]
# [tensor([329,   0,   5,  ..., 513, 837, 245]), tensor([ 1,  3,  2,  ...,  0,  1, 72])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(329, 1), (0, 3), (5, 2), (785, 3), (264, 429)]
# [tensor([  2,  21,  26,  ..., 379,   2, 132]), tensor([  3,  64, 118,  ...,   8, 602, 124])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 3), (21, 64), (26, 118), (37, 606), (380, 19)]
# [tensor([134,   0,  22,  ...,  45,  18, 386]), tensor([ 12, 250,   0,  ..., 392,   3, 624])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(134, 12), (0, 250), (22, 0), (39, 518), (378, 0)]
# [tensor([  0,  11,   0,  ...,  97,  19, 173]), tensor([ 22, 749, 263,  ...,  13,   0,  14])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 22), (11, 749), (0, 263), (729, 10), (10, 0)]
# [tensor([211,   8,   5,  ...,  14,   0, 883]), tensor([ 1,  2, 32,  ..., 71, 46,  0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(211, 1), (8, 2), (5, 32), (252, 134), (4, 0)]
# [tensor([359,   2,  32,  ..., 116,   3,  10]), tensor([254,  14,  23,  ..., 635, 384, 303])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(359, 254), (2, 14), (32, 23), (39, 0), (364, 125)]
# [tensor([  8,  26, 166,  ...,   6,   0, 332]), tensor([ 69,  12,   3,  ..., 656, 351, 113])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(8, 69), (26, 12), (166, 3), (582, 7), (5, 13)]
# [tensor([790,   0,  21,  ..., 707,   6,   2]), tensor([ 23,   1,   1,  ..., 504, 263,  12])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(790, 23), (0, 1), (21, 1), (1, 613), (9, 5)]
# [tensor([  2, 751,   3,  ...,   2, 861,  17]), tensor([  4, 764,   0,  ...,   1, 347, 754])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 4), (751, 764), (3, 0), (0, 16), (56, 849)]
# [tensor([ 0,  6, 62,  ...,  5,  1, 13]), tensor([616, 557,   6,  ...,  48,   2,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 616), (6, 557), (62, 6), (1, 0), (154, 7)]
# [tensor([349,  18, 346,  ...,  95,  21, 577]), tensor([  8, 317,   0,  ...,   4,  37,  21])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(349, 8), (18, 317), (346, 0), (158, 267), (38, 32)]
# [tensor([ 33,   0,   1,  ...,   1,  16, 285]), tensor([246, 143,  11,  ...,   3,   0, 181])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(33, 246), (0, 143), (1, 11), (946, 8), (81, 81)]
# [tensor([  7, 938, 550,  ...,  47, 108,  13]), tensor([ 34,   5,   1,  ...,   3, 352,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(7, 34), (938, 5), (550, 1), (779, 0), (5, 5)]
# [tensor([  0,   8, 193,  ..., 328,  14, 214]), tensor([595, 278,   1,  ..., 100,  86,  21])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 595), (8, 278), (193, 1), (386, 24), (382, 28)]
# [tensor([18, 10,  0,  ..., 12, 55, 12]), tensor([443,   6,  32,  ..., 233,   9,  46])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(18, 443), (10, 6), (0, 32), (7, 15), (0, 895)]
# [tensor([ 52, 820,   0,  ..., 943,  10,   0]), tensor([447, 272, 622,  ...,  23,   0,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(52, 447), (820, 272), (0, 622), (3, 615), (3, 20)]
# [tensor([ 66, 218, 186,  ...,   0,   0, 612]), tensor([453,   8,  83,  ..., 386, 249,  19])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(66, 453), (218, 8), (186, 83), (5, 14), (3, 0)]
# [tensor([  1,   1, 854,  ...,   0,   1,   0]), tensor([ 49, 742, 222,  ...,  23,  74,  15])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 49), (1, 742), (854, 222), (15, 2), (3, 0)]
# [tensor([167,  22,   5,  ...,  14,   1,   1]), tensor([ 15,  12, 733,  ...,  25, 541,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(167, 15), (22, 12), (5, 733), (530, 214), (0, 43)]
# [tensor([ 90, 591,   6,  ...,   3, 384,  32]), tensor([314,   2, 346,  ..., 327,   3, 226])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(90, 314), (591, 2), (6, 346), (0, 273), (44, 50)]
# [tensor([ 22,  13,  52,  ..., 112,   0,   4]), tensor([  4, 166, 887,  ...,   1, 761,  34])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(22, 4), (13, 166), (52, 887), (35, 0), (0, 1)]
# [tensor([  4, 424, 335,  ...,  82,  31,   0]), tensor([ 17,  60,  13,  ..., 524, 849, 368])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 17), (424, 60), (335, 13), (20, 129), (8, 0)]
# [tensor([ 17,  22, 301,  ..., 868,   9,   0]), tensor([  2,   4,   0,  ...,   7,  15, 108])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(17, 2), (22, 4), (301, 0), (35, 6), (116, 710)]
# [tensor([116, 175, 830,  ..., 568, 333,   0]), tensor([  3,  23,  21,  ...,   0, 628,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(116, 3), (175, 23), (830, 21), (24, 0), (16, 15)]
# [tensor([186,  39,   3,  ..., 675,   0, 167]), tensor([ 15, 489,   5,  ..., 398, 232,  55])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(186, 15), (39, 489), (3, 5), (0, 170), (3, 27)]
# [tensor([278,   0,   3,  ...,  17,  83,   0]), tensor([292, 312, 265,  ...,   3,   5, 767])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(278, 292), (0, 312), (3, 265), (4, 902), (50, 26)]
# [tensor([409,   1, 407,  ...,  39,   9,  15]), tensor([  0, 229,   0,  ..., 143, 300, 236])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(409, 0), (1, 229), (407, 0), (72, 127), (42, 183)]
# [tensor([ 30,   0,  12,  ...,   2, 164, 221]), tensor([936,  49, 604,  ...,  33, 398, 200])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(30, 936), (0, 49), (12, 604), (375, 13), (11, 5)]
# [tensor([ 65,   0,   8,  ..., 165, 870, 243]), tensor([ 13,  52, 851,  ...,   0, 101, 462])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(65, 13), (0, 52), (8, 851), (1, 275), (28, 47)]
# [tensor([  3,  35, 217,  ...,   0,   0,  27]), tensor([568,   3,   6,  ..., 194,   1,  37])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 568), (35, 3), (217, 6), (1, 110), (0, 1)]
# [tensor([121, 389,   5,  ..., 194,  70,  28]), tensor([584, 449, 165,  ..., 217, 360,   7])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(121, 584), (389, 449), (5, 165), (4, 375), (412, 0)]
# [tensor([  1, 566,  36,  ..., 114, 581, 571]), tensor([  0,  18,  76,  ..., 869,   0,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 0), (566, 18), (36, 76), (847, 155), (1, 960)]
# [tensor([  4,  48,  92,  ...,   3,   1, 108]), tensor([561, 597,   1,  ..., 657,   0,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 561), (48, 597), (92, 1), (21, 14), (549, 337)]
# [tensor([10,  2, 46,  ..., 16,  4,  4]), tensor([  7, 352, 496,  ..., 171, 281,   7])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(10, 7), (2, 352), (46, 496), (3, 18), (698, 942)]
# [tensor([385,   0,   6,  ...,  72,   4, 762]), tensor([139,   1, 400,  ..., 709,  43,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(385, 139), (0, 1), (6, 400), (594, 153), (608, 23)]
# [tensor([  3,  81,   4,  ...,  76, 149,   1]), tensor([65, 98, 72,  ..., 26, 46,  0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 65), (81, 98), (4, 72), (384, 28), (162, 0)]
# [tensor([316,  30,  19,  ..., 283, 895, 384]), tensor([  7, 251, 295,  ...,   1,  19,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(316, 7), (30, 251), (19, 295), (66, 10), (118, 242)]
# [tensor([ 67, 827,  16,  ..., 131,   2,  13]), tensor([  7, 543,   0,  ...,  15,  25,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(67, 7), (827, 543), (16, 0), (24, 5), (16, 222)]
# [tensor([  2, 414,  10,  ...,   2, 375,  50]), tensor([  0, 340,   2,  ...,   0,   0,  16])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 0), (414, 340), (10, 2), (0, 536), (724, 330)]
# [tensor([  3,  29, 737,  ...,   2, 142, 224]), tensor([  5,   2,   1,  ..., 418, 142,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 5), (29, 2), (737, 1), (0, 51), (159, 44)]
# [tensor([548,   0,   4,  ...,   2, 924,  46]), tensor([420,  98,   7,  ...,   5,  96,  24])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(548, 420), (0, 98), (4, 7), (119, 303), (60, 292)]
# [tensor([298,  11,   1,  ...,   2,  52,  42]), tensor([ 4, 21,  2,  ...,  0, 96,  2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(298, 4), (11, 21), (1, 2), (174, 0), (30, 8)]
# [tensor([124, 176,   9,  ..., 428,   0,   5]), tensor([ 7, 45,  6,  ...,  0, 12, 14])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(124, 7), (176, 45), (9, 6), (10, 355), (1, 0)]
# [tensor([  0,   2,   3,  ..., 513,  22,   1]), tensor([ 47, 932, 119,  ...,  34,   0,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 47), (2, 932), (3, 119), (0, 401), (1, 2)]
# [tensor([872, 112,  13,  ..., 827,   8, 502]), tensor([  2, 159, 777,  ..., 140,  41, 412])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(872, 2), (112, 159), (13, 777), (0, 981), (592, 2)]
# [tensor([  5,   1, 411,  ...,  55,  11,   4]), tensor([ 19,  28,   5,  ...,   8,   4, 443])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(5, 19), (1, 28), (411, 5), (0, 625), (404, 26)]
# [tensor([850, 980, 164,  ...,   0,   0, 365]), tensor([  9,   2,  66,  ...,  21, 233,  13])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(850, 9), (980, 2), (164, 66), (49, 0), (61, 17)]
# [tensor([295, 258,   2,  ..., 142, 690,   4]), tensor([  8, 325,   1,  ..., 455,  15,   9])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(295, 8), (258, 325), (2, 1), (656, 4), (2, 169)]
# [tensor([167, 106,   3,  ...,   3, 937,   4]), tensor([  0, 354,   5,  ...,   0,   2,  41])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(167, 0), (106, 354), (3, 5), (231, 0), (24, 4)]
# [tensor([ 18,  53, 399,  ...,   4,   0,   5]), tensor([40,  6,  1,  ..., 10, 36,  1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(18, 40), (53, 6), (399, 1), (41, 0), (85, 2)]
# [tensor([668,   5,  21,  ...,   7,  22,   6]), tensor([672,   6,  25,  ...,  13,  23,  18])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(668, 672), (5, 6), (21, 25), (843, 8), (5, 353)]
# [tensor([  4,  14,  15,  ..., 165, 341,   5]), tensor([ 12, 257,   7,  ...,   0,  11, 356])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 12), (14, 257), (15, 7), (42, 0), (334, 8)]
# [tensor([619, 507,   6,  ...,   1,   1,   6]), tensor([  0,   6,   5,  ...,   0, 756,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(619, 0), (507, 6), (6, 5), (414, 372), (6, 0)]
# [tensor([ 19, 308,  99,  ...,   7, 395,   4]), tensor([  0,   0,   1,  ..., 162,   4,  41])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(19, 0), (308, 0), (99, 1), (387, 418), (16, 2)]
# [tensor([557,  38,   0,  ...,   0, 514,   0]), tensor([  6,   1, 188,  ..., 630,   4, 791])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(557, 6), (38, 1), (0, 188), (2, 33), (203, 3)]
# [tensor([ 73, 703,   8,  ...,   3, 574,  89]), tensor([159,   4,   6,  ..., 786,   0,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(73, 159), (703, 4), (8, 6), (4, 14), (271, 255)]
# [tensor([ 1, 21,  8,  ...,  1,  6, 34]), tensor([629, 979,   5,  ...,  31,   3,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 629), (21, 979), (8, 5), (24, 97), (5, 721)]
# [tensor([741, 150,   7,  ...,   9, 309,   0]), tensor([  0,   3,   0,  ..., 117, 465, 329])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(741, 0), (150, 3), (7, 0), (223, 0), (2, 7)]
# [tensor([363,  11,  39,  ...,   6, 288,  36]), tensor([ 85, 598,  33,  ..., 110,  27, 101])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(363, 85), (11, 598), (39, 33), (4, 605), (5, 546)]
# [tensor([  3, 342, 116,  ...,   1,  40,  59]), tensor([  0,   0,  38,  ...,   5, 779, 983])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 0), (342, 0), (116, 38), (328, 3), (6, 28)]
# [tensor([690,  29, 182,  ..., 809, 188,  13]), tensor([  0, 134, 198,  ...,  36,   0,  90])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(690, 0), (29, 134), (182, 198), (15, 99), (161, 0)]
# [tensor([453, 208,  95,  ..., 236,   1,   2]), tensor([  2,  41,   9,  ..., 487, 378, 224])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(453, 2), (208, 41), (95, 9), (4, 189), (638, 101)]
# [tensor([  7, 600, 292,  ...,   4, 139, 572]), tensor([425,   5,   8,  ...,   0,   0,  26])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(7, 425), (600, 5), (292, 8), (8, 4), (0, 821)]
# [tensor([580, 292, 353,  ..., 201, 896,  43]), tensor([  0, 296, 698,  ..., 758, 620,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(580, 0), (292, 296), (353, 698), (22, 58), (62, 734)]
# [tensor([ 61, 139,   8,  ..., 901, 306,  26]), tensor([ 52, 783,  70,  ...,  11, 100, 679])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(61, 52), (139, 783), (8, 70), (3, 10), (26, 0)]
# [tensor([12,  0,  8,  ...,  7, 61,  6]), tensor([  0,   1,  18,  ..., 183, 230,  29])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(12, 0), (0, 1), (8, 18), (48, 145), (624, 9)]
# [tensor([  7,  42, 203,  ..., 944,  47,   2]), tensor([  1, 203, 153,  ...,   0,   0,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(7, 1), (42, 203), (203, 153), (87, 9), (41, 225)]
# [tensor([  6,  48, 865,  ..., 626, 666,  60]), tensor([182,   0,   2,  ...,   0,   9,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(6, 182), (48, 0), (865, 2), (5, 708), (29, 18)]
# [tensor([181,   6, 635,  ..., 138, 155, 969]), tensor([184,   0,   0,  ...,  74,   5,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(181, 184), (6, 0), (635, 0), (4, 12), (19, 4)]
# [tensor([51, 17,  0,  ..., 17, 53,  0]), tensor([ 9,  0,  0,  ...,  0, 99, 11])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(51, 9), (17, 0), (0, 0), (5, 14), (3, 2)]
# [tensor([  5,  54,  56,  ...,  10,   1, 114]), tensor([ 78,   5,   0,  ..., 233, 337, 211])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(5, 78), (54, 5), (56, 0), (13, 31), (195, 38)]
# [tensor([604,   0,  17,  ...,   1, 207,   3]), tensor([ 87,   0,   1,  ...,   0,   4, 377])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(604, 87), (0, 0), (17, 1), (888, 14), (19, 134)]
# [tensor([  7,   0,   0,  ..., 567, 124, 774]), tensor([201,  22,  27,  ...,   7,  21,  12])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(7, 201), (0, 22), (0, 27), (512, 0), (14, 0)]
# [tensor([  2,   0, 325,  ...,  21, 399,   0]), tensor([ 63, 253, 107,  ..., 396,  52,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 63), (0, 253), (325, 107), (95, 217), (42, 1)]
# [tensor([151,  19,   2,  ...,   0, 978,  98]), tensor([721,  19,  91,  ...,  14, 126, 762])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(151, 721), (19, 19), (2, 91), (10, 52), (17, 0)]
# [tensor([  0,  30,   1,  ..., 370,   1,   6]), tensor([133, 665,  33,  ..., 180, 290,  13])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 133), (30, 665), (1, 33), (210, 92), (3, 4)]
# [tensor([  3, 130,   0,  ..., 533, 125,  70]), tensor([198,  27,   8,  ...,   7, 144, 669])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 198), (130, 27), (0, 8), (88, 387), (413, 1)]
# [tensor([ 55, 198,   4,  ..., 895, 555, 153]), tensor([  0,  16,  65,  ..., 838,   1,  45])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(55, 0), (198, 16), (4, 65), (2, 114), (0, 648)]
# [tensor([667, 384,   5,  ...,  18,   6,   6]), tensor([281, 650, 470,  ..., 529,   4, 221])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(667, 281), (384, 650), (5, 470), (117, 125), (0, 355)]
# [tensor([ 62,   0, 181,  ..., 209, 175,  16]), tensor([  2, 340, 575,  ...,   8, 167,  30])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(62, 2), (0, 340), (181, 575), (998, 267), (15, 243)]
# [tensor([598,   0,   9,  ...,   3,   2,   2]), tensor([  4,   9,   0,  ..., 596,   0, 317])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(598, 4), (0, 9), (9, 0), (6, 48), (222, 3)]
# [tensor([574, 152,  37,  ...,   4, 977,   4]), tensor([  3,   2, 139,  ..., 352,   0,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(574, 3), (152, 2), (37, 139), (214, 6), (0, 952)]
# [tensor([921,  13, 278,  ..., 238,   0,  51]), tensor([414, 208,  20,  ...,   0,   2,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(921, 414), (13, 208), (278, 20), (2, 4), (147, 573)]
# [tensor([585, 104,   5,  ...,  11,  29,  13]), tensor([ 84,  12, 552,  ..., 431, 267,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(585, 84), (104, 12), (5, 552), (61, 0), (4, 6)]
# [tensor([  1,   0, 171,  ..., 113,   9,  78]), tensor([ 14,  12,   0,  ...,  29, 108,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 14), (0, 12), (171, 0), (7, 0), (1, 29)]
# [tensor([416,   0,   0,  ...,   0, 707,   4]), tensor([697,  11,   4,  ...,   0,  19,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(416, 697), (0, 11), (0, 4), (460, 0), (17, 266)]
# [tensor([ 11,   0,   1,  ..., 146, 184, 487]), tensor([170, 223,   0,  ..., 811,  25,  18])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(11, 170), (0, 223), (1, 0), (6, 11), (0, 598)]
# [tensor([111,  24, 498,  ..., 202, 714,   0]), tensor([ 54, 456,  12,  ...,   2, 569,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(111, 54), (24, 456), (498, 12), (5, 2), (4, 5)]
# [tensor([146,   9,  16,  ..., 191,  45, 487]), tensor([47,  2, 15,  ..., 86, 46,  0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(146, 47), (9, 2), (16, 15), (266, 0), (1, 0)]
# [tensor([228,   1,  84,  ..., 114,   7,  93]), tensor([  0, 811, 274,  ...,  19, 714,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(228, 0), (1, 811), (84, 274), (1, 32), (2, 0)]
# [tensor([136,  19,   1,  ..., 230,   6,   3]), tensor([ 21, 128,   6,  ...,  87, 858,  42])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(136, 21), (19, 128), (1, 6), (1, 2), (17, 35)]
# [tensor([ 15,   0,   3,  ...,  14, 355, 252]), tensor([153, 196,  20,  ...,   4, 416,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(15, 153), (0, 196), (3, 20), (679, 514), (526, 30)]
# [tensor([ 93, 338, 313,  ..., 139,   7,   6]), tensor([ 0, 12,  2,  ...,  0,  0, 45])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(93, 0), (338, 12), (313, 2), (8, 219), (799, 1)]
# [tensor([ 12, 109, 223,  ...,  34,  91,   5]), tensor([ 0,  0, 19,  ..., 47,  8,  3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(12, 0), (109, 0), (223, 19), (6, 1), (2, 294)]
# [tensor([  0,  16, 515,  ..., 269,  20, 944]), tensor([118,   4, 110,  ...,  29, 539, 153])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 118), (16, 4), (515, 110), (30, 0), (266, 22)]
# [tensor([103,  10,  47,  ...,   8,  14,   7]), tensor([984,   2,   9,  ..., 170,  23,  59])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(103, 984), (10, 2), (47, 9), (7, 163), (0, 5)]
# [tensor([  5,   1, 486,  ...,  34,   3,  52]), tensor([  7, 145, 183,  ...,   0,   2,  61])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(5, 7), (1, 145), (486, 183), (181, 0), (2, 13)]
# [tensor([447, 172,  19,  ...,   1, 521, 885]), tensor([ 18,   6, 953,  ...,   0, 202, 125])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(447, 18), (172, 6), (19, 953), (44, 3), (818, 665)]
# [tensor([ 10,   1, 974,  ...,  64,  49,   0]), tensor([666,  16,  26,  ..., 627,   4,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(10, 666), (1, 16), (974, 26), (7, 96), (3, 773)]
# [tensor([  5,   2,  84,  ..., 288,  20, 600]), tensor([305,  33, 307,  ...,  25,   4,  26])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(5, 305), (2, 33), (84, 307), (3, 43), (273, 100)]
# [tensor([121, 219, 802,  ...,  23, 209,   6]), tensor([ 96, 389,   2,  ...,   1, 240, 287])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(121, 96), (219, 389), (802, 2), (77, 80), (61, 37)]
# [tensor([ 2, 45,  6,  ...,  0,  0,  5]), tensor([111,  35,   5,  ...,  17, 734,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 111), (45, 35), (6, 5), (245, 32), (794, 3)]
# [tensor([  0,   0,   2,  ..., 381, 129, 592]), tensor([  0,   2, 670,  ..., 309, 701,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 0), (0, 2), (2, 670), (198, 562), (23, 367)]
# [tensor([  6,   0,   0,  ...,  60,  76, 550]), tensor([ 29,   1, 113,  ...,  34,   1,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(6, 29), (0, 1), (0, 113), (3, 95), (89, 3)]
# [tensor([  6, 325,  25,  ...,   7,   0,  16]), tensor([ 26, 591,  18,  ..., 500, 525,  11])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(6, 26), (325, 591), (25, 18), (2, 3), (23, 56)]
# [tensor([ 3, 62, 17,  ...,  5,  5,  0]), tensor([ 70, 538, 199,  ..., 266, 144,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 70), (62, 538), (17, 199), (1, 8), (29, 14)]
# [tensor([  1, 433,  38,  ...,   0,   0,   7]), tensor([  0, 170,   0,  ...,   0, 260, 620])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 0), (433, 170), (38, 0), (579, 7), (875, 885)]
# [tensor([722,  35, 984,  ..., 499,   7,   3]), tensor([ 16,   4,  12,  ...,   4,  11, 163])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(722, 16), (35, 4), (984, 12), (226, 388), (58, 37)]
# [tensor([  6, 402, 879,  ..., 135, 181, 618]), tensor([  2,  17, 666,  ...,   2,  98,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(6, 2), (402, 17), (879, 666), (244, 0), (303, 25)]
# [tensor([  1, 298, 304,  ...,   3, 237,   0]), tensor([ 57,   4,  97,  ...,  84,  22, 729])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 57), (298, 4), (304, 97), (230, 18), (11, 132)]
# [tensor([ 2,  7,  0,  ..., 74, 35, 43]), tensor([262, 124, 860,  ...,  49, 773,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 262), (7, 124), (0, 860), (295, 2), (690, 0)]
# [tensor([  4,  20,   1,  ..., 440, 110, 745]), tensor([191,   2,   2,  ..., 468,   0,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 191), (20, 2), (1, 2), (170, 262), (573, 235)]
# [tensor([ 4,  5,  1,  ..., 17, 27, 54]), tensor([  4, 519,  21,  ..., 114, 595, 788])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 4), (5, 519), (1, 21), (534, 424), (796, 0)]
# [tensor([329, 766, 519,  ...,   2,   4,  60]), tensor([  0,   0,   2,  ..., 959,   4,  94])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(329, 0), (766, 0), (519, 2), (8, 370), (25, 2)]
# [tensor([ 17, 958,   1,  ...,   3,   0, 200]), tensor([412, 200,   5,  ..., 882, 173, 202])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(17, 412), (958, 200), (1, 5), (74, 2), (760, 20)]
# [tensor([ 80,   6, 194,  ..., 250,   9,   9]), tensor([  0, 338,   1,  ..., 475,  83,  87])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(80, 0), (6, 338), (194, 1), (28, 27), (100, 1)]
# [tensor([ 27, 197,   3,  ..., 507,  79, 218]), tensor([137,  11,   0,  ...,  52,   4,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(27, 137), (197, 11), (3, 0), (0, 1), (0, 110)]
# [tensor([ 61, 762, 175,  ...,   0,   4, 677]), tensor([156,   4,   0,  ..., 530,  16, 652])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(61, 156), (762, 4), (175, 0), (5, 22), (1, 2)]
# [tensor([ 27, 227,  38,  ...,   1,  34, 102]), tensor([ 12, 310, 148,  ..., 238, 657, 987])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(27, 12), (227, 310), (38, 148), (0, 827), (0, 1)]
# [tensor([ 75, 717,   3,  ...,   5,   2, 829]), tensor([672,  13, 858,  ..., 358,  58,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(75, 672), (717, 13), (3, 858), (118, 58), (1, 127)]
# [tensor([ 36,  38,   2,  ...,   2, 106,   5]), tensor([186,   1,  19,  ...,  35, 501,  10])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(36, 186), (38, 1), (2, 19), (744, 94), (20, 5)]
# [tensor([153, 366,  13,  ..., 190,   3, 769]), tensor([ 29,   0, 791,  ...,   7,   0,  32])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(153, 29), (366, 0), (13, 791), (0, 1), (620, 0)]
# [tensor([630, 306, 368,  ...,   0, 690, 830]), tensor([  4,  17,   0,  ..., 155,   1,  13])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(630, 4), (306, 17), (368, 0), (46, 23), (238, 85)]
# [tensor([  3, 952,  72,  ..., 193,  96,   1]), tensor([ 42, 610,  12,  ..., 343,  26, 671])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 42), (952, 610), (72, 12), (12, 0), (289, 4)]
# [tensor([ 38,  16, 938,  ...,   1, 981, 303]), tensor([363, 932,   8,  ..., 651, 138,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(38, 363), (16, 932), (938, 8), (16, 3), (0, 121)]
# [tensor([  2,  25, 661,  ...,   0,   2,  10]), tensor([ 6,  5,  0,  ..., 19,  0,  6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 6), (25, 5), (661, 0), (489, 467), (2, 800)]
# [tensor([  0, 716,   2,  ..., 988,  16,  49]), tensor([143,  31,   0,  ...,   0,   3,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 143), (716, 31), (2, 0), (4, 35), (94, 26)]
# [tensor([358,   4,  27,  ...,   1,  23,   2]), tensor([  5, 318,   1,  ..., 882,   0,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(358, 5), (4, 318), (27, 1), (440, 511), (315, 5)]
# [tensor([  5, 625, 511,  ...,   0,  15,   0]), tensor([ 14, 471,   0,  ..., 441, 107,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(5, 14), (625, 471), (511, 0), (456, 18), (2, 0)]
# [tensor([459,   5, 270,  ...,   1,  17,  10]), tensor([  0,   6, 713,  ..., 171, 137, 478])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(459, 0), (5, 6), (270, 713), (0, 9), (32, 67)]
# [tensor([ 11,  27,   7,  ...,   6,   0, 146]), tensor([  1,  12, 151,  ...,  12,   1,  37])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(11, 1), (27, 12), (7, 151), (405, 386), (131, 5)]
# [tensor([ 15,  16,   2,  ...,   0,   1, 457]), tensor([ 25, 303,   5,  ...,  14,   0,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(15, 25), (16, 303), (2, 5), (46, 1), (137, 11)]
# [tensor([  0,   5,  78,  ..., 100,   2,   0]), tensor([  0,  11, 547,  ...,   1,  34, 481])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 0), (5, 11), (78, 547), (427, 8), (146, 3)]
# [tensor([917, 614, 384,  ...,   5, 267, 315]), tensor([  2,  13,   0,  ..., 636,  13, 152])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(917, 2), (614, 13), (384, 0), (0, 2), (84, 856)]
# [tensor([ 44,   0, 888,  ...,  78,   4,   0]), tensor([998,   4,  36,  ..., 576,   0, 118])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(44, 998), (0, 4), (888, 36), (0, 10), (10, 327)]
# [tensor([  2,   0, 139,  ...,   2,   0, 737]), tensor([ 17,   1,   0,  ...,  76, 607,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 17), (0, 1), (139, 0), (101, 94), (20, 26)]
# [tensor([129, 240, 282,  ...,  15,  13,  18]), tensor([ 36,   1,  97,  ...,  94, 938,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(129, 36), (240, 1), (282, 97), (926, 10), (82, 0)]
# [tensor([874, 278,  11,  ..., 107, 209,   1]), tensor([ 18,  28,   5,  ...,  17,   0, 384])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(874, 18), (278, 28), (11, 5), (2, 972), (16, 503)]
# [tensor([345,  13,   1,  ..., 323,   3,   0]), tensor([  9, 362, 103,  ...,   5, 383,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(345, 9), (13, 362), (1, 103), (5, 1), (38, 4)]
# [tensor([  0,   3,   0,  ..., 113,   2,   9]), tensor([ 30,   0, 140,  ...,   5, 555,  52])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 30), (3, 0), (0, 140), (1, 18), (150, 7)]
# [tensor([376,  18, 111,  ..., 840,   5,  77]), tensor([  2, 563, 173,  ...,   4,   4,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(376, 2), (18, 563), (111, 173), (2, 572), (38, 41)]
# [tensor([676, 636,   6,  ...,  22,  43,   8]), tensor([  0,   3,   3,  ..., 243,   8,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(676, 0), (636, 3), (6, 3), (27, 224), (37, 129)]
# [tensor([561,   4, 324,  ..., 186,   9,   8]), tensor([  2,  15, 173,  ...,   1, 489,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(561, 2), (4, 15), (324, 173), (15, 0), (4, 27)]
# [tensor([656, 334,  14,  ..., 584,  26,   2]), tensor([357, 242,   4,  ...,   2,  42,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(656, 357), (334, 242), (14, 4), (4, 784), (779, 63)]
# [tensor([887, 236, 262,  ...,   4,   7, 616]), tensor([ 25,   1,   7,  ..., 818, 286,   5])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(887, 25), (236, 1), (262, 7), (5, 1), (4, 48)]
# [tensor([154, 356,  67,  ...,   0,  11,  23]), tensor([340,   2,  60,  ..., 219, 386, 112])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(154, 340), (356, 2), (67, 60), (321, 828), (0, 1)]
# [tensor([ 15, 855,   2,  ...,  12,   1, 134]), tensor([  7,  11,   9,  ...,  75, 671, 580])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(15, 7), (855, 11), (2, 9), (0, 341), (3, 434)]
# [tensor([  1, 200,   4,  ...,   0, 230,   0]), tensor([  5, 112,  62,  ..., 873,  52,  49])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 5), (200, 112), (4, 62), (24, 5), (2, 1)]
# [tensor([  2,   0,   5,  ...,  64, 175,   2]), tensor([  1, 251,   1,  ...,  59,   0,   8])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 1), (0, 251), (5, 1), (119, 278), (608, 121)]
# [tensor([156,   2, 763,  ...,   0, 391, 137]), tensor([118, 484,   0,  ..., 724, 162,  78])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(156, 118), (2, 484), (763, 0), (243, 13), (9, 4)]
# [tensor([328, 937,  55,  ...,   0,   8,  76]), tensor([261,   5,  47,  ...,  30, 300, 735])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(328, 261), (937, 5), (55, 47), (8, 327), (44, 2)]
# [tensor([945,   2,  46,  ...,   0,   3,   2]), tensor([  1, 530,  12,  ...,  96, 315, 114])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(945, 1), (2, 530), (46, 12), (6, 15), (233, 101)]
# [tensor([ 0, 63, 48,  ...,  6,  0, 21]), tensor([  0,  39,  60,  ...,   2, 318,  22])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 0), (63, 39), (48, 60), (5, 278), (28, 2)]
# [tensor([346, 774,  19,  ...,  23,  75, 953]), tensor([332,   0, 130,  ...,   6, 184,  19])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(346, 332), (774, 0), (19, 130), (219, 5), (175, 6)]
# [tensor([781,  42,  14,  ...,  30,  82, 663]), tensor([ 14,  10,  29,  ...,  97,  77, 552])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(781, 14), (42, 10), (14, 29), (2, 72), (19, 21)]
# [tensor([ 24,  56,  28,  ..., 341, 266,   3]), tensor([15,  0, 91,  ...,  5,  0,  0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(24, 15), (56, 0), (28, 91), (1, 101), (104, 18)]
# [tensor([ 3, 17,  0,  ...,  0,  0, 48]), tensor([  2,  36, 816,  ..., 114, 295, 820])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 2), (17, 36), (0, 816), (2, 492), (2, 64)]
# [tensor([ 2,  7,  0,  ..., 58, 53, 79]), tensor([718, 421,   4,  ...,   4,   0,  14])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 718), (7, 421), (0, 4), (4, 28), (5, 923)]
# [tensor([261,  67,  13,  ...,  40,  65,   3]), tensor([  3,  71,   0,  ...,   0, 910,  37])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(261, 3), (67, 71), (13, 0), (4, 128), (125, 6)]
# [tensor([  4,   2,   1,  ..., 456,  15,  16]), tensor([  3, 402,  91,  ...,  46,   2, 253])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 3), (2, 402), (1, 91), (259, 4), (659, 39)]
# [tensor([ 15, 372, 111,  ...,  61, 481, 844]), tensor([360, 414, 202,  ...,  52,  13,   8])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(15, 360), (372, 414), (111, 202), (54, 26), (172, 310)]
# [tensor([ 23,   4,   6,  ...,  24, 272,   1]), tensor([285,   3, 450,  ...,  22,   4, 285])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(23, 285), (4, 3), (6, 450), (248, 14), (0, 278)]
# [tensor([132,   1,   2,  ...,   1,   3,  29]), tensor([  0,  91,   3,  ...,   9, 342,  37])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(132, 0), (1, 91), (2, 3), (138, 982), (0, 13)]
# [tensor([369, 169,  21,  ..., 179, 315, 128]), tensor([588,   5, 585,  ..., 113,   1,  13])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(369, 588), (169, 5), (21, 585), (76, 389), (4, 56)]
# [tensor([  1,   1,   0,  ...,   2,   4, 508]), tensor([352,   1,  36,  ...,  10,   0,  13])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 352), (1, 1), (0, 36), (263, 0), (121, 2)]
# [tensor([  0, 817,  13,  ...,   0,   5, 154]), tensor([ 12,  93,   3,  ...,  16, 490,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 12), (817, 93), (13, 3), (329, 4), (260, 14)]
# [tensor([  0, 121,  65,  ..., 610,  25, 213]), tensor([568,   0,   1,  ..., 163,   1,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 568), (121, 0), (65, 1), (563, 57), (7, 6)]
# [tensor([ 15, 278,  50,  ..., 134,   0,   2]), tensor([  2,   8,  14,  ...,  17,   1, 395])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(15, 2), (278, 8), (50, 14), (497, 0), (698, 1)]
# [tensor([  2,   0,   0,  ...,   3, 582,  26]), tensor([506, 274,  18,  ..., 328,   2,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 506), (0, 274), (0, 18), (15, 168), (0, 837)]
# [tensor([  2, 210,   6,  ..., 570,   8,   3]), tensor([270,  17,  18,  ..., 275, 329,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 270), (210, 17), (6, 18), (144, 213), (0, 392)]
# [tensor([386,   0,   0,  ...,  40,   2,   1]), tensor([ 0, 11, 25,  ...,  6,  2, 19])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(386, 0), (0, 11), (0, 25), (40, 6), (49, 1)]
# [tensor([  0, 249, 175,  ...,   0, 853, 236]), tensor([125,   2,   0,  ...,   6,  10,  32])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 125), (249, 2), (175, 0), (259, 904), (133, 10)]
# [tensor([  5,  11, 550,  ...,   1, 301,   7]), tensor([537, 414,   1,  ...,  54,   5, 163])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(5, 537), (11, 414), (550, 1), (40, 15), (290, 4)]
# [tensor([689, 203,   0,  ...,   9, 136, 995]), tensor([498,   0, 385,  ..., 319, 517,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(689, 498), (203, 0), (0, 385), (0, 9), (327, 0)]
# [tensor([  1, 407,   4,  ..., 186,   0, 613]), tensor([  5,  20, 840,  ..., 117,   1, 979])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 5), (407, 20), (4, 840), (17, 0), (1, 586)]
# [tensor([ 16,   2,  37,  ..., 237,   5,  12]), tensor([ 13, 363,  74,  ..., 510,  11, 126])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(16, 13), (2, 363), (37, 74), (296, 19), (0, 550)]
# [tensor([  2,  23, 304,  ...,   4,   1, 122]), tensor([  0,  37,  53,  ...,   0,   1, 505])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 0), (23, 37), (304, 53), (506, 7), (68, 507)]
# [tensor([304,  29,   5,  ..., 539, 178, 185]), tensor([922,  37, 492,  ...,   0, 105, 280])]
# Target batch shape: torch.Size([1024])
# ...
# Example batch (targets, contexts): [(10, 248), (120, 944), (7, 818), (2, 343), (675, 273)]
# [tensor([295,  70,  79,  ...,   0,  20,   0]), tensor([  0,   0, 378,  ...,  79, 523,  80])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(295, 0), (70, 0), (79, 378), (782, 24), (5, 2)]
# [tensor([ 64, 263,   0,  ...,   0,   3, 162]), tensor([  4,   1,   5,  ..., 434,   2,   4])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(64, 4), (263, 1), (0, 5), (1, 265), (0, 1)]
# [tensor([32, 12,  0,  ..., 75,  4, 61]), tensor([  0,   1,  20,  ...,   5, 518,   5])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(32, 0), (12, 1), (0, 20), (10, 815), (3, 241)]
# [tensor([ 16,   4,  13,  ..., 305,   8, 952]), tensor([  3,  36,   0,  ...,   2, 617,  19])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(16, 3), (4, 36), (13, 0), (330, 388), (382, 91)]
# [tensor([  7,   4,  40,  ..., 269, 144, 231]), tensor([418,  26,   5,  ..., 499, 896, 457])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(7, 418), (4, 26), (40, 5), (992, 21), (35, 178)]
# [tensor([ 44,   0,  13,  ...,   0,  20, 601]), tensor([ 22, 110, 954,  ..., 245, 481,  12])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(44, 22), (0, 110), (13, 954), (3, 57), (315, 895)]
# [tensor([358,  17,   4,  ..., 673,  14,   0]), tensor([  0, 969,   8,  ...,  72,  11,  58])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(358, 0), (17, 969), (4, 8), (8, 0), (739, 0)]
# [tensor([  0,  17,   4,  ..., 555, 106, 637]), tensor([ 1,  0,  0,  ...,  2,  0, 13])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 1), (17, 0), (4, 0), (54, 86), (38, 652)]
# [tensor([  0,  54,  25,  ...,   4,  12, 225]), tensor([  4, 178,   0,  ...,   0,   2,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 4), (54, 178), (25, 0), (0, 349), (8, 64)]
# [tensor([219, 150, 739,  ..., 932,  43, 318]), tensor([  8, 889,   4,  ...,   3,  15,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(219, 8), (150, 889), (739, 4), (772, 5), (2, 327)]
# [tensor([437,   4,  79,  ...,  38,  78,   2]), tensor([  0,   0, 360,  ...,   3,   7, 300])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(437, 0), (4, 0), (79, 360), (45, 18), (16, 15)]
# [tensor([  3, 463, 726,  ...,  82,  12, 724]), tensor([ 35, 328,  23,  ..., 264,  78, 259])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 35), (463, 328), (726, 23), (0, 12), (8, 5)]
# [tensor([902,   0, 351,  ...,   7, 422,   4]), tensor([949,  31,  21,  ..., 116,  17,  20])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(902, 949), (0, 31), (351, 21), (91, 112), (189, 71)]
# [tensor([  5, 135,   4,  ..., 107,   9,   0]), tensor([446, 143,  16,  ..., 873, 760,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(5, 446), (135, 143), (4, 16), (4, 19), (499, 95)]
# [tensor([ 11,   4,   9,  ...,   1,  80, 363]), tensor([146,  95,  15,  ..., 878,   3,   5])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(11, 146), (4, 95), (9, 15), (1, 0), (457, 510)]
# [tensor([ 1, 19,  6,  ..., 42,  3, 56]), tensor([  5, 473,   7,  ...,   2,   2, 878])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 5), (19, 473), (6, 7), (0, 10), (65, 454)]
# [tensor([ 66,  70, 178,  ...,   1, 212,   5]), tensor([  3, 100,  26,  ...,   4, 698,  73])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(66, 3), (70, 100), (178, 26), (78, 4), (428, 1)]
# [tensor([356,   2,  56,  ...,  32, 146,   5]), tensor([341,   3,   8,  ...,  41, 975, 988])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(356, 341), (2, 3), (56, 8), (11, 0), (29, 6)]
# [tensor([  4,   9, 317,  ...,  14,  16,   4]), tensor([  0, 117,  46,  ..., 640,   4,   3])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 0), (9, 117), (317, 46), (5, 99), (16, 478)]
# [tensor([ 51,   0,   1,  ...,   4, 189,  29]), tensor([  3,  56,   0,  ..., 366,   0,  27])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(51, 3), (0, 56), (1, 0), (0, 5), (165, 828)]
# [tensor([ 12,   0, 511,  ...,   0, 305,   8]), tensor([ 24,   1,  22,  ..., 353, 352, 167])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(12, 24), (0, 1), (511, 22), (145, 420), (0, 298)]
# [tensor([ 24, 115,   0,  ...,   9,   2,  73]), tensor([ 69,  15,   1,  ..., 780,   0,  41])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(24, 69), (115, 15), (0, 1), (0, 85), (613, 26)]
# [tensor([693,   0,   2,  ...,   0,   4,   3]), tensor([16,  1,  3,  ...,  4,  3, 94])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(693, 16), (0, 1), (2, 3), (17, 462), (150, 4)]
# [tensor([  4,  39,  86,  ..., 178,   7,   6]), tensor([  9, 428, 404,  ..., 367, 212,  18])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 9), (39, 428), (86, 404), (4, 14), (8, 1)]
# [tensor([  1, 639,   0,  ..., 474,   8,  94]), tensor([  0,  25,  17,  ...,  11, 652, 644])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 0), (639, 25), (0, 17), (796, 4), (11, 91)]
# [tensor([11,  4,  7,  ..., 15, 20,  8]), tensor([234, 416,  92,  ...,  75, 422,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(11, 234), (4, 416), (7, 92), (28, 1), (12, 86)]
# [tensor([282, 187,  21,  ...,  12,   4,  58]), tensor([ 18,   3,   1,  ...,   2,   0, 197])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(282, 18), (187, 3), (21, 1), (0, 13), (152, 4)]
# [tensor([404, 249,   0,  ...,  86,   2,   3]), tensor([ 17,   2, 465,  ...,  71,   7, 623])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(404, 17), (249, 2), (0, 465), (3, 7), (57, 55)]
# [tensor([  9, 636,  10,  ...,   8,   0, 483]), tensor([  2,  40, 337,  ...,  33, 382,  11])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(9, 2), (636, 40), (10, 337), (26, 96), (2, 259)]
# [tensor([472, 279,   7,  ..., 296,  28,   0]), tensor([ 33,   3, 403,  ...,   0, 306,  29])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(472, 33), (279, 3), (7, 403), (2, 124), (3, 48)]
# [tensor([124, 206,  13,  ..., 513, 243, 464]), tensor([955,   1,   0,  ...,  69, 211,   5])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(124, 955), (206, 1), (13, 0), (85, 249), (1, 2)]
# [tensor([ 10,   6,   6,  ..., 130,  29,   3]), tensor([ 5, 18, 51,  ..., 14,  8,  5])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(10, 5), (6, 18), (6, 51), (188, 0), (130, 0)]
# [tensor([  7,  22,  42,  ...,   1, 417,  32]), tensor([ 99,  39,   8,  ..., 199,   0,  27])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(7, 99), (22, 39), (42, 8), (93, 15), (341, 1)]
# [tensor([ 39,   0, 333,  ..., 353, 350, 240]), tensor([  3,  67,   6,  ...,  95, 353, 262])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(39, 3), (0, 67), (333, 6), (90, 11), (93, 841)]
# [tensor([537, 287, 630,  ...,  15,  74,  67]), tensor([ 28, 206, 541,  ...,   6,  24,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(537, 28), (287, 206), (630, 541), (2, 614), (175, 0)]
# [tensor([213,   2,   5,  ..., 735, 627, 705]), tensor([ 53,   2,   1,  ...,  66, 519,  25])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(213, 53), (2, 2), (5, 1), (96, 0), (475, 752)]
# [tensor([325, 165,   1,  ..., 556,   0, 601]), tensor([953,   1,   2,  ...,   0,   1,   0])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(325, 953), (165, 1), (1, 2), (643, 3), (0, 149)]
# [tensor([  2,   3,   0,  ..., 464,   1,  20]), tensor([ 77,   0,   0,  ...,  12,  17, 986])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 77), (3, 0), (0, 0), (320, 368), (18, 14)]
# [tensor([208,   3,  52,  ...,   4, 500,  53]), tensor([103, 222, 608,  ...,  12, 506,  21])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(208, 103), (3, 222), (52, 608), (112, 0), (539, 375)]
# [tensor([  2,   2, 594,  ..., 172, 118,  19]), tensor([407,   0,   5,  ...,   6,  15,  16])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(2, 407), (2, 0), (594, 5), (4, 45), (140, 0)]
# [tensor([ 21,  12,  25,  ...,   0, 191,   6]), tensor([  0, 287, 427,  ...,  19,  14, 567])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(21, 0), (12, 287), (25, 427), (621, 1), (3, 47)]
# [tensor([  7, 553,   2,  ...,   7,  23,  18]), tensor([776,  16,   4,  ...,   0,   1,   2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(7, 776), (553, 16), (2, 4), (298, 828), (11, 41)]
# [tensor([  1,   0, 802,  ..., 635, 861, 383]), tensor([  3,   0,   6,  ...,   7, 339, 358])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(1, 3), (0, 0), (802, 6), (0, 0), (0, 1)]
# [tensor([  4,  15,   0,  ..., 120, 719, 667]), tensor([367, 496,   0,  ...,   0,  17, 368])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 367), (15, 496), (0, 0), (160, 160), (11, 8)]
# [tensor([  3,  37, 288,  ..., 477,   1,   2]), tensor([360,  32,  14,  ...,  12, 161,  15])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 360), (37, 32), (288, 14), (9, 1), (5, 0)]
# [tensor([ 13,  43,   8,  ..., 257,   0, 421]), tensor([  6,  25,   0,  ...,   7,   8, 223])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(13, 6), (43, 25), (8, 0), (414, 2), (419, 196)]
# [tensor([  6, 142,   0,  ...,   4,   2, 831]), tensor([ 25,   0, 124,  ...,   1,  36,  25])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(6, 25), (142, 0), (0, 124), (5, 309), (39, 366)]
# [tensor([ 19, 246,   3,  ...,   3,   7, 516]), tensor([  0,  51, 198,  ...,  59,   4, 184])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(19, 0), (246, 51), (3, 198), (4, 9), (9, 4)]
# [tensor([  0, 459,   2,  ..., 838,   3,   9]), tensor([268, 922,   6,  ...,   2,   5, 186])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 268), (459, 922), (2, 6), (19, 482), (4, 2)]
# [tensor([374,   6, 195,  ..., 697,  29, 170]), tensor([831,  40,   3,  ...,   4,   0,   6])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(374, 831), (6, 40), (195, 3), (21, 3), (132, 174)]
# [tensor([ 3, 15, 34,  ..., 21, 12, 10]), tensor([ 0, 63, 12,  ..., 11,  0,  2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 0), (15, 63), (34, 12), (0, 1), (3, 0)]
# [tensor([  4, 864, 481,  ..., 550, 838,  98]), tensor([  0,  29,   6,  ..., 970,  48,  44])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(4, 0), (864, 29), (481, 6), (6, 223), (114, 4)]
# [tensor([  3, 140,   0,  ..., 607,   4, 147]), tensor([ 35,   2, 286,  ...,  85,  58, 668])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(3, 35), (140, 2), (0, 286), (720, 5), (59, 6)]
# [tensor([ 69,   2, 217,  ...,   1, 107,  21]), tensor([207, 104,  13,  ..., 153, 527, 563])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(69, 207), (2, 104), (217, 13), (23, 51), (0, 13)]
# [tensor([ 84, 275, 370,  ..., 456,   1,   5]), tensor([  0,  13, 772,  ...,   0, 428,   1])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(84, 0), (275, 13), (370, 772), (16, 32), (166, 458)]
# [tensor([705,  60,  67,  ..., 656,   1, 277]), tensor([ 1, 25, 65,  ...,  0, 12,  2])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(705, 1), (60, 25), (67, 65), (10, 0), (4, 445)]
# [tensor([511,   0,   0,  ..., 986,   0,  70]), tensor([901,   6,   0,  ...,  10, 621,  22])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(511, 901), (0, 6), (0, 0), (0, 4), (0, 601)]
# [tensor([914,   9, 100,  ..., 936,   7, 138]), tensor([101, 890,   9,  ..., 187, 231, 414])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(914, 101), (9, 890), (100, 9), (206, 0), (5, 173)]
# [tensor([164, 550,   3,  ...,  70, 169, 406]), tensor([ 2, 29, 21,  ...,  4,  3,  7])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(164, 2), (550, 29), (3, 21), (592, 3), (179, 27)]
# [tensor([  0, 523,   2,  ...,   0,  66,  33]), tensor([881,  12,  12,  ..., 265,  68, 159])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(0, 881), (523, 12), (2, 12), (2, 87), (186, 45)]
# [tensor([ 19, 588,   5,  ..., 141, 349,  31]), tensor([114,  13, 285,  ...,   2,  13,  28])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(19, 114), (588, 13), (5, 285), (214, 31), (60, 29)]
# [tensor([287, 105,   2,  ...,  79,   0, 113]), tensor([466,  10,  21,  ...,   0,   0,   8])]
# Target batch shape: torch.Size([1024])
# Context batch shape: torch.Size([1024])
# Example batch (targets, contexts): [(287, 466), (105, 10), (2, 21), (302, 5), (1, 112)]

# %%
batch_size = 1024

# %%
loader = torch.utils.data.DataLoader(word_contexts, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
for words, contexts in dataloader:
    print("Batch de mots (targets):", words.shape)
    print("Batch de contextes:", contexts.shape)
    print("Exemple de paires (w, c+):", list(zip(words[:5].tolist(), contexts[:5].tolist())))
    break  # Arrêter après le premier batch
# Out:
# Batch de mots (targets): torch.Size([1024])
# Batch de contextes: torch.Size([1024])
# Exemple de paires (w, c+): [(5, 4), (46, 258), (998, 734), (4, 3), (17, 263)]

# %% [markdown]
# ### Negative examples
#
# Using `torch.randint` draw $k=10$ random negative examples from the vocabulary for each target word $w$

# %%
K_size=10
Vocab_size = len(vocab)

# %%
def generate_negative_samples(vocab_size: int, batch_size: int, k: int) -> torch.Tensor:
    """
    Generates k negative samples for each target word in the batch.

    Args:
    - vocab_size (int): Taille du vocabulaire.
    - batch_size (int): Nombre d'exemples dans le batch.
    - k (int): Nombre d'exemples négatifs à tirer.

    Returns:
    - neg_samples (torch.Tensor): Tensor de shape (batch_size, k) contenant les indices des mots négatifs.
    """
    neg_samples = torch.randint(low=0, high=vocab_size, size=(batch_size, k))
    return neg_samples

# %%
for words, contexts in dataloader:
    neg_samples = generate_negative_samples(Vocab_size, words.shape[0], K_size)

    print("Target words batch:", words.shape)
    print("Positive context batch:", contexts.shape)
    print("Negative samples batch:", neg_samples.shape)
    print("Example negative samples for first word in batch:", neg_samples[0].tolist())
    break  # Afficher un seul batch
# Out:
# Target words batch: torch.Size([1024])
# Positive context batch: torch.Size([1024])
# Negative samples batch: torch.Size([1024, 10])
# Example negative samples for first word in batch: [248, 931, 611, 386, 257, 743, 591, 483, 536, 180]

# %% [markdown]
# Concatenate the indices of negatives and positives examples but keep track of the labels (`1.0` for positive, `0.0` for negative)

# %%
def prepare_training_data(dataloader, vocab_size, k=10):
    """
    Prepares the training data by concatenating positive and negative samples
    and assigning the corresponding labels.

    Args:
    - dataloader: DataLoader fournissant les (words, context).
    - vocab_size (int): Taille du vocabulaire.
    - k (int): Nombre d'exemples négatifs par mot cible.

    Returns:
    - targets (torch.Tensor): Tenseurs des mots cibles.
    - contexts (torch.Tensor): Concaténation des exemples positifs et négatifs.
    - labels (torch.Tensor): Labels associés (1.0 pour positif, 0.0 pour négatif).
    """
    all_targets = []
    all_contexts = []
    all_labels = []

    for words, contexts in dataloader:
        batch_size = words.shape[0]

        # Générer des exemples négatifs
        neg_samples = generate_negative_samples(vocab_size, batch_size, k)

        # Concaténer les exemples positifs et négatifs
        context_combined = torch.cat([contexts.unsqueeze(1), neg_samples], dim=1)  # Shape (batch_size, k+1)
        labels = torch.cat([torch.ones(batch_size, 1), torch.zeros(batch_size, k)], dim=1)  # Shape (batch_size, k+1)

        # Stocker les données
        all_targets.append(words)  # Shape (batch_size,)
        all_contexts.append(context_combined)  # Shape (batch_size, k+1)
        all_labels.append(labels)  # Shape (batch_size, k+1)

    # Convertir en tenseurs PyTorch concaténés
    targets_tensor = torch.cat(all_targets)
    contexts_tensor = torch.cat(all_contexts)
    labels_tensor = torch.cat(all_labels)

    return targets_tensor, contexts_tensor, labels_tensor

# %%
K = 10  # Nombre d'exemples négatifs par mot
targets, contexts, labels = prepare_training_data(dataloader, Vocab_size, k=K_size)

# %%
labels.shape
# Out:
# torch.Size([1202176, 11])

# %%
contexts.shape
# Out:
# torch.Size([1202176, 11])

# %% [markdown]
# ## Model
#
#
# ![diagram](https://paullerner.github.io/aivancity_nlp/_static/skipgram.png)
#
# Using `nn.Embedding`, initialize the two word embedding matrices, $W$ (word) and $C$ (context), of shape $(V, d)$. Let's see $d=100$ for now.

# %%
d=100

# %%
import torch.nn as nn

# Paramètres du modèle
V = len(vocab)  # Taille du vocabulaire
d = 100  # Dimension des embeddings

# Initialisation des embeddings
embedding_W = nn.Embedding(num_embeddings=V, embedding_dim=d)
embedding_C = nn.Embedding(num_embeddings=V, embedding_dim=d)

# Vérification des dimensions
print("Word embedding matrix W shape:", embedding_W.weight.shape)
print("Context embedding matrix C shape:", embedding_C.weight.shape)
# Out:
# Word embedding matrix W shape: torch.Size([1000, 100])
# Context embedding matrix C shape: torch.Size([1000, 100])

# %% [markdown]
# You can then call these embeddings by passing them the tokens indices computed above to get the vectors

# %%
embedding_W(words).shape
# Out:
# torch.Size([1024, 100])

# %%
embedding_C(contexts).shape
# Out:
# torch.Size([1202176, 11, 100])

# %% [markdown]
# ## Probability of similarity (sigmoid)
# $$P(+ | w,c) = \sigma(c \cdot w) = \frac{1}{1+\exp(-c \cdot w)}$$
#
#
# Compute the similarity $c \cdot w$. No need to compute Sigmoid as it is integrated in the loss function (see below).

# %%
def compute_similarity(targets, contexts, embedding_W, embedding_C):
    """
    Compute the similarity c ⋅ w between word and context embeddings.

    Args:
    - targets (torch.Tensor): Indices des mots cibles (shape: [batch_size])
    - contexts (torch.Tensor): Indices des mots de contexte (shape: [batch_size, k+1])
    - embedding_W (nn.Embedding): Matrice d'embedding des mots (V, d)
    - embedding_C (nn.Embedding): Matrice d'embedding des contextes (V, d)

    Returns:
    - similarities (torch.Tensor): Produit scalaire entre c et w (shape: [batch_size, k+1])
    """
    # Récupérer les embeddings des mots cibles (shape: [batch_size, d])
    w_vectors = embedding_W(targets)  # (batch_size, d)

    # Récupérer les embeddings des mots de contexte (shape: [batch_size, k+1, d])
    c_vectors = embedding_C(contexts)  # (batch_size, k+1, d)

    # Reshape w_vectors pour qu'il soit (batch_size, d, 1)
    w_vectors = w_vectors.unsqueeze(2)  # (batch_size, d, 1)

    # Produit scalaire entre chaque paire (w, c) -> shape: (batch_size, k+1)
    similarities = torch.matmul(c_vectors, w_vectors).squeeze(2)

    return similarities

# %%
# 🔥 Test avec un batch d'entraînement
for words, contexts in dataloader:
    similarities = compute_similarity(words, contexts, embedding_W, embedding_C)

    print("Similarity tensor shape:", similarities.shape)  # (batch_size, k+1)
    print("Example similarities:", similarities[:5])
    break  # Tester uniquement sur un batch
# Out:
# Similarity tensor shape: torch.Size([1024, 1024])
# Example similarities: tensor([[ -4.4987, -12.2394,   4.2754,  ..., -13.9737, -14.6826,   7.6650],
#         [-20.0720,  -6.8195,  11.2739,  ...,   7.8222,   0.1693, -13.4752],
#         [  5.1556,  -8.1852,  -4.3052,  ..., -12.6521,   8.0265,  10.4137],
#         [ -6.2136,   9.3837,  -9.5842,  ..., -16.6773,  -7.9885,   8.3415],
#         [  3.8548,  15.6787,   2.3566,  ...,   8.8896,  -9.3696, -12.1108]],
#        grad_fn=<SliceBackward0>)

# %%
similarities.shape
# Out:
# torch.Size([1024, 1024])

# %% [markdown]
# ## Loss: Binary Cross Entropy
#
# Compute the loss using `nn.BCEWithLogitsLoss`
#
# $$- \left(\log\sigma(c_+ \cdot w) + \sum_{i=1}^{k} \log\sigma(-c_i \cdot w)\right) $$
#
# You will need to reshape similarities and labels

# %%
def compute_loss(similarities, labels):
    """
    Compute the Binary Cross Entropy Loss using BCEWithLogitsLoss.

    Args:
    - similarities (torch.Tensor): Produit scalaire entre c et w (shape: [batch_size, k+1])
    - labels (torch.Tensor): Labels (1.0 pour positif, 0.0 pour négatif) (shape: [batch_size, k+1])

    Returns:
    - loss (torch.Tensor): Valeur scalaire de la perte.
    """
    # Initialiser la fonction de perte BCEWithLogitsLoss
    criterion = nn.BCEWithLogitsLoss()

    # Reshape les tenseurs pour qu'ils aient la même forme
    similarities = similarities.view(-1)  # (batch_size * (k+1),)
    labels = labels.view(-1)  # (batch_size * (k+1),)

    # Calcul de la perte
    loss = criterion(similarities, labels)
    return loss

# %%
for words, contexts in dataloader:
    print("Words shape:", words.shape)
    print("Contexts shape:", contexts.shape)  # Vérifier la forme

    # S'assurer que `contexts` est bien en 2D
    if contexts.dim() == 1:
        contexts = contexts.unsqueeze(1)  # Ajoute une dimension si nécessaire

    batch_size = words.shape[0]
    k = contexts.shape[1] - 1  # k+1 (1 positif + k négatifs)

    labels = torch.cat([torch.ones(batch_size, 1), torch.zeros(batch_size, k)], dim=1).to(contexts.device)

    # Calcul des similarités
    similarities = compute_similarity(words, contexts, embedding_W, embedding_C)

    # Calcul de la perte
    loss = compute_loss(similarities, labels)

    print("Loss:", loss.item())
    break  # Tester sur un seul batch
# Out:
# Words shape: torch.Size([1024])
# Contexts shape: torch.Size([1024])
# Loss: 4.290567874908447

# %%
similarities.reshape(-1).shape
# Out:
# torch.Size([1024])

# %% [markdown]
# ## Training loop
#
# Now that you checked everything is working, pack everything above in a `nn.Module` and training loop
#
# Ensure that everything is on GPU by calling `.cuda()` or passing `device="cuda"` on init

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class Skipgram(nn.Module):
    def __init__(self, vocab_size, embedding_dim, device="cuda"):
        super(Skipgram, self).__init__()
        self.device = torch.device(device if torch.cuda.is_available() else "cpu")

        # Word embedding matrix W
        self.W = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_dim)

        # Context embedding matrix C
        self.C = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_dim)

        # Move model to GPU if available
        self.to(self.device)

    def forward(self, words, contexts):
        """
        Computes similarities (dot product between word and context embeddings)
        """
        # Get word embeddings (batch_size, d)
        word_vectors = self.W(words.to(self.device))  # (batch_size, d)

        # Ensure `contexts` has the correct shape: (batch_size, k+1)
        if contexts.dim() == 1:
            contexts = contexts.unsqueeze(1)

        # Get context embeddings (batch_size, k+1, d)
        context_vectors = self.C(contexts.to(self.device))  # (batch_size, k+1, d)

        # Compute dot product (batch_size, k+1)
        similarities = torch.matmul(context_vectors, word_vectors.unsqueeze(2)).squeeze(2)

        return similarities  # Correct shape: (batch_size, k+1)

# %%
# Model Parameters
V = len(vocab)   # Vocabulary size
d = 100          # Embedding dimension
K = 10           # Negative samples
BATCH_SIZE = 1024
EPOCHS = 5
LR = 0.001       # Learning rate

# %%
# Initialize model
model = Skipgram(V, d).cuda()

# Loss function & Optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

criterion = criterion.cuda()  # Ensure loss runs on GPU

# %% [markdown]
# Run tensorboard before training. Refresh during training.

# %%
def train_model(model, dataloader, epochs):
    for epoch in range(epochs):
        total_loss = 0.0

        for words, contexts in dataloader:
            batch_size = words.shape[0]

            # Ensure `contexts` has correct shape (batch_size, k+1)
            if contexts.dim() == 1:
                contexts = contexts.unsqueeze(1)

            # Generate labels (1 for positive, 0 for negatives)
            labels = torch.cat([torch.ones(batch_size, 1), torch.zeros(batch_size, K)], dim=1).to(model.device)

            # Forward pass
            similarities = model(words, contexts)

            # **Fix shape issue**: Make sure `similarities` matches `labels`
            assert similarities.shape == labels.shape, f"Shape mismatch: {similarities.shape} vs {labels.shape}"

            # Compute loss
            loss = criterion(similarities, labels)

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        # Print loss after every epoch
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {total_loss / len(dataloader):.4f}")

# %%
train_model(model, dataloader, EPOCHS)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-219-d58e889cc1f7> in <cell line: 0>()
# ----> 1 train_model(model, dataloader, EPOCHS)
#
# <ipython-input-218-5f86b1ad5001> in train_model(model, dataloader, epochs)
#      17
#      18             # **Fix shape issue**: Make sure `similarities` matches `labels`
# ---> 19             assert similarities.shape == labels.shape, f"Shape mismatch: {similarities.shape} vs {labels.shape}"
#      20
#      21             # Compute loss
#
# AssertionError: Shape mismatch: torch.Size([1024, 1]) vs torch.Size([1024, 11])

# %%
skipgram = Skipgram().cuda()

optimizer = torch.optim.AdamW(skipgram.parameters(), lr=0.0001)

batch_size = 1024
k=10
loader = torch.utils.data.DataLoader(word_contexts, batch_size=batch_size, shuffle=True, drop_last=True)

steps = 0
for epoch in range(10):
    for words, contexts in loader:
        words = words.cuda()
        contexts = contexts.cuda()

        # TODO
        negatives =

        similarities =

        loss = loss_fct(similarities.reshape(-1), labels.reshape(-1))
        writer.add_scalar("Loss/train", loss.item(), steps)
        steps+=1
        loss.backward()
        optimizer.step()

# %% [markdown]
# # Part 2 - Analogies and Intrinsic Evaluation of Embeddings

# %% [markdown]
# ## Data and imports
#
# We'll manipulate numpy arrays instead of torch tensors from here

# %%
# %pip install gensim

# %%
import torch
import numpy as np

# %%
import gensim.downloader

# %%
# take the embeddings from the model you just trained
#embeddings = skipgram.W.weight.detach().cpu().numpy()

# %%
# load from a model you previously trained
#embeddings = torch.load("embeddings.bin").numpy()

# %%
# load a model someone else trained, probably better than yours (more data, larger vocabulary, etc.)
keyedvectors = gensim.downloader.load("word2vec-google-news-300")

embeddings = keyedvectors.vectors
vocabulary = {word: index for index, word in enumerate(keyedvectors.index_to_key)}
i2token = {index: word for index, word in enumerate(keyedvectors.index_to_key)}
V = len(vocabulary)

# %% [markdown]
# ## Qualitative/playing around

# %% [markdown]
# ### visualization
#
# We'll reduce embeddings to 2D using [PCA](https://en.wikipedia.org/wiki/Principal_component_analysis) to be able to plot them
#
# What can you see from the plot? Take a look at near-synonyms like "large" and "massive", or "interesting" and "fascinating".

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings)

# %% [markdown]
# Using `plt.scatter` plot the 2D embeddings of the words in `words`. Also show the word using `plt.annotate`

# %%
words = ['movie', 'book', 'mysterious', 'story', 'fascinating', 'good', 'interesting', 'large', 'massive', 'huge', "woman","man","he","she",'july',
 'december',
 'february',
 'november',
 'october',
 'january',
 'april',
 'june']

# %% [markdown]
# ### Nearest neighbors
#
#
# Now that we have word vectors, we need a way to quantify the similarity between individual words, according to these vectors. One such metric is cosine-similarity. We will be using this to find words that are "close" and "far" from one another.
#
# We can think of n-dimensional vectors as points in n-dimensional space. If we take this perspective [L1](http://mathworld.wolfram.com/L1-Norm.html) and [L2](http://mathworld.wolfram.com/L2-Norm.html) Distances help quantify the amount of space "we must travel" to get between these two points. Another approach is to examine the angle between two vectors. From trigonometry we know that:
#
#
#
# Instead of computing the actual angle, we can leave the similarity in terms of similarity $s = \cos(\Theta)$. Formally the [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity) $s$ between two vectors $p$ and $q$ is defined as:
#
# $$s = \frac{p \cdot q}{||p|| \cdot ||q||}, \textrm{ where } s \in [-1, 1] $$
#
#
# Compute the 10 nearest neighbors of the words from the above `words` list

# %% [markdown]
# #### Bias
#
# What word appears in the top-10 closest to "woman" and "she"? Compare to "man" and "he".

# %% [markdown]
# ### Analogies
#
# #### Semantic analogies
# Word vectors have been shown to *sometimes* exhibit the ability to solve analogies.
#
# As an example, for the analogy "man : grandfather :: woman : t" (read: man is to grandfather as woman is to t), what is t?
#
# noting analogies $x:y :: z:t$ ($x$ is to $y$ as $z$ is to?) solve the following analogies using:
# $$\max_{t\in V} \cos(t, y-x+z)$$
#
# You'll see that it does not work perfectly. Instead of keep only the very $\max_{t\in V}$, keep the top 5 (like in the nearest neighbors above)
#
# What's the difference between the first analogies `[("France", "Paris", "Germany"), ("France", "Sarkozy", "Germany")]` and the others?
#
# Try your own examples

# %%
for x, y, z in [("France", "Paris", "Germany"), ("France", "Sarkozy", "Germany"), ("France", "French", "Germany"), ("dog","puppy","cat"), ("man", "grandfather", "woman"), ("man", "king", "woman"), ("apple", "tree", "grape")]:
    raise NotImplementedError("TODO")

# %% [markdown]
# #### Biases
#
# It's important to be cognizant of the biases (gender, race, sexual orientation etc.) implicit in our word embeddings. Bias can be dangerous because it can reinforce stereotypes through applications that employ these models.
#
# Using the same code as above, notice how "gynecologist" is top-2 of "man is to doctor as woman is to?" and "nurse" is 3
#
# Why is that? Try to find other problematic analogies/biases in the embeddings

# %%
for x, y, z in [("man", "doctor", "woman")]:

# %% [markdown]
# ### Syntactic analogies
#
# Word embeddings capture both semantic and syntactic analogies! Use the same code as above but for the following word list.
#
# Notice how it works even with irregular verbs like "eat"
#
#
# Try your own examples

# %%
for x, y, z in [
    # derivational morphology: suffixation
    ("speak", "speaker", "sing"),
    ("short", "shortly", "rapid"),
    # derivational morphology: prefixation
    ("like", "unlike", "able"),
    # inflectional morphology: verbs
    ("walking", "walked", "work"),
    ("walking", "walked", "eating"),
    ("walking", "walked", "going"),
    # inflectional morphology: nouns
    ("shoe", "shoes", "table"),
]:

# %% [markdown]
# ## Quantitative evaluation using academic benchmarks

# %% [markdown]
# ### Correlation of similarity with human judgements

# %% [markdown]
# #### data

# %%
# !wget https://staff.fnwi.uva.nl/e.bruni/resources/MEN.zip

# %%
# !unzip MEN

# %%
import pandas as pd

# %%
dataset = pd.read_csv("MEN/MEN_dataset_natural_form_full", delimiter=" ",names=["a","b","label"])

# %%
dataset

# %% [markdown]
# #### evaluation
#
# Compute the cosine similarity of words `a` and `b` for all words in the dataset, except (of course), those that are absent from our `vocabulary`.
#
# Compute Spearmann correlation between the cosine similarity you computed and the label, using `scipy.stats.spearmanr`

# %%
import scipy

# %% [markdown]
# Compare this value to what is reported in Levy, O., & Goldberg, Y. (2014). Neural Word Embedding as Implicit Matrix Factorization. Advances in Neural Information Processing Systems, 27. https://proceedings.neurips.cc/paper/2014/hash/feab05aa91085b7a8012516bc3533958-Abstract.html

# %% [markdown]
# Inspect this correlation visually: plot the cosine similarities against the labels

# %% [markdown]
# ### Accuracy of analogies

# %% [markdown]
# #### Data

# %%
# !wget https://www.fit.vut.cz/person/imikolov/public/rnnlm/word-test.v1.txt

# %%
with open("word-test.v1.txt","rt") as file:
    lines = file.read().strip().split("\n")

# %%
lines.pop(0)

# %%
dataset = []
subset_ok=False
for i, line in enumerate(lines):
    # We keep a single subset to save computation time.
    # As a bonus, compute the results on the entire dataset, or for each subset
    if line[0]==":":
        if line ==": family":
            subset_ok=True
        if line == ": gram1-adjective-to-adverb":
            break
        continue
    if subset_ok:
        x,y,z,t = line.split(" ")
        ok = True
        for token in [x,y,z,t]:
            if token not in vocabulary:
                ok = False
                break
        if ok:
            dataset.append((x,y,z,t))

# %%
len(dataset)

# %%
for i in np.random.choice(len(dataset), 10):
    x, y, z, t = dataset[i]
    print(f"{x}:{y} :: {z}:{t}")

# %% [markdown]
# #### evaluation
#
# Using the same code as above, solve the analogy for $x:y :: z:t$ ($x$ is to $y$ as $z$ is to?) using:
# $$\max_{t\in V} \cos(t, y-x+z)$$
#
# For all samples of the dataset
#
# Compute the accuracy (check that you retrieve the correct $t$)

# %%
accuracy

# %% [markdown]
# Compare this value to what is reported in Mikolov, T., Chen, K., Corrado, G., & Dean, J. (2013). Efficient Estimation of Word Representations in Vector Space (arXiv:1301.3781). arXiv. https://doi.org/10.48550/arXiv.1301.3781
#
# Remember we used only the "family" subset, not all semantic analogies.

# %% [markdown]
# # Bonus Part
#
# - Try different hyperparameters in Part. 1:
#   - Vocabulary size $V$
#   - `window_size`
#   - Number of negative examples $k$
#   - embedding dimension $d$
#
# - Try other models than Skipgram in Part. 2:
#   - [fastText](https://fasttext.cc/docs/en/english-vectors.html)
#   - [GloVe](https://nlp.stanford.edu/projects/glove/) (also available via `gensim` used above)
#   - CBOW
